# %% [markdown]
# # Aim: Amazon product review analysis
# 1. Analyze and monitor the entire review history: tone, language, keywords, trends
# 2. To provide insights that increase the success rate of existing and new products and marketing campaigns
#
# ### Product datasets:
# Toys_and_Games
#
# # Scenario: Inventory optimization and demand forecasting
# 1. Identify product categories- clustering as an outcome of text processing
# 2. Predict products that could be in demand- time series analysis

# %% [markdown]
# ---

# %% [markdown]
# # Data acquisition

# %%
import pandas as pd
import gzip
import json

import warnings
warnings.filterwarnings('ignore')

# %%
def parse(path):
    g = gzip.open(path, 'r')
    for l in g:
        yield json.loads(l)
        
def parse(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield json.loads(l)

def getDF(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

# %% [markdown]
# ### Review dataset & Product dataset

# %%
tg = getDF('F:/NIIT/Capstone Project/Resources/Toys_and_Games_5.json.gz')                      
mtg = getDF('F:/NIIT/Capstone Project/Resources/meta_Toys_and_Games.json.gz')

# %% [markdown]
# # Data collection

# %%
import re                     
import numpy as np

# %% [markdown]
# ### Review dataset

# %%
print('Toys_and_Games')
display(tg.head(3))

print('Shape:',tg.shape)
    
print('COLUMN'.ljust(18),'DATATYPE'.ljust(10),'NULL VALUES')
print('--'*20)
for i in tg.columns:
    nanp = tg[i].isnull().sum()/len(tg[i])*100
    print(f'{i:18} {str(tg[i].dtype):10} {nanp:.2f}%')
# Out:
# Toys_and_Games
#    overall vote  verified  reviewTime      reviewerID        asin  \
# 0      5.0    3      True  10 6, 2013  A2LSCFZM2FBZK7  0486427706
# 1      5.0    9      True  08 9, 2013  A3IXP5VS847GE5  0486427706
# 2      5.0  NaN      True  04 5, 2016  A1274GG1EB2JLJ  0486427706
#
#                        style                     reviewerName  \
# 0  {'Format:': ' Paperback'}                           Ginger
# 1  {'Format:': ' Paperback'}  Dragonflies &amp; Autumn Leaves
# 2  {'Format:': ' Paperback'}                      barbara ann
#
#                                           reviewText  \
# 0  The stained glass pages are pretty cool. And i...
# 1  My 11 y.o. loved this...and so do I (you know ...
# 2  The pictures are great , I've done one and gav...
#
#                                              summary  unixReviewTime image
# 0                                          Nice book      1381017600   NaN
# 1                                     Great pictures      1376006400   NaN
# 2  The pictures are great, I've done one and gave...      1459814400   NaN
# Shape: (1828971, 12)
# COLUMN             DATATYPE   NULL VALUES
# ----------------------------------------
# overall            float64    0.00%
# vote               object     88.63%
# verified           bool       0.00%
# reviewTime         object     0.00%
# reviewerID         object     0.00%
# asin               object     0.00%
# style              object     71.38%
# reviewerName       object     0.01%
# reviewText         object     0.06%
# summary            object     0.02%
# unixReviewTime     int64      0.00%
# image              object     97.74%

# %% [markdown]
# Obaservation:
# Fields in Toys_and_Games that had more than 70% missing values: vote, style, and image
#
# Since those fields don't have much information those fields are dropped

# %%
# for reusability
tgc = tg.copy()


# dropping fields that don't have information
tgc = tgc.drop(['vote','style','image'],axis=1)


# fields that aren't relavant
tgc = tgc.drop(['reviewerID','reviewerName','unixReviewTime'],axis=1)


# changing to relevant data types
tgc['reviewTime'] = pd.to_datetime(tgc['reviewTime'])

# %%
print('Toys_and_Games')
print('Shape:',tgc.shape)

print('COLUMN'.ljust(18),'DATATYPE'.ljust(10),'NULL VALUES')
print('--'*20)
for i in tgc.columns:
    nanp = tgc[i].isnull().sum()/len(tgc[i])*100
    print(f'{i:18} {str(tgc[i].dtype):15} {nanp:.2f}%')
# Out:
# Toys_and_Games
# Shape: (1828971, 6)
# COLUMN             DATATYPE   NULL VALUES
# ----------------------------------------
# overall            float64         0.00%
# verified           bool            0.00%
# reviewTime         datetime64[ns]  0.00%
# asin               object          0.00%
# reviewText         object          0.06%
# summary            object          0.02%

# %% [markdown]
# ### Metadata

# %%
# for reusability 
mtgc = mtg.copy() 

display(mtgc.head(3))

print('Meta Toys_and_Games')
print('Shape:',mtgc.shape)

print('COLUMN'.ljust(18),'DATATYPE'.ljust(10),'NULL VALUES')
print('--'*20)
for i in mtgc.columns:
    nanp = mtgc[i].isnull().sum()/len(mtgc[i])*100
    print(f'{i:18} {str(mtgc[i].dtype):10} {nanp:.2f}%')
# Out:
#                                   category tech1  \
# 0  [Toys & Games, Puzzles, Jigsaw Puzzles]
# 1                                       []
# 2                                       []
#
#                                          description fit  \
# 0  [Three Dr. Suess' Puzzles: Green Eggs and Ham,...
# 1  [<b>Prepare to be Afraid!</b><br /><br />The B...
# 2                                                 []
#
#                                             title also_buy tech2  \
# 0  Dr. Suess 19163 Dr. Seuss Puzzle 3 Pack Bundle       []
# 1     Pathfinder: Book of Beasts - Legendary Foes       []
# 2                        Nursery Rhymes Felt Book       []
#
#                                            brand  \
# 0                                      Dr. Seuss
# 1  Pathfinder Roleplaying Jon Brazer Productions
# 2                                   Betty Lukens
#
#                                              feature  \
# 0  [Three giant floor puzzles, Includes: Dr. Sues...
# 1                                                 []
# 2                                                 []
#
#                                                 rank also_view      main_cat  \
# 0  [>#2,230,717 in Toys & Games (See Top 100 in T...        []  Toys & Games
# 1  [>#2,294,535 in Toys & Games (See Top 100 in T...        []  Toys & Games
# 2  [>#2,871,983 in Toys & Games (See Top 100 in T...        []  Toys & Games
#
#   similar_item date                                              price  \
# 0
# 1                    .a-box-inner{background-color:#fff}#alohaBuyBo...
# 2                    .a-box-inner{background-color:#fff}#alohaBuyBo...
#
#          asin                                           imageURL  \
# 0  0000191639  [https://images-na.ssl-images-amazon.com/image...
# 1  0004950763                                                 []
# 2  0005069491                                                 []
#
#                                      imageURLHighRes details
# 0  [https://images-na.ssl-images-amazon.com/image...     NaN
# 1                                                 []     NaN
# 2                                                 []     NaN
# Meta Toys_and_Games
# Shape: (633883, 19)
# COLUMN             DATATYPE   NULL VALUES
# ----------------------------------------
# category           object     0.00%
# tech1              object     0.00%
# description        object     0.00%
# fit                object     0.00%
# title              object     0.00%
# also_buy           object     0.00%
# tech2              object     0.00%
# brand              object     0.00%
# feature            object     0.00%
# rank               object     0.00%
# also_view          object     0.00%
# main_cat           object     0.00%
# similar_item       object     0.00%
# date               object     0.00%
# price              object     0.00%
# asin               object     0.00%
# imageURL           object     0.00%
# imageURLHighRes    object     0.00%
# details            object     0.23%

# %%
def text_to_currency(df,col):
    '''Returns a series of float value
    Parameters: DataFrame df, Field col'''
    
    import re
    import numpy as np
    
    for i in df[col].index:
        item = df[col][i]
        res = re.compile('(\$\d+\.\d+)').findall(item)
        if res:
            df[col][i] = float(re.sub('\$','',res[0]))
        else: 
            df[col][i] = np.nan
            
    return df[col]

# %%
# changing data types
mtgc['price'] = text_to_currency(mtgc,'price')

mtgc['price'] = mtgc['price'].astype(float)

# %%
# dropping blank + irrelavant fields
mtgc.drop(['tech1','description','fit','also_buy','tech2','feature','rank','also_view','similar_item','date',
           'imageURL','imageURLHighRes','details','title'],
          axis=1,inplace=True)

# %%
print('Meta Toys_and_Games')
print('Shape:',mtgc.shape)

print('COLUMN'.ljust(18),'DATATYPE'.ljust(10),'NULL VALUES')
print('--'*20)
for i in mtgc.columns:
    nanp = mtgc[i].isnull().sum()/len(mtgc[i])*100
    print(f'{i:18} {str(mtgc[i].dtype):10} {nanp:.2f}%')
# Out:
# Meta Toys_and_Games
# Shape: (633883, 5)
# COLUMN             DATATYPE   NULL VALUES
# ----------------------------------------
# category           object     0.00%
# brand              object     0.00%
# main_cat           object     0.00%
# price              float64    50.29%
# asin               object     0.00%

# %% [markdown]
# # Data merging
# Merging reviews and product into a single dataset

# %%
data = tgc.merge(mtgc,how='inner',on='asin')

print('Toys_and_Games')
print('Shape:',data.shape)


print('COLUMN'.ljust(18),'DATATYPE'.ljust(15),'NULL VALUES')
print('--'*20)
for i in data.columns:
    nanp = data[i].isnull().sum()/len(data[i])*100
    print(f'{i:18} {str(data[i].dtype):15} {nanp:.2f}%')
# Out:
# Toys_and_Games
# Shape: (1884953, 10)
# COLUMN             DATATYPE        NULL VALUES
# ----------------------------------------
# overall            float64         0.00%
# verified           bool            0.00%
# reviewTime         datetime64[ns]  0.00%
# asin               object          0.00%
# reviewText         object          0.06%
# summary            object          0.02%
# category           object          0.00%
# brand              object          0.00%
# main_cat           object          0.00%
# price              float64         26.12%

# %%
# deleting the records containing missing values
# since the products not having price don't have and details for appropriate mean/median imputation  
# and imputation of category/brand wise means data manipulation and might/not condratict the actual data
data = data.dropna(axis=0)


# picking out only the necessary category for the 
data = data[data.main_cat=='Toys & Games'].drop('main_cat',axis=1)


# resetting the index afer dropping 
data = data.reset_index()
data = data.drop(['index'],axis = 1)

# %%
print('Toys_and_Games')
print('Shape:',data.shape)


print('COLUMN'.ljust(18),'DATATYPE'.ljust(15),'NULL VALUES')
print('--'*20)
for i in data.columns:
    nanp = data[i].isnull().sum()/len(data[i])*100
    print(f'{i:18} {str(data[i].dtype):15} {nanp:.2f}%')
# Out:
# Toys_and_Games
# Shape: (1280016, 9)
# COLUMN             DATATYPE        NULL VALUES
# ----------------------------------------
# overall            float64         0.00%
# verified           bool            0.00%
# reviewTime         datetime64[ns]  0.00%
# asin               object          0.00%
# reviewText         object          0.00%
# summary            object          0.00%
# category           object          0.00%
# brand              object          0.00%
# price              float64         0.00%

# %%
# for reusability
df = data.copy()

df['category'] = df['category'].astype(str)


print('Cleaned data')
print('Shape:',df.shape)


print('COLUMN'.ljust(18),'DATATYPE'.ljust(15),'NULL VALUES')
print('--'*20)
for i in df.columns:
    nanp = df[i].isnull().sum()/len(df[i])*100
    print(f'{i:18} {str(df[i].dtype):15} {nanp:.2f}%')
# Out:
# Cleaned data
# Shape: (1280016, 9)
# COLUMN             DATATYPE        NULL VALUES
# ----------------------------------------
# overall            float64         0.00%
# verified           bool            0.00%
# reviewTime         datetime64[ns]  0.00%
# asin               object          0.00%
# reviewText         object          0.00%
# summary            object          0.00%
# category           object          0.00%
# brand              object          0.00%
# price              float64         0.00%

# %% [markdown]
# # Data exploration

# %%
print(df['category'].nunique())
df['category'].unique()
# Out:
# 718
# array(["['Toys & Games', 'Arts & Crafts', 'Craft Kits']",
#        "['Toys & Games', 'Games', 'Card Games']",
#        "['Toys & Games', 'Stuffed Animals & Plush Toys', 'Plush Figures']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Nesting Dolls']", '[]',
#        "['Toys & Games', 'Puzzles', 'Floor Puzzles']",
#        "['Toys & Games', 'Puzzles', 'Jigsaw Puzzles']",
#        "['Toys & Games', 'Learning & Education']",
#        "['Toys & Games', 'Games', 'Board Games']",
#        "['Toys & Games', 'Arts & Crafts', 'Stickers']",
#        "['Toys & Games', 'Dolls & Accessories', 'Dolls']",
#        "['Toys & Games', 'Puzzles', 'Brain Teasers']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Money Banks']",
#        "['Toys & Games', 'Games', 'Game Accessories']",
#        "['Toys & Games', 'Learning & Education', 'Musical Instruments', 'Accessories']",
#        "['Toys & Games', 'Baby & Toddler Toys']",
#        "['Toys & Games', 'Stuffed Animals & Plush Toys']",
#        "['Toys & Games', 'Games']",
#        "['Toys & Games', 'Arts & Crafts', 'Drawing & Painting Supplies', 'Pencil Erasers']",
#        "['Toys & Games', 'Learning & Education', 'Mathematics & Counting']",
#        "['Toys & Games', 'Arts & Crafts', 'Drawing & Painting Supplies', 'Drawing & Sketch Pads']",
#        "['Toys & Games', 'Games', 'Standard Playing Card Decks']",
#        "['Toys & Games', 'Stuffed Animals & Plush Toys', 'Stuffed Animals & Teddy Bears']",
#        "['Toys & Games', 'Puppets', 'Finger Puppets']",
#        '[\'Toys & Games\', "Kids\' Electronics", \'Electronic Learning Toys\']',
#        "['Toys & Games', 'Arts & Crafts', 'Craft Kits', 'Jewelry']",
#        "['Toys & Games', 'Grown-Up Toys', 'Action & Toy Figures']",
#        "['Toys & Games', 'Action Figures & Statues', 'Accessories']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play', 'Magnetic & Felt Playboards']",
#        "['Toys & Games', 'Action Figures & Statues', 'Action Figures']",
#        "['Toys & Games', 'Games', 'Game Room Games', 'Mini Table Games']",
#        "['Toys & Games', 'Games', 'Tile Games']",
#        "['Toys & Games', 'Learning & Education', 'Science', 'Microscopes']",
#        "['Toys & Games', 'Learning & Education', 'Science', 'Anatomy']",
#        "['Toys & Games', 'Learning & Education', 'Basic & Life Skills Toys']",
#        "['Toys & Games', 'Puzzles']",
#        "['Toys & Games', 'Games', 'DVD Games']",
#        "['Toys & Games', 'Hobbies', 'Models & Model Kits', 'Pre-Built & Diecast Models', 'Airplanes & Jets']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicles', 'Helicopters']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicles']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicles', 'Trucks']",
#        '[\'Toys & Games\', "Kids\' Furniture, Dcor & Storage", \'Backpacks & Lunch Boxes\', \'Lunch Boxes\']',
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play', 'Grocery Shopping', 'Cash Registers']",
#        "['Toys & Games', 'Learning & Education', 'Science', 'Geology & Earth Sciences']",
#        "['Toys & Games', 'Building Toys', 'Gear Sets']",
#        "['Toys & Games', 'Building Toys', 'Stacking Blocks']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Toy Balls']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Juggling Sets']",
#        "['Toys & Games', 'Baby & Toddler Toys', 'Bath Toys']",
#        "['Toys & Games', 'Toy Remote Control & Play Vehicles', 'Play Trains & Railway Sets', 'Accessories', 'Train Tracks']",
#        "['Toys & Games', 'Toy Remote Control & Play Vehicles', 'Play Trains & Railway Sets', 'Train Sets']",
#        "['Toys & Games', 'Learning & Education', 'Science', 'Physics']",
#        "['Toys & Games', 'Dolls & Accessories', 'Dollhouse Accessories', 'Furniture']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Bean Bags & Footbags']",
#        "['Toys & Games', 'Learning & Education', 'Science', 'Biology']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Play Tents & Tunnels']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play', 'Kitchen Toys', 'Play Food']",
#        "['Toys & Games', 'Building Toys', 'Building Sets']",
#        "['Toys & Games', 'Arts & Crafts', 'Craft Kits', 'Sewing']",
#        "['Toys & Games', 'Toy Remote Control & Play Vehicles', 'Play Vehicles']",
#        "['Toys & Games', 'Puzzles', 'Pegged Puzzles']",
#        "['Toys & Games', 'Learning & Education', 'Science', 'Electronics']",
#        "['Toys & Games', 'Action Figures & Statues', 'Playsets & Vehicles', 'Playsets']",
#        "['Toys & Games', 'Tricycles, Scooters & Wagons', 'Pull-Along Wagons']",
#        "['Toys & Games', 'Games', 'Travel Games']",
#        "['Toys & Games', 'Arts & Crafts', 'Clay & Dough']",
#        "['Toys & Games', 'Baby & Toddler Toys', 'Rattles']",
#        "['Toys & Games', 'Baby & Toddler Toys', 'Music & Sound']",
#        "['Toys & Games', 'Learning & Education', 'Early Development Toys', 'Shapes & Colors']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Sports', 'Toy Sports', 'Toy Basketball']",
#        "['Toys & Games', 'Learning & Education', 'Science', 'Magnetic Science']",
#        "['Toys & Games', 'Grown-Up Toys']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Wind-up Toys']",
#        "['Toys & Games', 'Baby & Toddler Toys', 'Stacking & Nesting Toys']",
#        "['Toys & Games', 'Toy Remote Control & Play Vehicles', 'Play Trains & Railway Sets', 'Train Cars']",
#        "['Toys & Games', 'Arts & Crafts', 'Molding & Sculpting Sticks']",
#        "['Toys & Games', 'Arts & Crafts', 'Drawing & Sketching Tablets']",
#        "['Toys & Games', 'Dolls & Accessories', 'Doll Accessories']",
#        "['Toys & Games', 'Building Toys']",
#        "['Toys & Games', 'Building Toys', 'Marble Runs']",
#        "['Toys & Games', 'Learning & Education', 'Reading & Writing']",
#        "['Toys & Games', 'Games', 'Trading Card Games', 'Single Cards']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Prisms & Kaleidoscopes']",
#        "['Toys & Games', 'Puppets', 'Hand Puppets']",
#        "['Toys & Games', 'Stuffed Animals & Plush Toys', 'Plush Puppets']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Blasters & Foam Play']",
#        "['Toys & Games', 'Learning & Education', 'Musical Instruments', 'Wind & Brass']",
#        "['Toys & Games', 'Learning & Education', 'Science']",
#        "['Toys & Games', 'Arts & Crafts', 'Craft Kits', 'Tie-Dye & Fashion']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play']",
#        "['Toys & Games', 'Games', 'Stacking Games']",
#        "['Toys & Games', 'Learning & Education', 'Early Development Toys', 'Activity Centers']",
#        "['Toys & Games', 'Tricycles, Scooters & Wagons', 'Ride-On Toys']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Pools & Water Fun', 'Pool Rafts & Inflatable Ride-ons']",
#        '[\'Toys & Games\', \'Party Supplies\', \'Party Hats\', \'38.1 centimeters high\', \'20.32 centimeters wide\', \'Fabric lining, secret pocket with fortune\', \'Velcro size adjuster\', \'Kids\\\' size, ages 3-12, fits 5556 cm heads 21.75"\', \'Velvet, satin\']',
#        "['Toys & Games', 'Toy Remote Control & Play Vehicles', 'Toy RC Vehicles & Batteries', 'Toy RC Vehicles']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play', 'Kitchen Toys', 'Dishes & Tea Sets']",
#        "['Toys & Games', 'Learning & Education', 'Musical Instruments', 'Pianos & Keyboards']",
#        "['Toys & Games', 'Grown-Up Toys', 'Puzzles']",
#        '[\'Toys & Games\', "Kids\' Furniture, Dcor & Storage"]',
#        "['Toys & Games', 'Baby & Toddler Toys', 'Push & Pull Toys']",
#        "['Toys & Games', 'Toy Remote Control & Play Vehicles', 'Toy RC Vehicles & Batteries', 'Battery Packs & Chargers']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Flying Toys', 'Toy Parachute Figures']",
#        "['Toys & Games', 'Arts & Crafts', 'Aprons & Smocks']",
#        '[\'Toys & Games\', \'Novelty & Gag Toys\', \'Light-Up Toys\', \'Plastic\', \'2.25" high\', \'5" wide\', \'Fun costumes for kids and adults\', "Whether it\'s for Halloween, a themed party, or even for giggles", \'Beautiful colors, hand-wash needed, excellent for dress up\']',
#        "['Toys & Games', 'Arts & Crafts', 'Drawing & Painting Supplies']",
#        "['Toys & Games', 'Toy Remote Control & Play Vehicles', 'Die-Cast Vehicles']",
#        "['Toys & Games', 'Arts & Crafts', 'Drawing & Painting Supplies', 'Colored Pencils']",
#        "['Toys & Games', 'Arts & Crafts']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play', 'Construction Tools']",
#        "['Toys & Games', 'Arts & Crafts', 'Drawing & Painting Supplies', 'Coloring Pens & Markers']",
#        "['Toys & Games', 'Hobbies', 'Models & Model Kits', 'Model Kits', 'Architecture Kits']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Magnets & Magnetic Toys']",
#        "['Toys & Games', 'Learning & Education', 'Reading & Writing', 'Magnetic Letters & Words']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Pools & Water Fun']",
#        "['Toys & Games', 'Games', 'Floor Games']",
#        "['Toys & Games', 'Toy Remote Control & Play Vehicles', 'Vehicle Playsets']",
#        '[\'Toys & Games\', "Kids\' Electronics", \'Systems & Accessories\', \'Electronic System Accessories\']',
#        "['Toys & Games', 'Sports & Outdoor Play', 'Pogo Sticks & Hoppers', 'Hoppers']",
#        "['Toys & Games', 'Dolls & Accessories', 'Dollhouse Accessories']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Pools & Water Fun', 'Basketball & Volleyball Sets']",
#        "['Toys & Games', 'Arts & Crafts', 'Drawing & Painting Supplies', 'Paints', 'Tempera & Poster Paint']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Gardening Tools']",
#        "['Toys & Games', 'Toy Remote Control & Play Vehicles', 'Pull Back Vehicles']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Slime & Putty Toys']",
#        "['Toys & Games', 'Games', 'Trading Card Games', 'Counters, Playmats & Gameplay Accessories', 'Playmats']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Yo-yos']",
#        "['Toys & Games', 'Hobbies', 'Models & Model Kits', 'Model Kits', 'Helicopter Kits']",
#        "['Toys & Games', 'Party Supplies']",
#        "['Toys & Games', 'Action Figures & Statues']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play', 'Housekeeping']",
#        "['Toys & Games', 'Arts & Crafts', 'Printing & Stamping']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Pools & Water Fun', 'Kiddie Pools']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Pools & Water Fun', 'Pool Loungers']",
#        "['Toys & Games', 'Learning & Education', 'Musical Instruments', 'Drums & Percussion']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play', 'Kitchen Toys', 'Kitchen Playsets']",
#        '[\'Toys & Games\', "Kids\' Electronics", \'Plug & Play Video Games\']',
#        "['Toys & Games', 'Baby & Toddler Toys', 'Blocks']",
#        "['Toys & Games', 'Games', 'Game Collections']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Ball Pits & Accessories']",
#        "['Toys & Games', 'Dolls & Accessories', 'Dollhouses']",
#        "['Toys & Games', 'Dolls & Accessories', 'Playsets']",
#        "['Toys & Games', 'Learning & Education', 'Early Development Toys', 'Sorting & Stacking']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Play Sets & Playground Equipment', 'Play Set Attachments', 'Swings']",
#        '[\'Toys & Games\', "Kids\' Electronics", \'Systems & Accessories\', \'Electronic Software & Books\']',
#        "['Toys & Games', 'Arts & Crafts', 'Drawing & Painting Supplies', 'Pastels']",
#        "['Toys & Games', 'Arts & Crafts', 'Drawing & Painting Supplies', 'Crayons']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Sports', 'Toy Sports', 'Toy Football']",
#        "['Toys & Games', 'Party Supplies', 'Piatas']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Light-Up Toys']",
#        "['Toys & Games', 'Games', 'Handheld Games']",
#        "['Toys & Games', 'Learning & Education', 'Musical Instruments']",
#        "['Toys & Games', 'Party Supplies', 'Party Games & Crafts']",
#        "['Toys & Games', 'Learning & Education', 'Science', 'Chemistry']",
#        "['Toys & Games', 'Dolls & Accessories', 'Doll Accessories', 'Furniture']",
#        "['Toys & Games', 'Novelty & Gag Toys']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Sports']",
#        "['Toys & Games', 'Dolls & Accessories']",
#        "['Toys & Games', 'Action Figures & Statues', 'Playsets & Vehicles', 'Vehicles']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Sandboxes & Accessories']",
#        '[\'Toys & Games\', \'Action Figures & Statues\', \'Playsets & Vehicles\', \'Playsets\', \'17" high\', \'2.5" wide\', \'Includes holster\', \'Includes blaster\', \'One size fits most adults and big kids\', \'Officially licensed Star Wars costume\', \'Rubies makes dress-up fun for all ages\']',
#        "['Toys & Games', 'Hobbies', 'Models & Model Kits', 'Model Kits', 'Ships & Submarine Kits']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Sports', 'Toy Sports', 'Toy Soccer']",
#        "['Toys & Games', 'Hobbies', 'Trains & Accessories', 'Train Sets']",
#        "['Toys & Games', 'Hobbies', 'Trains & Accessories', 'Accessories', 'Train Signals, Signs & Lights']",
#        "['Toys & Games', 'Hobbies', 'Trains & Accessories', 'Accessories', 'Tracks']",
#        "['Toys & Games', 'Hobbies', 'Hobby Building Tools & Hardware', 'Adhesives']",
#        "['Toys & Games', 'Hobbies', 'Models & Model Kits', 'Model Kits', 'Airplane & Jet Kits']",
#        "['Toys & Games', 'Grown-Up Toys', 'Die-Cast & Toy Vehicles']",
#        "['Toys & Games', 'Hobbies', 'Hobby Building Tools & Hardware', 'Paints']",
#        "['Toys & Games', 'Hobbies']",
#        "['Toys & Games', 'Toy Remote Control & Play Vehicles']",
#        "['Toys & Games', 'Hobbies', 'Trains & Accessories', 'Train Cars', 'Locomotives']",
#        "['Toys & Games', 'Hobbies', 'Trains & Accessories', 'Accessories', 'Buildings & Structures']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Bubbles']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Spy Gadgets']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play', 'Money & Banking']",
#        "['Toys & Games', 'Arts & Crafts', 'Craft Kits', 'Scrapbooking']",
#        "['Toys & Games', 'Baby & Toddler Toys', 'Activity Play Centers']",
#        '[\'Toys & Games\', "Kids\' Electronics"]',
#        "['Toys & Games', 'Baby & Toddler Toys', 'Hammering & Pounding Toys']",
#        '[\'Toys & Games\', "Kids\' Electronics", \'Systems & Accessories\']',
#        "['Toys & Games', 'Novelty & Gag Toys', 'Magic Kits & Accessories']",
#        "['Toys & Games', 'Baby & Toddler Toys', 'Rocking & Spring Ride-Ons']",
#        "['Toys & Games', 'Learning & Education', 'Science', 'Botany']",
#        "['Toys & Games', 'Puzzles', 'Brain Teasers', 'Puzzle Boxes']",
#        "['Toys & Games', 'Dolls & Accessories', 'Doll Accessories', 'Strollers']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Marble Games']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Play Sets & Playground Equipment']",
#        "['Toys & Games', 'Grown-Up Toys', 'Games']",
#        "['Toys & Games', 'Hobbies', 'Slot Cars, Race Tracks & Accessories', 'Race Tracks']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Playhouses']",
#        "['Toys & Games', 'Hobbies', 'Slot Cars, Race Tracks & Accessories', 'Slot Car Parts & Chassis']",
#        "['Toys & Games', 'Hobbies', 'Hobby Building Tools & Hardware', 'Magnifying Tools']",
#        "['Toys & Games', 'Baby & Toddler Toys', 'Balls']",
#        '[\'Toys & Games\', "Kids\' Electronics", \'Music Players & Karaoke\']',
#        "['Toys & Games', 'Puzzles', 'Brain Teasers', 'Maze & Sequential Puzzles']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Pools & Water Fun', 'Water Balloons']",
#        "['Toys & Games', 'Hobbies', 'Models & Model Kits', 'Model Kits', 'Figure Kits']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Play Sets & Playground Equipment', 'Play Set Attachments']",
#        "['Toys & Games', 'Party Supplies', 'Balloons']",
#        "['Toys & Games', 'Hobbies', 'Models & Model Kits', 'Pre-Built & Diecast Models', 'Figures']",
#        "['Toys & Games', 'Hobbies', 'Models & Model Kits', 'Model Kits', 'Tanks & Artillery Kits']",
#        "['Toys & Games', 'Hobbies', 'Models & Model Kits']",
#        "['Toys & Games', 'Hobbies', 'Models & Model Kits', 'Model Kits']",
#        "['Toys & Games', 'Hobbies', 'Models & Model Kits', 'Model Kits', 'Car & Truck Kits']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Gag Toys & Practical Jokes']",
#        "['Toys & Games', 'Grown-Up Toys', 'Novelty & Gag Toys']",
#        "['Toys & Games', 'Hobbies', 'Rockets', 'Model Rocket Kits']",
#        '[\'Toys & Games\', "Kids\' Electronics", \'Remote- & App-Controlled Figures & Robots\']',
#        "['Toys & Games', 'Party Supplies', 'Rubies Lord of The Rings Arwen Costume Evenstar Costume', 'Officially licensed silver colored necklace', 'Inspired by jewelry worn in the Lord of the Rings movie trilogy']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Power Plant & Driveline Systems', 'Brakes']",
#        "['Toys & Games', 'Hobbies', 'Rockets', 'Rocket Accessories']",
#        "['Toys & Games', 'Hobbies', 'Trains & Accessories', 'Control & Power Supplies']",
#        "['Toys & Games', 'Learning & Education', 'Geography']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Servos & Parts', 'Servos']",
#        "['Toys & Games', 'Hobbies', 'Rockets', 'Model Rockets']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Fuel']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Radios & Parts', 'Radio Antennae']",
#        "['Toys & Games', 'Hobbies', 'Hobby Building Tools & Hardware', 'RC Linkages']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Vehicle Bodies & Scale Accessories']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Wheels & Tires', 'Tire & Wheel Sets']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Power Plant & Driveline Systems', 'Drive Pulleys']",
#        "['Toys & Games', 'Hobbies', 'Hobby Building Tools & Hardware']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Wheels & Tires', 'Wheels']",
#        "['Toys & Games', 'Hobbies', 'Trains & Accessories', 'Accessories', 'Couplers & Trucks']",
#        "['Toys & Games', 'Learning & Education', 'Science', 'Telescopes']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Sports', 'Toy Sports']",
#        "['Toys & Games', 'Puzzles', 'Brain Teasers', 'Assembly & Disentanglement Puzzles']",
#        "['Toys & Games', 'Arts & Crafts', 'Beads']",
#        "['Toys & Games', 'Sports & Outdoor Play']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes']",
#        "['Toys & Games', 'Hobbies', 'Coin Collecting']",
#        "['Toys & Games', 'Games', 'Trading Card Games', 'Albums, Cases & Sleeves', 'Protective Sleeves']",
#        "['Toys & Games', 'Arts & Crafts', 'Drawing & Painting Supplies', 'Paints', 'Finger Paint']",
#        "['Toys & Games', 'Toy Remote Control & Play Vehicles', 'Play Trains & Railway Sets', 'Accessories', 'Buildings & Scenery']",
#        "['Toys & Games', 'Learning & Education', 'Flash Cards']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Pools & Water Fun', 'Beach Balls']",
#        "['Toys & Games', 'Learning & Education', 'Science', 'Robotics']",
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Accessories\', \'Polyester\', \'Imported\', \'1" high\', \'6" wide\', \'Costume sound effect creating accessory\', \'Star Wars is officially licensed by Lucasfilms\', \'Produces the distinctive heavy breathing sound from the original movie\']',
#        "['Toys & Games', 'Novelty & Gag Toys', 'Flying Toys', 'Toy Parachute Figures', 'Made with top quality materials', 'Not suitable for ages below 3 years']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Accessories']",
#        "['Toys & Games', 'Hobbies', 'Trains & Accessories', 'Accessories', 'Bridges & Tunnels', 'Bridges']",
#        "['Toys & Games', 'Arts & Crafts', 'Craft Kits', 'Paper Craft']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Pools & Water Fun', 'Beach Toys']",
#        '[\'Toys & Games\', "Kids\' Furniture, Dcor & Storage", \'Outdoor Furniture\', \'Picnic Tables\']',
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play', 'Kitchen Toys']",
#        "['Toys & Games', 'Stuffed Animals & Plush Toys', 'Stuffed Animals & Teddy Bears', 'fabric', 'Hand-crafted horse head, comes with bridle and reins', 'Squeeze the ear to hear the stick horse neigh and gallop', 'Sturdy wooden stick', 'AA Batteries Not Included', '3+ years']",
#        "['Toys & Games', 'Games', 'Dice & Gaming Dice']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Remote & App Controlled Vehicle Batteries']",
#        "['Toys & Games', 'Arts & Crafts', 'Drawing & Painting Supplies', 'Chalk']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Novelty Games']",
#        "['Toys & Games', 'Arts & Crafts', 'Drawing & Painting Supplies', 'Paintbrushes']",
#        "['Toys & Games', 'Puppets']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Wheels & Tires', 'Aircraft Landing Gear']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Wheels & Tires', 'Wheel Hubs']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Power Plant & Driveline Systems', 'Axles']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Flying Toys', 'Airplane Construction Kits']",
#        "['Toys & Games', 'Baby & Toddler Toys', 'Stick Horses']",
#        "['Toys & Games', 'Games', 'Game Room Games', 'Darts']",
#        '[\'Toys & Games\', "Kids\' Electronics", \'Electronic Pets\']',
#        "['Toys & Games', 'Party Supplies', 'Party Favors']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Wheels & Tires']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Flying Toys']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Fitness Equipment']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Power Plant & Driveline Systems', 'Rotor Shafts']",
#        "['Toys & Games', 'Dolls & Accessories', 'Doll Accessories', 'Clothing & Shoes']",
#        "['Toys & Games', 'Learning & Education', 'Science', 'Archaeology & Paleontology']",
#        '[\'Toys & Games\', "Kids\' Electronics", \'Cameras & Camcorders\']',
#        "['Toys & Games', 'Arts & Crafts', 'Easels']",
#        '[\'Toys & Games\', "Kids\' Electronics", \'Dance Mats\']',
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play', 'Kitchen Toys', 'Cooking & Baking Kits']",
#        "['Toys & Games', 'Baby & Toddler Toys', 'Teaching Clocks']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Pools & Water Fun', 'Sprinklers']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Pools & Water Fun', 'Baby Floats']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Beauty & Fashion', 'Purses']",
#        "['Toys & Games', 'Puzzles', 'Puzzle Accessories']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', 'Polyester', 'Imported', 'White', 'Includes: mask and jumpsuit with boot covers', 'This is an officially licensed Star Wars costume', 'Small: 4-6', 'Medium: 8-10']",
#        "['Toys & Games', 'Action Figures & Statues', 'Playsets & Vehicles']",
#        "['Toys & Games', 'Baby & Toddler Toys', 'Toy Gift Sets']",
#        "['Toys & Games', 'Learning & Education', 'Solar']",
#        "['Toys & Games', 'Arts & Crafts', 'Craft Kits', 'Waterpainting Kits']",
#        "['Toys & Games', 'Arts & Crafts', 'Blackboards & Whiteboards']",
#        "['Toys & Games', 'Games', 'Game Room Games', 'Indoor Bowling']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', 'Hand washable.', 'Soft soled shoes and pants NOT included.']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Beauty & Fashion', 'Costume fairy wings', 'Features 6 gossamer panels in pale purple', 'Fabulous accessory for fairy or angel costumes, pony play time or fun photos', 'One size fits most', 'From toddler size to plus adult, complete costume or accessories, Rubies has been making your parties more fun since 1950']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Pools & Water Fun', 'Pool Toys', 'Swim Rings']",
#        "['Toys & Games', 'Party Supplies', 'Noisemakers']",
#        "['Toys & Games', 'Stuffed Animals & Plush Toys', 'Plush Interactive Toys']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Beauty & Fashion', 'Necklaces', 'Plastic', 'One (1) per pack.', 'Manufacturer Minimum Age - 4 Years']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play', 'Medical Kits']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Wigs', 'Includes Wig']",
#        "['Toys & Games', 'Games', 'Trading Card Games']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Play Sets & Playground Equipment', 'Parts & Hardware']",
#        '[\'Toys & Games\', "Kids\' Electronics", \'Music Players & Karaoke\', \'MP3 Players\']',
#        "['Toys & Games', 'Learning & Education', 'Reading & Writing', 'Diaries, Journals & Notebooks']",
#        "['Toys & Games', 'Baby & Toddler Toys', 'Car Seat & Stroller Toys']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Viewfinders']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play', 'Kitchen Toys', 'Real-Food Appliances']",
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Hats\', \'Includes cap with elastic back, propeller.\', \'This Tweedledee Twill is an officially licensed Alice In Wonderland costume accessory.\', "Please note: This item\'s color may vary due to inherent manufacturing variations or your computer monitor\'s color settings. The item you receive will be identical or substantially similar to the item pictured in this listing.", \'elope, Inc.\', \'Spot clean air dry only\', \'Costumes\']',
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Wigs\', \'Synthetic Acrylic Hair\', \'Made in USA or Imported\', \'1.5" high\', \'7.5" wide\', \'Give every little girl Dorothy hair\', \'Brown with braids\', \'One size fits most children\']',
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play', 'Paper & Magnetic Dolls', 'Magnetic Dress-up Dolls']",
#        "['Toys & Games', 'Learning & Education', 'Musical Instruments', 'Guitars & Strings']",
#        "['Toys & Games', 'Baby & Toddler Toys', 'Indoor Climbers & Play Structures']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicles', 'Ships & Submarines']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Play Sets & Playground Equipment', 'Play Set Attachments', 'Ring & Trapeze Attachments']",
#        "['Toys & Games', 'Games', 'Game Accessories', 'Game Pieces']",
#        "['Toys & Games', 'Puzzles', '3-D Puzzles']",
#        "['Toys & Games', 'Tricycles, Scooters & Wagons', 'Pedal Cars']",
#        "['Toys & Games', 'Games', 'Game Room Games', 'Pinball']",
#        "['Toys & Games', 'Hobbies', 'Models & Model Kits', 'Pre-Built & Diecast Models']",
#        "['Toys & Games', 'Arts & Crafts', 'Craft Kits', 'Wood']",
#        "['Toys & Games', 'Hobbies', 'Trains & Accessories', 'Accessories', 'Scenery']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Kites & Wind Spinners', 'Kites']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Kites & Wind Spinners']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Finger Boards & Finger Bikes']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Kites & Wind Spinners', 'Kite Accessories']",
#        "['Toys & Games', 'Learning & Education', 'Science', 'Mechanics']",
#        "['Toys & Games', 'Games', 'Trading Card Games', 'Lots']",
#        "['Toys & Games', 'Hobbies', 'Hobby Building Tools & Hardware', 'RC Turnbuckles & Pro-Links']",
#        "['Toys & Games', 'Games', 'Trading Card Games', 'Albums, Cases & Sleeves', 'Cases']",
#        "['Toys & Games', 'Games', 'Game Accessories', 'Role Playing Dice']",
#        "['Toys & Games', 'Hobbies', 'Cases & Stands', 'Display Stands']",
#        "['Toys & Games', 'Baby & Toddler Toys', 'Spinning Tops']",
#        "['Toys & Games', 'Arts & Crafts', 'Drawing & Painting Supplies', 'Paints', 'Watercolor Paint']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Sports', 'Toy Sports', 'Toy Golf']",
#        "['Toys & Games', 'Hobbies', 'Trains & Accessories']",
#        "['Toys & Games', 'Party Supplies', 'Tablecovers']",
#        "['Toys & Games', 'Hobbies', 'Hobby Building Tools & Hardware', 'Painting Tools']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', '100% Woven poly poplin, washable', 'Does not include Hat And Sword']",
#        "['Toys & Games', 'Action Figures & Statues', 'Action Figures', 'This is a necklace with a replica Save Crystal pendant from the Final Fantasy game series!', 'The blue pendant is about 2-inches long. It is wrapped in a silver-color frame for added style. The chain is approx 19-inches.', 'This is a great item to wear and show support from the Final Fantasy series!']",
#        "['Toys & Games', 'Arts & Crafts', 'Craft Kits', 'Scratch Art']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Pools & Water Fun', 'Pool Toys', 'Inflatable Water Slides']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Wheels & Tires', 'Accessories']",
#        "['Toys & Games', 'Puppets', 'Puppet Theaters']",
#        "['Toys & Games', 'Dress Up & Pretend Play']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicles', 'Cars']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Sports', 'Baseball & Softball', 'Batting Gloves']",
#        "['Toys & Games', 'Party Supplies', 'Party Hats']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Pools & Water Fun', 'Pool Toys']",
#        "['Toys & Games', 'Party Supplies', 'Party Tableware', 'Cups']",
#        "['Toys & Games', 'Action Figures & Statues', 'Statues & Bobbleheads', 'Bobbleheads']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', 'Polyester.', 'Includes: A Dress, Cape, Belt, Glovelets, Mask And Boot Tops.']",
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Accessories\', \'Fun costumes for kids and adults\', "Whether it\'s for Halloween, a themed party, or even for giggles", \'Beautiful colors, hand-wash needed, excellent for dress up\']',
#        "['Toys & Games', 'Hobbies', 'Cases & Stands', 'Display Cases']",
#        "['Toys & Games', 'Games', 'Trading Card Games', 'Booster Packs']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Temporary Tattoos']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Nature Exploration Toys']",
#        "['Toys & Games', 'Arts & Crafts', 'Craft Kits', 'Paint-By-Number Kits']",
#        "['Toys & Games', 'Action Figures & Statues', 'Statues & Bobbleheads', 'Statues']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Beauty & Fashion', 'Bracelets']",
#        "['Toys & Games', 'Games', 'Trading Card Games', 'Decks & Sets']",
#        "['Toys & Games', 'Hobbies', 'Slot Cars, Race Tracks & Accessories', 'Slot Cars']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play', 'Plastic', 'Silver rings that slide over nose or lip to look like piercings.Silver color.', 'Manufacturer minimum age: 48 Months']",
#        "['Toys & Games', 'Hobbies', 'Trains & Accessories', 'Accessories', 'Figures']",
#        "['Toys & Games', 'Hobbies', 'Trains & Accessories', 'Accessories']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', '100% Polyester', 'Hand wash. Line Dry. Cold water. No bleach.', 'Includes: Jumpsuit, Cap. Does Not Include Shoes.']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Hats']",
#        "['Toys & Games', 'Hobbies', 'Hobby Building Tools & Hardware', 'Hobby Tool Sets']",
#        '[\'Toys & Games\', "Kids\' Electronics", \'Walkie Talkies\']',
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', '100% acrylic', 'Tiger Costume for Children.', 'Four sizes. 4-6, 6-8, 8-10 and 10-12 Years.', 'Costume includes jumpsuit with tail , mittens and hood.', 'Machine washable. 100% Acrylic.', 'Conforms to European & North American safety regulations. As a precaution keep away from fire. For more information view the product details below.']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Vehicle Bodies & Scale Accessories', 'Wings']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Servos & Parts', 'Servo Gears']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Inflatable Bouncers']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Pools & Water Fun', 'Water Guns, Blasters & Soakers']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play', 'Grocery Shopping', 'Shopping Carts']",
#        "['Toys & Games', 'Party Supplies', 'Party Packs']",
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Accessories\', \'Polyester\', \'0.5" high\', \'4" wide\', \'100% polyester\', \'Gryffindor colors of purple and yellow\', \'One size fits most\', \'Accessories make the costume\', \'Officially Licensed Harry Potter accessory\']',
#        "['Toys & Games', 'Novelty & Gag Toys', 'Finger Boards & Finger Bikes', 'Skateboards']",
#        "['Toys & Games', 'Puppets', 'Ventriloquist']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Play Sets & Playground Equipment', 'Freestanding Climbers']",
#        "['Toys & Games', 'Stuffed Animals & Plush Toys', 'Stuffed Animal Clothing & Accessories']",
#        "['Toys & Games', 'Hobbies', 'Stamp Collecting']",
#        "['Toys & Games', 'Arts & Crafts', 'Craft Kits', 'Sand Art']",
#        "['Toys & Games', 'Party Supplies', 'Banners, Streamers & Confetti', 'Banners']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Miniatures']",
#        "['Toys & Games', 'Action Figures & Statues', 'Statues & Bobbleheads']",
#        "['Toys & Games', 'Hobbies', 'Models & Model Kits', 'Pre-Built & Diecast Models', 'Spacecraft']",
#        "['Toys & Games', 'Games', 'Battling Tops']",
#        '[\'Toys & Games\', "Kids\' Electronics", \'Systems & Accessories\', \'Electronic Systems\']',
#        "['Toys & Games', 'Tricycles, Scooters & Wagons', 'Electric Vehicles']",
#        "['Toys & Games', 'Toy Remote Control & Play Vehicles', 'Play Trains & Railway Sets', 'Accessories']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Pools & Water Fun', 'Lawn Water Slides']",
#        "['Toys & Games', 'Party Supplies', 'Cake & Cupcake Toppers', 'Cake Toppers']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Accessories', 'Polyester Fibers', 'Opening between mustache and beard for mouth']",
#        "['Toys & Games', 'Party Supplies', 'Banners, Streamers & Confetti', 'Streamers']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', '100% acrylic', 'White Bunny Rabbit Costume for Kids.', 'Four sizes to fit children aged 4-6, 6-8, 8-10 and 10-12 years.', 'Costume includes jump suit with pink bob tail, attached hood, mittens and a carrot.', 'Machine washable. 100% Acrylic.', 'Conforms to European & North American safety regulations. As a precaution keep away from fire. For more information view the product details below.']",
#        "['Toys & Games', 'Toy Remote Control & Play Vehicles', 'Toy RC Vehicles & Batteries']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Radios & Parts']",
#        "['Toys & Games', 'Toy Remote Control & Play Vehicles', 'Play Trains & Railway Sets', 'Train Sets', 'wood', 'Imported', 'Complete wooden train set with swiveling river bridge', '47-piece set includes swivel bridge, 3 train cars, tunnel, 34 track pieces and accessories.', 'Bridge automatically activates traffic gates.', 'Compatible with popular wooden railway systems', 'Great for hand-eye coordination, problem solving skills and imaginative play']",
#        '[\'Toys & Games\', "Kids\' Furniture, Dcor & Storage", \'Outdoor Furniture\', \'Table & Chair Sets\']',
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', 'Polyester, Exclusive of Decoration, Fiber Optics', 'Includes: Dress With Twinkle Shirt And Hat']",
#        "['Toys & Games', 'Arts & Crafts', 'Drawing & Painting Supplies', 'Paints']",
#        "['Toys & Games', 'Puzzles', 'Sudoku Puzzles']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', 'Polyester', 'Gentle Machine Washable ~ Flame Retardant  Set packaged in durable snap-sealed poly bag', 'Product comes complete with: jacket, pants, hood.', 'Set packaged in a deluxe garment bag closes with zipper for easy and secure storage', 'Made with 100% Polyester Featuring: resistant to most chemicals, stretching and shrinking, wrinkle resistant, mildew and abrasion resistant', 'Realistic looking with embroidered patches', 'Pants feature an elastic waistband for comfortable fit']",
#        "['Toys & Games', 'Hobbies', 'Models & Model Kits', 'Pre-Built & Diecast Models', 'Cars & Trucks']",
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Radios & Parts', 'Radio Receivers']",
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Hats\', \'6" high\', \'8.25" wide\', \'Quality materials used to make Disguise products\', \'Fun, Colorful, Inventive designs to put you in the world of role play\', "Whether it\'s Halloween, birthday parties, or even a fun filled night, disguise is good for everything!", \'Tiara with beads and fabric roses\', \'Character cameo\', \'Official Disney Licensed Costume Accessory\']',
#        "['Toys & Games', 'Sports & Outdoor Play', 'Play Sets & Playground Equipment', 'Play Set Attachments', 'Slide Attachments']",
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Hats\', \'poly-cotton\', \'Made in China\', \'4" high\', \'10.5" wide\', \'Relive the adventure of the action packed movie\', "Deluxe children\'s size hat is a fun addition to any dress up wardrobe", \'Printed with Indian Jones logo\']',
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Hats\', \'felt\', \'5" high\', \'11" wide\', \'Civil War era hat\', \'Durable and stain resistant man-made fabrics\', \'Gold trim and handsome embroidered badge\', \'Forum Novelties offers a huge variety of historical figures perfect for stage productions\', \'Great for play time or Halloween\']',
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Costumes\', "Kid\'s Costumes 100% Polyester Hand wash only.", \'Includes: Dress. Does Not Include Slippers.\']',
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Wigs']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', '100% Polyester']",
#        '[\'Toys & Games\', \'Novelty & Gag Toys\', \'Imported\', \'3" high\', \'11.5" wide\', \'50" posable spider decoration\', \'Package includes 1 spider\', \'Legs bend to pose in different positions\', \'A creepy addition to any scene or display\', \'Perfect for Halloween displays and haunted houses\']',
#        "['Toys & Games', 'Party Supplies', 'plastic', 'Plastic. Phoney Dynamite party accessory']",
#        "['Toys & Games', 'Party Supplies', 'Looks like a gold chain']",
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Accessories\', \'0.75" high\', \'4" wide\', \'Quality materials used to make Disguise products\', \'Fun, Colorful, Inventive designs to put you in the world of role play\', "Whether it\'s Halloween, birthday parties, or even a fun filled night, disguise is good for everything!", \'Wand with ribbons and beads\', \'Character cameo\', \'Official Disney Licensed Costume Accessory\']',
#        "['Toys & Games', 'Dolls & Accessories', 'Dollhouse Accessories', 'Dcor']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Accessories', '86947188940']",
#        '[\'Toys & Games\', \'Party Supplies\', \'Party Hats\', \'Includes one beaded Cinderella Tiara.\', \'This Cinderella Tiara is an officially licensed Disney Princess costume accessory.\', "Please note: This item\'s color may vary due to inherent manufacturing variations or your computer monitor\'s color settings. The item you receive will be identical or substantially similar to the item pictured in this listing."]',
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Masks\', \'Latex\', \'Imported\', \'12" high\', \'6" wide\', \'Made from Latex\', \'Comes with elastic string to help it stay on comfortably\', \'Complete your Joker look with the Officially Licensed Dark Knight Joker costume\']',
#        '[\'Toys & Games\', \'Action Figures & Statues\', \'Action Figures\', \'Polyester\', \'Made in USA or Imported\', \'1" high\', \'12" wide\', \'Inflatable jetpack\', \'Suitable for ages 4 and up\', \'Measures 30" in length\']',
#        "['Toys & Games', 'Hobbies', 'Trains & Accessories', 'Accessories', 'Vehicles, Boats & Airplanes']",
#        "['Toys & Games', 'Puzzles', 'Puzzle Play Mats']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Play Sets & Playground Equipment', 'Play Set Attachments', 'Climber Attachments']",
#        '[\'Toys & Games\', \'Party Supplies\', \'Polyester\', \'1" high\', \'4.5" wide\', \'Includes one pair of gloves\', \'One size fits most children\', \'Wipe clean\', \'100% polyester\', \'Look for other Officially Licensed Batman Dark Knight accessories\']',
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Hats', '100% Cotton', 'Imported', 'Hand Wash', 'Realistic-looking badge on the front', 'Plastic tab adjustable enclosure']",
#        '[\'Toys & Games\', \'Novelty & Gag Toys\', \'Gag Toys & Practical Jokes\', \'Plastic\', \'0.75" high\', \'5.2" wide\', \'Prop lollipop in light-weight plastic\', \'9-inches tall x 5-inches wide\', \'Brightly colored\', \'Great for munchkins of all ages\', \'Look to Forum Novelties for gag gifts and other fun party props\']',
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Beauty & Fashion', 'Makeup']",
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Hats\', \'Polyester\', \'Imported\', \'1.5" high\', \'8" wide\', \'Tricorn hat\', \'Durable and stain resistant man-made fabrics\', \'Also great for clown costumes\']',
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', '100% Polyester, Non Leather Material', 'Hand wash. Cold water. Use only non-chlorine bleach when needed. Line dry. Do not iron.', 'Body armor with attached cape', 'Arm bands', 'Cuffs', 'Leg guards']",
#        '[\'Toys & Games\', \'Dolls & Accessories\', \'Dolls\', \'3.75" x 1.75"\', \'Made of Polyresin\', \'Has adhesive sticker for the dashboard\', \'Makes a great driving companion!\', \'Was shown on an episode of Chicago Fire!\']',
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Masks']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Beauty & Fashion']",
#        '[\'Toys & Games\', \'Party Supplies\', \'Piatas\', \'8.5" high\', \'9.75" wide\', \'On each pinata there is a clear sticker labeled "Insert candy here."\', \'Under that sticker and a layer of tissue, there is a pre-made hole. Press sticker or use scissors to create an opening.\', \'All pinatas have a built-in hang loop at the top.\', \'Holds 2lbs of candy/toys\']',
#        "['Toys & Games', 'Hobbies', 'Models & Model Kits', 'Model Kits', 'Spacecraft Kits']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Kites & Wind Spinners', 'Wind Spinners']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Beauty & Fashion', 'Necklaces']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Bean Bags & Footbags', 'Footbags']",
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Beauty & Fashion\', \'Makeup\', \'1" high\', \'6" wide\', \'12 Color makeup palette, 5 colored makeup pencils, tooth black out, fake blood, glitter gel makeup, fake skin and applicators\', \'Great for Halloween, party time, play time or any time\', \'Everything in the kit washes off with warm water and soap\', \'Also great for a stage makeup starter kit\']',
#        "['Toys & Games', 'Tricycles, Scooters & Wagons', 'Balance Bikes']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Very Soft and Absorbent', 'Wears for hours without discomfort', 'Made of ultra lite poly foam', 'Pre-slit', 'Made in USA']",
#        '[\'Toys & Games\', \'Arts & Crafts\', \'Craft Kits\', \'Jewelry\', \'9.25" high\', \'8.25" wide\', \'Makes 22 Friendship Bracelets\', \'Weave hearts, stripes, diamonds and flowers\', \'Perfect for parties and sleepovers\', \'Includes 4 color coded looms, 22 colors of embroidery floss, beads, beading needle, instruction book, and carrying case\', \'Recommended for children 8 years of age and older\']',
#        "['Toys & Games', 'Party Supplies', 'Party Tableware', 'Plates']",
#        "['Toys & Games', 'Party Supplies', 'Party Tableware', 'Napkins']",
#        "['Toys & Games', 'Games', 'Game Collections', 'Wooden game board features all fifty states and their capitals', 'Learn the name and location of all fifty states and Identify states by their license plate design', 'Two players may keep score with color-coded edges', '14.5 x 11.5 x 1.1', '8+ years']",
#        "['Toys & Games', 'Hobbies', 'Models & Model Kits', 'Diorama Kits']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Lawn Games']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play', 'Paper & Magnetic Dolls', 'Magnetic Dress-up Dolls', 'vinyl', 'Have four times as much fun dressing two double-sided models with stands', 'Magnetic fashions for every occasion', 'Add shoes and hair accessories to complete their outfits', 'Carry case with handles measures 13.2 x 9.5 x 1.5', '3+ years', 'WARNING: Choking Hazard - Small parts. Not for children under 3 yrs.']",
#        "['Toys & Games', 'Arts & Crafts', 'Craft Kits', 'Mosaics']",
#        "['Toys & Games', 'Hobbies', 'Models & Model Kits', 'Pre-Built & Diecast Models', 'Ships & Submarines']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', 'Polyester', 'Product comes complete with: Plush Jumpsuit with attached head', 'Set packaged in durable snap-sealed poly bag', 'Gentle Machine Washable ~ Flame Retardant', 'Costume is made of a soft high quality fabric']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Beauty & Fashion', 'Rings']",
#        "['Toys & Games', 'Learning & Education', 'Early Development Toys']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Bean Bags & Footbags', 'Bean Bag Game Sets']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Hats', 'Faux fur/Satin', 'Great accessory to top off your outfit and celbrate Easter!']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Pools & Water Fun', 'Pool Toys', 'Dive Rings & Toys']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Slumber Bags']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play', 'Pretend Phones & Smartphones']",
# ...
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Accessories', 'POWER RANGERS - DINO CHARGE (SABAN)', 'Officially Licensed Power Rangers product!', 'Completes the costume!', 'Product Includes: One pair of gloves.']",
#        "['Toys & Games', 'Arts & Crafts', 'Drawing & Painting Supplies', 'Sharpeners']",
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Pretend Play\', \'5" high\', \'8" wide\', \'Youth Size, fits most\', \'Not a protective helmet\', \'Hats measure approx. 10 1/2"\', \'Set of 24, Makes great party favors!\']',
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', 'Includes a plush jumpsuit with attached hands, headpiece and shoe covers.', 'This Elmo costume is an officially licensed Sesame Street costume.']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', 'Tutu dress', 'Elmo character headband']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', 'Polyester', 'NULL', 'Includes: Jumpsuit With Attached Jacket, Attached Belt, And Character Hat.', 'Shoes Not Included']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', 'NULL', 'Includes: Dress With Character Cameo, Detachable Wings, And Headband With Ears And Faux Hair', 'Shoes Not Included']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', 'Includes a dress and matching headband with ears.']",
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Costumes\', \'100% Polyester\', \'Hand Wash\', \'Be the coolest character at the costume contest\', \'Dazzle your friends at your next Halloween parties\', "Brilliant colors to catch everyone\'s eyes", \'Designed to be true to The Isle of the Lost\', \'Quality costume to last through your adventures\']',
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', '100% Polyester', 'Hand Wash', 'This costume includes a yellow dress with a Belle embellishment and pink roses. Does not include shoes. This is an officially li']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', '100% Polyester', 'Imported', 'Hand Wash', 'Printed emblem on bodice', 'Belt with satchel', 'Tween size costume']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', 'Imported', 'Includes: Headpiece And Backpack.', 'This Is An Officially Licensed Item']",
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Costumes\', \'100% Polyester\', \'Half Helmet mask accessory covers face; one size fits most\', \'Officially licensed Star Wars Episode VII costume accessory; as worn by Kylo Ren in Star Wars Episode VII: The Force Awakens\', \'Helmet has faux battle damage representing a pivotal moment in the movie\', \'Kylo Ren costumes and additional accessories available separately\', "Rubie\'s offers costumes and accessories from Star Wars original and prequel trilogies as well as the Clone Wars series; great group and family costume ideas"]',
#        '[\'Toys & Games\', \'Party Supplies\', \'Party Hats\', \'1 crown\', \'Features a golden trim, white-bordered blue "1" and furry trim with foam stuffing\', \'Allow your baby boy to be a prince on his birthday with this novelty crown\', \'Let him wear this for his first birthday\']',
#        '[\'Toys & Games\', \'Party Supplies\', \'Banners, Streamers & Confetti\', \'Banners\', \'10 1/2\\\' long x 10" high\', \'Features letter cutouts spelling "Happy Birthday" with images of John Cena, Sheamus, Triple H, Kofi Kingston, The Rock and Rey Mysterio including adhesive numbers and ordinal suffixes in vibrant colors\', \'Hang this banner from the ceiling to welcome guests to your WWE birthday\', \'Perfect for birthdays\']',
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Vehicle Bodies & Scale Accessories', 'Fuselages']",
#        "['Toys & Games', 'Arts & Crafts', 'Craft Kits', 'Waterpainting Kits', 'An ideal introduction to painting!', '24 painting pages, each featuring kid-favorite vehicles like trains, boats, trucks, a plane, a school bus, and more', 'Simply wet the paintbrush, use it to blend a patterned area, and watch the colors combine', 'Perforated pages tear out cleanly for painting and display', 'Helps teach color recognition and promotes fine motor skills and hand-eye coordination']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play', 'Toy Police Gear - Police Swat Toys; 14 Police Toys Included; Police Toys for Toddlers & Older Kids; Toy Police Accessories', 'Great For Police Dress Up and Cop and Police Costumes; Toy Halloween Police Accessories; Toy Police Equipment; Great for Police Halloween Costumes', 'Toys for Boys - Kid Police Toys Includes: Flip Wallet Badge, Police Handcuffs, Baton, Glasses, Walkie Talkie, Keys, Knife', 'Compass, Binoculars, Police Badge, Whistle, Tweezers, Identity Card, and Watch; Boy Police Toys', 'Boys Toys; Police Toddler Toys; Police Kids Toys; Swat Police Toys; Police Force Toys; Child Police Toys; Kids Toys Police; Cheap Police Toys; Halloween Costumes Police Ideas']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Pools & Water Fun', 'Pool Toys', 'Dive Rings & Toys', 'synthetic', 'Disney Frozen Glitter Dive Wands from SwimWays are dive sticks that bring a little magic to the pool!', 'The heart-shaped top features Elsa, Anna, and Olaf graphics', 'Liquid glitter inside the wand sparkles in the sun and underwater', 'Great for everyday play at the pool, swim training practice, and for sharing with friends', 'Makes a great Disney Frozen party favor that kids can enjoy all year long!']",
#        '[\'Toys & Games\', "Kids\' Furniture, Dcor & Storage", \'Toy Chests & Storage\']',
#        "['Toys & Games', 'Party Supplies', 'Noisemakers', 'Product comes complete with: Hand Mic with attached Shoulder strap (Batteries not included)', 'Multi function mic has talk, siren and volume control options', 'Megaphone has a fold down handle and an attached strap', 'Product needs 4 AA batteries (not included)', 'For Indoor/Outdoor Use']",
#        '[\'Toys & Games\', \'Action Figures & Statues\', \'Action Figures\', \'Made in USA or Imported\', \'Kylo Ren A dark warrior strong with the Force!\', \'Kylo Ren commands First Order missions with a temper as fiery as his unconventional lightsaber.\', \'Includes 5-7 points of articulation!\', \'JAKKS BIG FIGS 18" figure comes complete with soft goods robe and Lightsaber.\', \'For Ages 3 and up\']',
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Beauty & Fashion', 'Bracelets', 'Exotic', 'Indian', 'metal']",
#        "['Toys & Games', 'Sports & Outdoor Play', 'Sports', 'Boxing', 'Boxing Gloves']",
#        '[\'Toys & Games\', "Kids\' Electronics", \'Music Players & Karaoke\', \'Karaoke Accessories\']',
#        "['Toys & Games', 'Arts & Crafts', 'Fuse Beads']",
#        "['Toys & Games', 'Hobbies', 'Slot Cars, Race Tracks & Accessories', 'Race Sets']",
#        "['Toys & Games', 'Novelty & Gag Toys', 'Light-Up Toys', 'A Perfect Accessory for Costume Party and Music Festival', 'One Size Fits All With Adjustable Neck Strap', 'Volume Sensing Technology Automatically Calibrates From concert Volume to conversation Volume', 'Adjustable Sensitivity To Music Volume', 'Takes Two AAA Batteries (NOT INCLUDED)']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Hats', 'Material: Cotton blend, fabric & care', 'Soft hat with goggles and aviator-inspired detailing.', 'Size: length 19cm(Do not contain braid length), width 24cm', 'Fits for: Baby from 2 years to 5 years', 'Item come with a stylus as free gift']",
#        "['Toys & Games', 'Dolls & Accessories', 'Doll Accessories', 'Clothing & Shoes', 'Matching Pajama Set for Girls and Dolls.', 'Fits American Girl Dolls, Dollie & Me, Madame Alexander and other 18 inches Dolls', 'Beautiful and unique designs.', 'Made in Ecuador - Premium Quality Materials.', 'Pink Butterfly Closet is a registered trademark and best-seller of Doll Clothing & Accessories']",
#        '[\'Toys & Games\', \'Novelty & Gag Toys\', \'Temporary Tattoos\', \'Measures 2" x 1.75"\', \'Package of 16 non-toxic child safe tattoos\', \'"Peppa Pig" & family temporary tattoos\', \'Match with our other "Peppa Pig" party collection\']',
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Masks', 'Celebrate the new Batman v Superman: Dawn Of Justice movie', 'Iconic detail from the film', 'Features voice changing technology', 'True to movie style', 'Lights and & Sounds']",
#        '[\'Toys & Games\', \'Party Supplies\', \'Party Packs\', \'fabric\', \'Imported\', \'Measures 13" ribbons w/ plastic medallion, 1.5" dia.\', \'Package of 12 non-toxic child safe party favors\', \'Pastel colored laces, "Peppa" & friends on medallions, sweet words headlines\', \'Match with our other "Peppa Pig" party collection\']',
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Masks\', \'Made from 100% natural latex, high quality, fits comfortably\', \'Environmental and non-toxic, no pungent chemical smell(normally have a smelling of latex)\', \'Large enough to fit most adults and kids heads\', "Horse head is with eyes, mouth and teeth, nostrils and brown fur mane, see through the mask\'s mouth and the nose holes", \'Perfect for masquerade parties, gifts, costume parties, carnival, christmas, easter, new years eve party, halloween, etc.\']',
#        '[\'Toys & Games\', \'Party Supplies\', \'Centerpieces\', \'1 decorating kit\', \'Kit contents: 1 foil fringe centerpiece, 2 3-D centerpieces and 20 pieces of paper confetti\', \'Display these high-spirited images of "Super Mario Brothers" characters on your table for everyone\\\'s entertainment\', \'Ornament your table with these for parties and fun occasions\']',
#        "['Toys & Games', 'Party Supplies', 'EDUCATIONAL role play promotes STEM (science, technology, engineering, and mathematics)', 'QUALITY construction will last for years of great play value', 'PERFECT for Halloween, pretend play, and parties for boys and girls ages 3-8', 'CUSTOM DESIGNED with movable visor and rotating antennae makes this great fun with interactive play', 'INCLUDES one helmet for endless fun as kids grow their imaginations']",
#        '[\'Toys & Games\', "Kids\' Furniture, Dcor & Storage", \'Outdoor Furniture\']',
#        "['Toys & Games', 'Hobbies', 'Models & Model Kits', 'Pre-Built & Diecast Models', 'Helicopters']",
#        '[\'Toys & Games\', \'Party Supplies\', \'Party Favors\', \'Imported\', \'48 party favors\', \'Multicolored "Blaze and the Monster Machines" plastic value pack\', \'Extend the fun with this mix of cute value pack favors\', \'Perfect for parties and fun occasions\']',
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Accessories\', \'Officially licensed Captain America: Civil War costume accessory\', \'War Machine gloves\', \'Sized for children ages 4+\', "Perfect final touch for child\'s War Machine costume", "Look to Rubie\'s for Captain America costumes and accessories in styles and sizes for the entire family"]',
#        "['Toys & Games', 'Hobbies', 'Cases & Stands', 'Carrying Cases']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Beauty & Fashion', 'Plastic', 'Product Includes: One necklace', 'Descendants (Disney)', 'Officially Licensed Product']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', '100% Polyester', 'Official L.O.L. Surprise costume']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Accessories', 'Polyester', 'Product Includes: Pair of hands', 'Nexo Knights (Lego)', 'Officially Licensed Product']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Accessories', 'Product Includes: One wand', 'Disney Princess - Beauty & The Beast', 'Officially Licensed Product']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Masks', 'Plastic', 'Imported', 'Featuring hundreds of fun and wacky eyewear designs', 'As seen on the popular show, Shark Tank', '100% UV400 protection and impact resistant lenses', 'Great for kids and adults, one size fits most', 'Officially licensed products']",
#        '[\'Toys & Games\', \'Novelty & Gag Toys\', \'5.9" high\', \'7.4" wide\', \'7" tall pouncing skeleton kitty\', \'Crafted from durable all-weather plastic\', \'Bendable tail and movable head and jaw\', \'Part of the original Crazy Bonez Skeleton line\', \'Spooky addition to any Halloween scene or decoration\']',
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Wigs', 'Officially licensed Willy Wonka & The Chocolate Factory costume accessory', 'Oompa Loompa wig', 'Designed to fit children', 'Based on the beloved 1971 movie', 'Look for Willy Wonka and Oompa Loompa costumes']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Accessories', 'Plastic', 'Officially licensed Teenage Mutant Ninja Turtle 2 Leonardo katana', 'Measures 26 x 2.75 x 1-inches', 'Designed to be used by children and teens', 'Costume accessory, not intended for play', 'Look for TMNT costumes and accessories for babies, children, adults, and pets']",
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Beauty & Fashion\', \'Includes 4 sets of clip-on earrings jewelry; Shown as picture\', \'Perfect accessories for dressing up your girl for birthday parties and other fanciful occasions\', "It\'s a good gift to your princess."]',
#        "['Toys & Games', 'Hobbies', 'Models & Model Kits', 'Model Kits', 'Motorcycle Kits']",
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Hats\', \'Imported\', \'Measures 3.5" x 4.5"\', \'Green electroplated plastic tiara\', \'Headline of "Princess Ariel", pink seashells\', \'Match with our other " Disney Ariel Dream Big" party collection\']',
#        "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Servos & Parts', 'Servo Arms']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', 'Hat', 'Jacket', 'Name Tag']",
#        "['Toys & Games', 'Hobbies', 'Trains & Accessories', 'Train Cars', 'Freight Cars', 'Tank Cars']",
#        "['Toys & Games', 'Party Supplies', 'Party Favors', 'Size: 8oz.']",
#        '[\'Toys & Games\', \'Party Supplies\', \'24" inflate\', \'Unique Fun Item\', \'Great For Parties\']',
#        "['Toys & Games', 'Hobbies', 'Trains & Accessories', 'Train Cars', 'Locomotives', 'Steam']",
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', '100% Polyester Exclusive of Decoration', 'Hand wash cold water. Do not bleach. Dry flat. Do not iron.', 'Size: Small (4-6), Medium (8-10), Large (12-14)', 'Includes: a hat, top with attached tie and hoop pants with attached suspenders.', 'Fake lollipop, wig, clown nose, makeup and gloves sold separately. Shoes not included.']",
#        '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Wigs\', \'8" high\', \'10" wide\', \'Officially licensed Avengers 2 costume accessory\', \'Thor costume wig\', \'One size fits most children\', "Add to your child\'s Thor costume to complete the look", "Put together a complete Avengers 2 team with costumes and accessories from Rubie\'s"]',
#        "['Toys & Games', 'Dress Up & Pretend Play', 'Accessories', 'Imported', 'Complete your Twilight Sparkle costume!', 'Officially licensed!', 'True to character ears!', 'Product Includes: Headband with ears and attached hair extension.']",
#        '[\'Toys & Games\', \'Party Supplies\', \'Imported\', \'10 1/2\\\' long x 10" high\', \'Features Blaze and the monster machines printed on paper letter banner\', \'Welcome your guests to your birthday with these enormous machines\', \'Hang this banner for birthdays\']',
#        '[\'Toys & Games\', \'Party Supplies\', \'Party Tableware\', \'Napkins\', \'16 lunch napkins, 2-ply\', \'Each napkin measures 12-7/8 in. x 12-7/8 in. unfolded\', \'Made in the USA\', \'Bright and colorful DC Super Hero Girls party napkins feature Wonder Woman, Supergirl, Batgirl and their signature emblems\', "Perfect American Greetings party supplies for a kid\'s birthday party or DC Superhero Girls themed party"]'],
#       dtype=object)

# %%
indi_games_cat = []
for i in data['category'].index:
    for icat in data['category'][i]:
        if icat not in indi_games_cat:
            indi_games_cat.append(icat)

print('Individual games category:',len(indi_games_cat))
# Out:
# Individual games category: 1363

# %% [markdown]
# #### NOTE
# Since the individial games category are immense and more of which aren't categorized properly, example. remarks and descriptions are also considered as categories and cleaning them are then proccesing is highly compulational expensive, the list of categories will henceforth be considered as the main category

# %%
df = df[df['category']!='[]']
print('Data shape:',df.shape)
# Out:
# Data shape: (1207194, 9)

# %% [markdown]
# #### NOTE
# Some empty values like '[]' are noted which do not convey any information. Hence those are dropped.

# %%
print(df['brand'].nunique())
df['brand'].unique()
# Out:
# 5111
# array(['Klutz', 'Therapy Game HQ', 'Yottoy', ...,
#        'Dunwoody Specialty Sales - Classic Car Sets', 'Sproutoy', 'Rowiz'],
#       dtype=object)

# %%
df['asin'].value_counts()
# Out:
# B00WR5357G    2178
# B00000K3BR    1988
# B000ZKPOTM    1902
# B001543YEY    1781
# B000197NXM    1584
#               ...
# B000YQW2MY       1
# B000Z4DOXG       1
# B00144DZIA       1
# B0017TO82Y       1
# B0010AMXNG       1
# Name: asin, Length: 46266, dtype: int64

# %%
df['asin'].value_counts().describe().to_frame().T
# Out:
#         count       mean        std  min  25%   50%   75%     max
# asin  46266.0  26.092465  55.555569  1.0  7.0  12.0  25.0  2178.0

# %% [markdown]
# #### INFERENCE
# Min = 1 and q3 = 25 whereas max = 2178: Review distribution in products is not uniform

# %% [markdown]
# # Data visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['overall'].value_counts().plot(kind='bar',color='r',figsize=(8,5))
plt.grid(axis='y')

# %% [markdown]
# #### INFERENCE
# Higher number of 5/5 reviews implies most customers are pleased with the products and services

# %%
df['category'].value_counts()[:10].plot(kind='barh',color='r',figsize=(8,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### INFERENCE
# Action figures and action statues are the top on review stand, its well spoken about- very popular among customers

# %%
df['verified'].value_counts().plot(kind='bar',color='r',figsize=(8,5))
plt.grid(axis='y')

# %% [markdown]
# #### INFERENCE
# Most of the reviewed products are verified

# %%
df['reviewTime'].value_counts().plot(color='r',figsize=(10,4))
plt.grid()

# %% [markdown]
# #### INFERENCE
# The performance of product popularity ie. the review collection has remained in the same range till 2012. The number of reviews or say the popularity of products hit its epitome between 2015-17

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decompose = seasonal_decompose(df['reviewTime'].value_counts().to_frame(),period=365)

fig,ax = plt.subplots(3,1,figsize=(10,12))
decompose.trend.plot(ax=ax[0],color='r')
decompose.seasonal.plot(ax=ax[1],color='r')
decompose.resid.plot(ax=ax[2],color='r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### INFERENCE
# Trend and residuals are related- The residuals are high when the popularity is high

# %%
df['brand'].value_counts().to_frame()[:10].plot(kind='barh',color='r',figsize=(8,5))
plt.grid(axis='x')

df['brand'].value_counts().to_frame()[-11:-1].plot(kind='barh',color='r',figsize=(8,5))
plt.grid(axis='x')

# %% [markdown]
# #### INFERENCE
# Melissa & Dough is the most popular brand and Didj is the least popular brand

# %% [markdown]
# #### BUSINESS INSIGHTS
# * Most customers are pleased with the products and services
# * Action figures and action statues are the most popular
# * Most of the reviewed products are verified
# * The popularity of products hit its epitome between 2015-17
# * Trend and residuals are related- The residuals are high when the popularity is high
# * Melissa & Dough is the most popular brand and Didj is the least popular brand
#
#
# * Toys and Games hit its epitome between 2015-17
# * Relationship can be observed between price and ratings: directly proportional.
# * [Action figures] receive the highest ratings. In spite of being the most expensive of all toys [Building toys, Building sets] maintains second in total ratings throughout the time.
# * Fisher-Price is the oldest brand member and has been maintaining stand though many other younger brands have surpassed it.
# * LEGO is the expensive younger brand receiving high ratings.
#
# * Poorly rated categories and brands have inconsistent performance. They are only short lived 1-3 years.
# * All the poor reviewed categories are expensive and related to [costumes].
# * Brands have seen decline in performance before termination. Artesania Latina is a just born brand showing increase in ratings but slow
#
#
# * FantasyFlightGames has the highest variety and products. But MerryMakers has the highest number products despite lesser variety of products.
# * Melissa&Dough is the most popular producer of non-expensive products
# * Most products of toys are Action Figures, the average price of action figure toy is above average than the price of other toys
# * Most variety and most products is in the category of [toys&games, games, board games]. Category having the highest products: variety ratio is [toys&games, games, tile games]
#
#
# * Despite having some variety 1967 MILTON BRADLEY-MB doesn’t produce many products.
# * ArtNaturals is the most non-expensive brand among least popular products and has the highest rating/price ratio.
# * Art toy products are the least expensive and the least reviewed category.
# * Despite having variety [Party Supplies] are the least reviewed category.

# %% [markdown]
# ---

# %% [markdown]
# # Sentiment Analysis
# Sentiment analysis, also referred to as opinion mining, is an approach that identifies the emotional tone behind a body of text: positive, negative and neutral

# %%
data = pd.read_csv('F:/NIIT/Capstone Project/Data_merge.csv')

# %%
data.dropna(axis=0,inplace=True)

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)

data['reviewTime'] = pd.to_datetime(data['reviewTime'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1205727 entries, 0 to 1207193
# Data columns (total 9 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   overall     1205727 non-null  float64
#  1   verified    1205727 non-null  bool
#  2   reviewTime  1205727 non-null  datetime64[ns]
#  3   asin        1205727 non-null  object
#  4   reviewText  1205727 non-null  object
#  5   summary     1205727 non-null  object
#  6   category    1205727 non-null  object
#  7   brand       1205727 non-null  object
#  8   price       1205727 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(2), object(5)
# memory usage: 83.9+ MB

# %%
data['reviewText'] = data['reviewText'] + ' ' + data['summary']
data.head()
# Out:
#    overall  verified reviewTime        asin  \
# 0      3.0      True 2014-02-23  0545346193
# 1      4.0      True 2012-11-14  0545346193
# 2      5.0      True 2015-02-11  0545346193
# 3      5.0      True 2015-01-04  0545346193
# 4      4.0      True 2016-02-14  0545346193
#
#                                           reviewText  \
# 0  The packaging for a draw-your-own DC Universe ...
# 1  I'm 37 years old and I just took up drawing ag...
# 2       Our little artist loves this kit. Five Stars
# 3             love this delivered on time Five Stars
# 4  Useful if you want to train your muscle memory...
#
#                                              summary  \
# 0  Great Idea But Needs More Instructions & Detai...
# 1                                 Good for beginners
# 2                                         Five Stars
# 3                                         Five Stars
# 4                             Great Drawing Practice
#
#                                           category  brand  price
# 0  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92
# 1  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92
# 2  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92
# 3  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92
# 4  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92

# %% [markdown]
# #### Approach
# 1. convert ratings into sentiments
# 2. classification of reviews based on sentiments
#     1. preprocess reviews
#     2. feature extraction (nlp)
#     3. classification modelling of reviews
# 3. find out the products in the inventory based on the sentiments

# %% [markdown]
# ## Ratings to sentiments

# %%
def predict_sentiment(rating):
    
    '''Returns the sentiment of the rating'''
    if rating < 3:
        sentiment = 'Negative'
    elif rating > 3:
        sentiment = 'Positive'
    else:
        sentiment = 'Neutral'
        
    return sentiment

# %%
data['sentiment'] = data['overall'].apply(predict_sentiment)
data.head()
# Out:
#    overall  verified reviewTime        asin  \
# 0      3.0      True 2014-02-23  0545346193
# 1      4.0      True 2012-11-14  0545346193
# 2      5.0      True 2015-02-11  0545346193
# 3      5.0      True 2015-01-04  0545346193
# 4      4.0      True 2016-02-14  0545346193
#
#                                           reviewText  \
# 0  The packaging for a draw-your-own DC Universe ...
# 1  I'm 37 years old and I just took up drawing ag...
# 2       Our little artist loves this kit. Five Stars
# 3             love this delivered on time Five Stars
# 4  Useful if you want to train your muscle memory...
#
#                                              summary  \
# 0  Great Idea But Needs More Instructions & Detai...
# 1                                 Good for beginners
# 2                                         Five Stars
# 3                                         Five Stars
# 4                             Great Drawing Practice
#
#                                           category  brand  price sentiment
# 0  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92   Neutral
# 1  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92  Positive
# 2  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92  Positive
# 3  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92  Positive
# 4  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92  Positive

# %% [markdown]
# ## Review preprocessing
# 1. expand shortforms
# 2. removing special characters
# 3. lemmatization
# 4. stopwords removal (negation)

# %% [markdown]
# ### expand shortforms

# %% [raw]
# !pip install contractions

# %%
import contractions

# %%
data['reviewText'] = data['reviewText'].apply(lambda x:contractions.fix(x))

# %% [markdown]
# ### removing special characters

# %%
import re

# %%
def clean_text(text):
    
    '''Return clean version of the text'''
    
    text = text.lower() 
    # Remove all non-letters and non-spaces except for hyphens and digits
    text = re.sub("[^0-9A-Za-z ]+", " ", text)
    # Remove all numbers except those attached to a word
    text = re.sub("(?<!\w)\d+", "", text)
    # Remove multiple spaces
    text = re.sub('\s+',' ',text)
    
    return text

# %%
data['reviewText'] = data['reviewText'].apply(clean_text)
data['reviewText'].head()
# Out:
# 0    the packaging for a draw your own dc universe ...
# 1    i am years old and i just took up drawing agai...
# 2          our little artist loves this kit five stars
# 3               love this delivered on time five stars
# 4    useful if you want to train your muscle memory...
# Name: reviewText, dtype: object

# %% [markdown]
# ### lemmatization

# %%
import nltk
from nltk.stem import WordNetLemmatizer

# %%
def lemmatization(text):
    
    '''Returns the text after lemmatization'''

    lemmatizer = WordNetLemmatizer()
    words = text.split()
    text_lemma = ' '.join(lemmatizer.lemmatize(word) for word in words)
    
    return text_lemma

# %%
data['reviewText'] = data['reviewText'].apply(lemmatization)
data['reviewText'].head()
# Out:
# 0    the packaging for a draw your own dc universe ...
# 1    i am year old and i just took up drawing again...
# 2            our little artist love this kit five star
# 3                love this delivered on time five star
# 4    useful if you want to train your muscle memory...
# Name: reviewText, dtype: object

# %% [markdown]
# ### stopwords removal

# %%
from spacy.lang.en.stop_words import STOP_WORDS

# %% [markdown]
# negation words are removed for appropriate vectorization and therby correct classification

# %%
STOP_WORDS -= {'cannot','least','less','neither','never','no','not','nor','none','nobody'}

# %%
def remove_stopwords(text):
    
    '''Returns text after removing stopwords'''
    
    new_text = []
    for word in text.split():
        if word not in STOP_WORDS:
            new_text.append(word)
            
    return ' '.join(new_text)

# %%
data['reviewText'] = data['reviewText'].apply(remove_stopwords)
data['reviewText'].head()
# Out:
# 0    packaging draw dc universe look easy think twi...
# 1    year old took drawing time high school wa not ...
# 2                          little artist love kit star
# 3                             love delivered time star
# 4    useful want train muscle memory tracing improv...
# Name: reviewText, dtype: object

# %%
data.head()
# Out:
#    overall  verified reviewTime        asin  \
# 0      3.0      True 2014-02-23  0545346193
# 1      4.0      True 2012-11-14  0545346193
# 2      5.0      True 2015-02-11  0545346193
# 3      5.0      True 2015-01-04  0545346193
# 4      4.0      True 2016-02-14  0545346193
#
#                                           reviewText  \
# 0  packaging draw dc universe look easy think twi...
# 1  year old took drawing time high school wa not ...
# 2                        little artist love kit star
# 3                           love delivered time star
# 4  useful want train muscle memory tracing improv...
#
#                                              summary  \
# 0  Great Idea But Needs More Instructions & Detai...
# 1                                 Good for beginners
# 2                                         Five Stars
# 3                                         Five Stars
# 4                             Great Drawing Practice
#
#                                           category  brand  price sentiment
# 0  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92   Neutral
# 1  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92  Positive
# 2  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92  Positive
# 3  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92  Positive
# 4  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92  Positive

# %% [markdown]
# ---

# %% [markdown]
# # Classification
# Supervised Learning technique that is used to identify the category of new observations on the basis of training data

# %% [markdown]
# ### CHALLENGES
# 1. large data size
# 2. unbalance in data

# %% [markdown]
# ### SOLUTION HYPOTHESIS
# 1. data after 2012                                                      - REJECTED        - no significant reduction
# 2. choose the time period that has the maximum reviews i.e 2015-17      - REJECTED        - no significant reduction
# 3. choose stratifies random sampling for years after 2012               - ACCEPTED

# %%
print('population data:',data.shape)
# Out:
# population data: (1205727, 10)

# %%
data['sentiment'].value_counts()
# Out:
# Positive    1049113
# Neutral       82129
# Negative      74485
# Name: sentiment, dtype: int64

# %%
# data after 2012
d = data[(data['reviewTime']>'2011-12-31')]
print(d.shape)

print(d['sentiment'].value_counts())
# Out:
# (1170969, 10)
# Positive    1020338
# Neutral       79039
# Negative      71592
# Name: sentiment, dtype: int64

# %%
# data for time period that has the maximum reviews i.e 2015-17
d = data[(data['reviewTime']>'2014-12-31')&(data['reviewTime']<'2018-01-01')]
print(d.shape)

print(d['sentiment'].value_counts())
# Out:
# (809647, 10)
# Positive    708021
# Neutral      52436
# Negative     49190
# Name: sentiment, dtype: int64

# %%
# stratified random sampling 10% of each sentiment

grouped = data.groupby('sentiment')
group_names = data['sentiment'].unique()

sample = pd.DataFrame()

for g in group_names:
    igroup = grouped.get_group(g)
    temp_sample = igroup.sample(frac=0.05,replace=False)
    sample = sample.append(temp_sample,ignore_index=True)

# %%
sample.shape
# Out:
# (60286, 10)

# %%
sample['sentiment'].value_counts()
# Out:
# Positive    52456
# Neutral      4106
# Negative     3724
# Name: sentiment, dtype: int64

# %% [markdown]
# ### Hypothesis testing: Mood's median test
# Is a non-parametric statistical test that works on 2 or more groups to compare the ordinal data distribution based on their median.
#
# Null hypothesis: Medians of the groups are equal
# Alternate hypothesis: Medians of the groups are not equal

# %%
p = pd.DataFrame(data['sentiment'].value_counts()).rename({'sentiment':'frequency'},axis=1)
p = p.sort_values(by='frequency',ascending=True)
p
# Out:
#           frequency
# Negative      74485
# Neutral       82129
# Positive    1049113

# %%
s = pd.DataFrame(sample['sentiment'].value_counts()).rename({'sentiment':'frequency'},axis=1)
s = s.sort_values(by='frequency',ascending=True)
s
# Out:
#           frequency
# Negative       3724
# Neutral        4106
# Positive      52456

# %%
# significance level = 5%
alpha = 0.05

# df = number of sample groups - 1
df = 1

# %%
from scipy.stats import median_test

res = median_test(p['frequency'].values,s['frequency'].values)

pvalue = res[1]

if pvalue < alpha:
    print('Reject null hypothesis')
    print('Medians of the groups are not equal')
else:
    print('Cannot reject null hypothesis')
    print('Medians of the groups are equal')
# Out:
# Cannot reject null hypothesis
# Medians of the groups are equal

# %% [markdown]
# #### INFERENCE
# Sample represents population- sample can be used for modelling

# %% [markdown]
# ---

# %% [markdown]
# ## Vectorization

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
x = sample['reviewText']
y = sample['sentiment']

tfidf = TfidfVectorizer()
X = tfidf.fit_transform(x)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
Y = encoder.fit_transform(y)

# %% [markdown]
# ## Data splitting

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=777)

print('x:',x_train.shape,x_test.shape)
print('y:',y_train.shape,y_test.shape)
# Out:
# x: (48228, 29419) (12058, 29419)
# y: (48228,) (12058,)

# %% [raw]
# x_train = x_train.toarray()
# x_test = x_test.toarray()

# %% [markdown]
# # Modelling
# for multi-classification: KNeighborsClassifier, Naive-bayes, DecisionTreeClassifier, RandomForestClassifier(Bagging), AdaBoost, Stacking

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score, precision_score, recall_score

# %% [markdown]
# ## KNeighbors
# computes classification from majority of vote of knearest neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### finding the parameters for maximum score
# k = number of neighbors for the maximum score \
# odd number is preferred to ommit equal voting of neighbors

# %%
score = dict()
up = 10

for k in range(1,up,2):
    temp_knn = KNeighborsClassifier(n_neighbors=k).fit(x_train,y_train) 
    temp_score = temp_knn.score(x_test,y_test)
    score[k] = temp_score
    
best_k = max(score,key=lambda i:score[i])
print('Best k =',best_k)
# Out:
# Best k = 7

# %% [markdown]
# ### training

# %%
knn = KNeighborsClassifier(n_neighbors=best_k)
knn.fit(x_train,y_train)

print('KNeighborsClassifier: Training accuracy:',knn.score(x_train,y_train))
# Out:
# KNeighborsClassifier: Training accuracy: 0.8761715186198888

# %% [markdown]
# ### testing

# %%
y_knn = knn.predict(x_test)

print('KNeighborsClassifier: Testing accuracy:',accuracy_score(y_test,y_knn))
# Out:
# KNeighborsClassifier: Testing accuracy: 0.8734450157571737

# %% [markdown]
# ### evaluation

# %%
sns.heatmap(confusion_matrix(y_test,y_knn),annot=True,fmt='d')
plt.title('confusion_matrix\n')
plt.xlabel('predicted\n')
plt.ylabel('actual\n')
# Out:
# Text(33.0, 0.5, 'actual\n')

# %%
print('Classification report:\n',classification_report(y_test,y_knn))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.59      0.06      0.12       732
#            1       0.44      0.03      0.05       831
#            2       0.88      1.00      0.93     10495
#
#     accuracy                           0.87     12058
#    macro avg       0.64      0.36      0.37     12058
# weighted avg       0.83      0.87      0.82     12058

# %%
imbal = pd.DataFrame({'KNeighborsClassifier':
                    [accuracy_score(y_test,y_knn),
                     precision_score(y_test,y_knn,average='weighted'),
                    recall_score(y_test,y_knn,average='weighted'),
                    f1_score(y_test,y_knn,average='weighted')]},
                   index=['accuracy','precision','recall','f1_score'])

# %% [markdown]
# # Naive-Bayes
# assumes each imput is independent and is based on Bayes theorem

# %%
from sklearn.naive_bayes import MultinomialNB

# %% [markdown]
# ### training

# %%
nb = MultinomialNB()
nb.fit(x_train,y_train)

print('MultinomialNB: Taining accuracy:',nb.score(x_train,y_train))
# Out:
# MultinomialNB: Taining accuracy: 0.8709048685410965

# %% [markdown]
# ### testing

# %%
y_nb = nb.predict(x_test)
print('MultinomialNB: Testing accuracy:',accuracy_score(y_test,y_nb))
# Out:
# MultinomialNB: Testing accuracy: 0.8709570409686516

# %% [markdown]
# ### evaluation

# %%
sns.heatmap(confusion_matrix(y_test,y_nb),annot=True,fmt='d')
plt.title('confusion_matrix\n')
plt.xlabel('predicted\n')
plt.ylabel('actual\n')
# Out:
# Text(33.0, 0.5, 'actual\n')

# %%
print('Classification report:\n',classification_report(y_test,y_nb))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.01      0.02       732
#            1       0.00      0.00      0.00       831
#            2       0.87      1.00      0.93     10495
#
#     accuracy                           0.87     12058
#    macro avg       0.59      0.34      0.32     12058
# weighted avg       0.81      0.87      0.81     12058

# %%
imbal['MultinomialNB'] = [accuracy_score(y_test,y_nb),precision_score(y_test,y_nb,average='weighted'),
                    recall_score(y_test,y_nb,average='weighted'), f1_score(y_test,y_nb,average='weighted')]

# %% [markdown]
# ## DecisionTreeClassifier
# produces a sequence of rules that can be used to classify the data

# %%
from sklearn import tree
from sklearn.tree import plot_tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold, cross_val_score

# %% [markdown]
# ### finding the parameters for maximum score
# parameters: max_dept, min_samples_leaf

# %%
max_depth = list(range(2,20,2))
cv=KFold(n_splits=5)

score = dict()

for depth in max_depth:
    iscore = cross_val_score(tree.DecisionTreeClassifier(max_depth=depth, random_state=777),X,Y,cv=cv,scoring="accuracy")
    score[depth] = iscore

depth = max(score,key=lambda i:score[i].mean())
print('Best depth =',depth)
# Out:
# Best depth = 2

# %%
min_sam_leaf = list(range(10,100,10))

score = dict()

for min_sam in min_sam_leaf:
    iscore = cross_val_score(tree.DecisionTreeClassifier(min_samples_leaf=min_sam,random_state=777)
                             ,X,Y,cv=cv,scoring="accuracy")
    score[min_sam] = iscore
    
min_sam = max(score,key=lambda i:score[i].mean())
print('Best min_sam_leaf =',min_sam)
# Out:
# Best min_sam_leaf = 80

# %% [markdown]
# ### training

# %%
dtc = DecisionTreeClassifier(max_depth=depth,min_samples_leaf=min_sam)
dtc.fit(x_train,y_train)

print('DecisionTreeClassifier: Training accuracy:',dtc.score(x_train,y_train))
# Out:
# DecisionTreeClassifier: Training accuracy: 0.8708633988554366

# %% [markdown]
# ### testing

# %%
y_dtc = dtc.predict(x_test)
print('DecisionTreeClassifier: Testing accuracy:',accuracy_score(y_test,y_dtc))
# Out:
# DecisionTreeClassifier: Testing accuracy: 0.8712887709404544

# %% [markdown]
# ### evaluation

# %%
sns.heatmap(confusion_matrix(y_test,y_dtc),annot=True,fmt='d')
plt.xlabel('predicted')
plt.ylabel('actual')
plt.title('confusion_matrix')
# Out:
# Text(0.5, 1.0, 'confusion_matrix')

# %%
print('Classification report:\n',classification_report(y_test,y_dtc))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.51      0.03      0.05       732
#            1       0.00      0.00      0.00       831
#            2       0.87      1.00      0.93     10495
#
#     accuracy                           0.87     12058
#    macro avg       0.46      0.34      0.33     12058
# weighted avg       0.79      0.87      0.81     12058

# %% [markdown]
# ### model representation

# %%
plt.figure(figsize=(20,10))
plot_tree(DecisionTreeClassifier(max_depth=depth,min_samples_leaf=min_sam,random_state=1).fit(x_train,y_train),
         fontsize=10,filled=True);

# %%
imbal['DecisionTreeClassifier'] = [accuracy_score(y_test,y_dtc),precision_score(y_test,y_dtc,average='weighted'),
                    recall_score(y_test,y_dtc,average='weighted'), f1_score(y_test,y_dtc,average='weighted')]

# %% [markdown]
# ## RandomForestClassifier
# bagging ensemble technique: that is a strong learner- combination of multiple homogeneous weak learners \
# learning happens parallel and the final class is predicted based on hard voting

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### training

# %%
params={'n_estimators':list(range(1,10,2))}

grid_search_rfc = GridSearchCV(estimator=RandomForestClassifier(max_depth=depth,min_samples_leaf=min_sam,random_state=777),
                             param_grid=params,cv=5,n_jobs=-1)
grid_search_rfc.fit(x_train,y_train)

print(grid_search_rfc.best_estimator_)
print('RandomForestClassifier: Training accuracy:',grid_search_rfc.best_estimator_.score(x_train,y_train))
# Out:
# RandomForestClassifier(max_depth=2, min_samples_leaf=80, n_estimators=1,
#                        random_state=777)
# RandomForestClassifier: Training accuracy: 0.8719001409969312

# %% [markdown]
# ### testing

# %%
y_rfc = grid_search_rfc.predict(x_test)
print('RandomForestClassifier: Testing accuracy:',accuracy_score(y_test,y_rfc))
# Out:
# RandomForestClassifier: Testing accuracy: 0.8712887709404544

# %% [markdown]
# ### evaluation

# %%
sns.heatmap(confusion_matrix(y_test,y_rfc,),annot=True,fmt='d')
plt.xlabel('\nPredicted',fontsize=15)
plt.ylabel('Actual\n',fontsize=15)
plt.title('\nConfusion matrix\n',fontsize=15)
# Out:
# Text(0.5, 1.0, '\nConfusion matrix\n')

# %%
print('\nClassification report:')
print(classification_report(y_test,y_rfc))
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.02      0.04       732
#            1       0.00      0.00      0.00       831
#            2       0.87      1.00      0.93     10495
#
#     accuracy                           0.87     12058
#    macro avg       0.48      0.34      0.33     12058
# weighted avg       0.79      0.87      0.81     12058

# %% [markdown]
# ### model representation

# %%
plt.figure(figsize=(20,5),dpi=300)
plot_tree(RandomForestClassifier(max_depth=2,min_samples_leaf=90,n_estimators=1,random_state=777).
          fit(x_train,y_train).estimators_[0],fontsize=10,filled=True);

# %%
imbal['RandomForestClassifier'] = [accuracy_score(y_test,y_rfc),precision_score(y_test,y_rfc,average='weighted'),
                    recall_score(y_test,y_rfc,average='weighted'), f1_score(y_test,y_rfc,average='weighted')]

# %% [markdown]
# ## AdaBoost
# boosting ensemble technique: that is a combination of multiple weal learners \
# learning happens sequentially

# %%
from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# ### training

# %%
ab=AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=depth, random_state=777),
                     random_state=777,n_estimators=1)
ab.fit(x_train,y_train)

print('AdaBoost: Taining accuracy:',ab.score(x_train,y_train))
# Out:
# AdaBoost: Taining accuracy: 0.8708633988554366

# %% [markdown]
# ### testing

# %%
y_ab=ab.predict(x_test)
print('AdaBoost: Testing accuracy:',accuracy_score(y_test,y_ab))
# Out:
# AdaBoost: Testing accuracy: 0.8712887709404544

# %% [markdown]
# ### evaluation

# %%
sns.heatmap(confusion_matrix(y_test,y_ab,),annot=True,fmt='d')
plt.xlabel('\nPredicted',fontsize=15)
plt.ylabel('Actual\n',fontsize=15)
plt.title('\nConfusion matrix\n',fontsize=15)
# Out:
# Text(0.5, 1.0, '\nConfusion matrix\n')

# %%
print('\nClassification report:')
print(classification_report(y_test,y_ab))
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.51      0.03      0.05       732
#            1       0.00      0.00      0.00       831
#            2       0.87      1.00      0.93     10495
#
#     accuracy                           0.87     12058
#    macro avg       0.46      0.34      0.33     12058
# weighted avg       0.79      0.87      0.81     12058

# %% [markdown]
# ### model representation

# %%
plot_tree(AdaBoostClassifier(random_state=777).fit(x_train,y_train).estimators_[0],fontsize=10,filled=True);

# %%
imbal['AdaBoost'] = [accuracy_score(y_test,y_ab),precision_score(y_test,y_ab,average='weighted'),
                    recall_score(y_test,y_ab,average='weighted'), f1_score(y_test,y_ab,average='weighted')]

# %% [markdown]
# # Stacking
# ensemble method in which the predictions, generated by using various machine learning algorithms, are used as inputs in a second-layer learning algorithm. This second-layer algorithm is trained to optimally combine the model predictions to form a new set of predictions

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### training

# %%
level0=[('dtree', DecisionTreeClassifier()),('nb',MultinomialNB())] 
level1 = LogisticRegression()

sc = StackingClassifier(estimators=level0,final_estimator=level1,cv=3).fit(x_train,y_train)
print('StackingClassifier: Training accuracy:',sc.score(x_train,y_train))
# Out:
# StackingClassifier: Training accuracy: 0.9241726797710873

# %% [markdown]
# ### testing

# %%
y_sc=sc.predict(x_test)
print('StackingClassifier: Testing accuracy:',accuracy_score(y_test,y_sc))
# Out:
# StackingClassifier: Testing accuracy: 0.8867971471222424

# %% [markdown]
# ### evaluation

# %%
sns.heatmap(confusion_matrix(y_test,y_sc,),annot=True,fmt='d')
plt.xlabel('\nPredicted',fontsize=15)
plt.ylabel('Actual\n',fontsize=15)
plt.title('\nConfusion matrix\n',fontsize=15)
# Out:
# Text(0.5, 1.0, '\nConfusion matrix\n')

# %%
print('\nClassification report:')
print(classification_report(y_test,y_sc))
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.59      0.43      0.50       732
#            1       0.50      0.02      0.05       831
#            2       0.90      0.99      0.94     10495
#
#     accuracy                           0.89     12058
#    macro avg       0.66      0.48      0.49     12058
# weighted avg       0.86      0.89      0.85     12058

# %%
imbal['StackingClassifier'] = [accuracy_score(y_test,y_sc),precision_score(y_test,y_sc,average='weighted'),
                    recall_score(y_test,y_sc,average='weighted'), f1_score(y_test,y_sc,average='weighted')]

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.multiclass import OneVsRestClassifier

# %% [markdown]
# ### training

# %%
score = dict()
up = 200

for i in range(100,up,50):
    temp_lr = LogisticRegression(max_iter=i)
    temp_ovr = OneVsRestClassifier(temp_lr).fit(x_train,y_train) 
    
    temp_score = temp_ovr.score(x_test,y_test)
    score[i] = temp_score
    
best_i = max(score,key=lambda i:score[i])
print('Best i =',best_i)
# Out:
# Best i = 100

# %%
lr = LogisticRegression(max_iter=best_i)
ovr = OneVsRestClassifier(lr)
ovr.fit(x_train, y_train)

print('StackingClassifier: Training accuracy:',ovr.score(x_train,y_train))
# Out:
# StackingClassifier: Training accuracy: 0.9123538193580493

# %% [markdown]
# ### testing

# %%
y_lr = ovr.predict(x_test)
print('LogisticRegression: Testing accuracy:',accuracy_score(y_test,y_lr))
# Out:
# LogisticRegression: Testing accuracy: 0.8999834135014099

# %% [markdown]
# ### evaluation

# %%
sns.heatmap(confusion_matrix(y_test,y_lr,),annot=True,fmt='d')
plt.xlabel('\nPredicted',fontsize=15)
plt.ylabel('Actual\n',fontsize=15)
plt.title('\nConfusion matrix\n',fontsize=15)
# Out:
# Text(0.5, 1.0, '\nConfusion matrix\n')

# %%
print('\nClassification report:')
print(classification_report(y_test,y_lr))
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.47      0.57       732
#            1       0.55      0.11      0.19       831
#            2       0.91      0.99      0.95     10495
#
#     accuracy                           0.90     12058
#    macro avg       0.73      0.52      0.57     12058
# weighted avg       0.88      0.90      0.88     12058

# %%
imbal['LogisticRegression'] = [accuracy_score(y_test,y_lr),precision_score(y_test,y_lr,average='weighted'),
                    recall_score(y_test,y_lr,average='weighted'), f1_score(y_test,y_lr,average='weighted')]

# %% [markdown]
# ## Comparison

# %%
imbal.T.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_3bfbe_row0_col0, #T_3bfbe_row0_col2 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_3bfbe_row0_col1 {
#   background-color: #fb7757;
#   color: #f1f1f1;
# }
# #T_3bfbe_row0_col3 {
#   background-color: #fdd3c1;
#   color: #000000;
# }
# #T_3bfbe_row1_col0, #T_3bfbe_row1_col2, #T_3bfbe_row1_col3, #T_3bfbe_row2_col1, #T_3bfbe_row4_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_3bfbe_row1_col1 {
#   background-color: #fcb79c;
#   color: #000000;
# }
# #T_3bfbe_row2_col0, #T_3bfbe_row2_col2, #T_3bfbe_row3_col0, #T_3bfbe_row3_col2, #T_3bfbe_row4_col0, #T_3bfbe_row4_col2 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_3bfbe_row2_col3, #T_3bfbe_row3_col1, #T_3bfbe_row4_col3 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_3bfbe_row3_col3 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_3bfbe_row5_col0, #T_3bfbe_row5_col2 {
#   background-color: #f7593f;
#   color: #f1f1f1;
# }
# #T_3bfbe_row5_col1 {
#   background-color: #c8171c;
#   color: #f1f1f1;
# }
# #T_3bfbe_row5_col3 {
#   background-color: #e43027;
#   color: #f1f1f1;
# }
# #T_3bfbe_row6_col0, #T_3bfbe_row6_col1, #T_3bfbe_row6_col2, #T_3bfbe_row6_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3bfbe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3bfbe_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_3bfbe_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_3bfbe_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_3bfbe_level0_col3" class="col_heading level0 col3" >f1_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3bfbe_level0_row0" class="row_heading level0 row0" >KNeighborsClassifier</th>
#       <td id="T_3bfbe_row0_col0" class="data row0 col0" >0.873445</td>
#       <td id="T_3bfbe_row0_col1" class="data row0 col1" >0.829625</td>
#       <td id="T_3bfbe_row0_col2" class="data row0 col2" >0.873445</td>
#       <td id="T_3bfbe_row0_col3" class="data row0 col3" >0.822567</td>
#     </tr>
#     <tr>
#       <th id="T_3bfbe_level0_row1" class="row_heading level0 row1" >MultinomialNB</th>
#       <td id="T_3bfbe_row1_col0" class="data row1 col0" >0.870957</td>
#       <td id="T_3bfbe_row1_col1" class="data row1 col1" >0.812864</td>
#       <td id="T_3bfbe_row1_col2" class="data row1 col2" >0.870957</td>
#       <td id="T_3bfbe_row1_col3" class="data row1 col3" >0.811842</td>
#     </tr>
#     <tr>
#       <th id="T_3bfbe_level0_row2" class="row_heading level0 row2" >DecisionTreeClassifier</th>
#       <td id="T_3bfbe_row2_col0" class="data row2 col0" >0.871289</td>
#       <td id="T_3bfbe_row2_col1" class="data row2 col1" >0.790493</td>
#       <td id="T_3bfbe_row2_col2" class="data row2 col2" >0.871289</td>
#       <td id="T_3bfbe_row2_col3" class="data row2 col3" >0.813913</td>
#     </tr>
#     <tr>
#       <th id="T_3bfbe_level0_row3" class="row_heading level0 row3" >RandomForestClassifier</th>
#       <td id="T_3bfbe_row3_col0" class="data row3 col0" >0.871289</td>
#       <td id="T_3bfbe_row3_col1" class="data row3 col1" >0.793411</td>
#       <td id="T_3bfbe_row3_col2" class="data row3 col2" >0.871289</td>
#       <td id="T_3bfbe_row3_col3" class="data row3 col3" >0.813380</td>
#     </tr>
#     <tr>
#       <th id="T_3bfbe_level0_row4" class="row_heading level0 row4" >AdaBoost</th>
#       <td id="T_3bfbe_row4_col0" class="data row4 col0" >0.871289</td>
#       <td id="T_3bfbe_row4_col1" class="data row4 col1" >0.790493</td>
#       <td id="T_3bfbe_row4_col2" class="data row4 col2" >0.871289</td>
#       <td id="T_3bfbe_row4_col3" class="data row4 col3" >0.813913</td>
#     </tr>
#     <tr>
#       <th id="T_3bfbe_level0_row5" class="row_heading level0 row5" >StackingClassifier</th>
#       <td id="T_3bfbe_row5_col0" class="data row5 col0" >0.886797</td>
#       <td id="T_3bfbe_row5_col1" class="data row5 col1" >0.855225</td>
#       <td id="T_3bfbe_row5_col2" class="data row5 col2" >0.886797</td>
#       <td id="T_3bfbe_row5_col3" class="data row5 col3" >0.853662</td>
#     </tr>
#     <tr>
#       <th id="T_3bfbe_level0_row6" class="row_heading level0 row6" >LogisticRegression</th>
#       <td id="T_3bfbe_row6_col0" class="data row6 col0" >0.899983</td>
#       <td id="T_3bfbe_row6_col1" class="data row6 col1" >0.875804</td>
#       <td id="T_3bfbe_row6_col2" class="data row6 col2" >0.899983</td>
#       <td id="T_3bfbe_row6_col3" class="data row6 col3" >0.875003</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### OBSERVATION
# inorder to decide the best comparitive model:
# 1. overall metrics
# 2. individual f1 scores
#
# LogisticRegression is the best comparitive model on imbalanced data
#
# though the combined f1_score is good, the data being unbalanced the individual class f1_scores are not good

# %% [markdown]
# ### OBSERVATION
# data is imbalanced, hence the data has to be made balanced for efficient machine learning
#
# Technique to make it balanced:
# * SMOTE - requires numeric data

# %% [markdown]
# ## Data balancing

# %%
from imblearn.over_sampling import SMOTE

# %% [markdown]
# sample imbalance data

# %%
sample['sentiment'].value_counts()
# Out:
# Positive    52456
# Neutral      4106
# Negative     3724
# Name: sentiment, dtype: int64

# %%
smote = SMOTE(random_state=777)
Xb,Yb = smote.fit_resample(X,Y)

print('x:',Xb.shape,'y:',Yb.shape)
# Out:
# x: (157368, 29419) y: (157368,)

# %% [markdown]
# ### Data splitting

# %%
x_trainb,x_testb,y_trainb,y_testb = train_test_split(Xb,Yb,test_size=0.2,random_state=777)

print('x:',x_trainb.shape,x_testb.shape)
print('y:',y_trainb.shape,y_testb.shape)
# Out:
# x: (125894, 29419) (31474, 29419)
# y: (125894,) (31474,)

# %% [markdown]
# sample balanced data

# %%
pd.DataFrame(y_trainb).value_counts()
# Out:
# 2    42013
# 0    41971
# 1    41910
# dtype: int64

# %%
bal = pd.DataFrame(index=['accuracy','precision','recall','f1_score'])

# %% [markdown]
# # Naive-Bayes
# assumes each imput is independent and is based on Bayes theorem

# %% [markdown]
# ### training

# %%
nbb = MultinomialNB()
nbb.fit(x_trainb,y_trainb)

print('MultinomialNB: Taining accuracy:',nbb.score(x_trainb,y_trainb))
# Out:
# MultinomialNB: Taining accuracy: 0.838665861756716

# %% [markdown]
# ### testing

# %%
y_nbb = nbb.predict(x_testb)
print('MultinomialNB: Testing accuracy:',accuracy_score(y_testb,y_nbb))
# Out:
# MultinomialNB: Testing accuracy: 0.8263010739022686

# %% [markdown]
# ### evaluation

# %%
sns.heatmap(confusion_matrix(y_testb,y_nbb),annot=True,fmt='d')
plt.title('confusion_matrix\n')
plt.xlabel('predicted\n')
plt.ylabel('actual\n')
# Out:
# Text(33.0, 0.5, 'actual\n')

# %%
print('Classification report:\n',classification_report(y_testb,y_nbb))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86     10485
#            1       0.77      0.78      0.78     10546
#            2       0.87      0.82      0.84     10443
#
#     accuracy                           0.83     31474
#    macro avg       0.83      0.83      0.83     31474
# weighted avg       0.83      0.83      0.83     31474

# %%
bal['MultinomialNB'] = [accuracy_score(y_testb,y_nbb),precision_score(y_testb,y_nbb,average='weighted'),
                    recall_score(y_testb,y_nbb,average='weighted'), f1_score(y_testb,y_nbb,average='weighted')]

# %% [markdown]
# ## DecisionTreeClassifier
# produces a sequence of rules that can be used to classify the data

# %% [markdown]
# ### finding the parameters for maximum score
# parameters: max_dept, min_samples_leaf

# %%
max_depth = list(range(2,10,2))
cv=KFold(n_splits=5)

score = dict()

for depth in max_depth:
    iscore = cross_val_score(tree.DecisionTreeClassifier(max_depth=depth, random_state=777)
                             ,x_trainb,y_trainb,cv=cv,scoring="accuracy")
    score[depth] = iscore

depth = max(score,key=lambda i:score[i].mean())
print('Best depth =',depth)
# Out:
# Best depth = 8

# %% [markdown]
# ### training

# %%
dtcb = DecisionTreeClassifier(max_depth=depth)
dtcb.fit(x_trainb,y_trainb)

print('DecisionTreeClassifier: Training accuracy:',dtcb.score(x_trainb,y_trainb))
# Out:
# DecisionTreeClassifier: Training accuracy: 0.6469331342240298

# %% [markdown]
# ### testing

# %%
y_dtcb = dtcb.predict(x_testb)
print('DecisionTreeClassifier: Testing accuracy:',accuracy_score(y_testb,y_dtcb))
# Out:
# DecisionTreeClassifier: Testing accuracy: 0.6438330050200165

# %% [markdown]
# ### evaluation

# %%
sns.heatmap(confusion_matrix(y_testb,y_dtcb),annot=True,fmt='d')
plt.xlabel('predicted')
plt.ylabel('actual')
plt.title('confusion_matrix')
# Out:
# Text(0.5, 1.0, 'confusion_matrix')

# %%
print('Classification report:\n',classification_report(y_testb,y_dtcb))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.71      0.67     10485
#            1       0.64      0.36      0.46     10546
#            2       0.65      0.86      0.74     10443
#
#     accuracy                           0.64     31474
#    macro avg       0.64      0.64      0.63     31474
# weighted avg       0.64      0.64      0.62     31474

# %%
bal['DecisionTreeClassifier'] = [accuracy_score(y_testb,y_dtcb),precision_score(y_testb,y_dtcb,average='weighted'),
                    recall_score(y_testb,y_dtcb,average='weighted'), f1_score(y_testb,y_dtcb,average='weighted')]

# %% [markdown]
# ## RandomForestClassifier
# bagging ensemble technique: that is a strong learner- combination of multiple homogeneous weak learners \
# learning happens parallel and the final class is predicted based on hard voting

# %% [markdown]
# ### training

# %%
params={'n_estimators':list(range(1,10,2))}

grid_search_rfcb = GridSearchCV(estimator=RandomForestClassifier(max_depth=depth,random_state=777),
                             param_grid=params,cv=5,n_jobs=-1)
grid_search_rfcb.fit(x_trainb,y_trainb)

print(grid_search_rfcb.best_estimator_)
print('RandomForestClassifier: Training accuracy:',grid_search_rfcb.best_estimator_.score(x_trainb,y_trainb))
# Out:
# RandomForestClassifier(max_depth=8, n_estimators=9, random_state=777)
# RandomForestClassifier: Training accuracy: 0.5760322175798688

# %% [markdown]
# ### testing

# %%
y_rfcb = grid_search_rfcb.predict(x_testb)
print('RandomForestClassifier: Testing accuracy:',accuracy_score(y_testb,y_rfcb))
# Out:
# RandomForestClassifier: Testing accuracy: 0.5745377136684248

# %% [markdown]
# ### evaluation

# %%
sns.heatmap(confusion_matrix(y_testb,y_rfcb),annot=True,fmt='d')
plt.xlabel('\nPredicted',fontsize=15)
plt.ylabel('Actual\n',fontsize=15)
plt.title('\nConfusion matrix\n',fontsize=15)
# Out:
# Text(0.5, 1.0, '\nConfusion matrix\n')

# %%
print('\nClassification report:')
print(classification_report(y_testb,y_rfcb))
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.66      0.56      0.60     10485
#            1       0.58      0.40      0.47     10546
#            2       0.52      0.76      0.62     10443
#
#     accuracy                           0.57     31474
#    macro avg       0.59      0.58      0.57     31474
# weighted avg       0.59      0.57      0.57     31474

# %% [markdown]
# ### model representation

# %%
plt.figure(figsize=(20,5),dpi=300)
plot_tree(RandomForestClassifier(max_depth=2,min_samples_leaf=90,n_estimators=1,random_state=777).
          fit(x_trainb,y_trainb).estimators_[0],fontsize=10,filled=True);

# %%
bal['RandomForestClassifier'] = [accuracy_score(y_testb,y_rfcb),precision_score(y_testb,y_rfcb,average='weighted'),
                    recall_score(y_testb,y_rfcb,average='weighted'), f1_score(y_testb,y_rfcb,average='weighted')]

# %% [markdown]
# ## AdaBoost
# boosting ensemble technique: that is a combination of multiple weal learners \
# learning happens sequentially

# %% [markdown]
# ### training

# %%
abb = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=depth, random_state=777),
                     random_state=777,n_estimators=1)
abb.fit(x_trainb,y_trainb)

print('AdaBoost: Taining accuracy:',abb.score(x_trainb,y_trainb))
# Out:
# AdaBoost: Taining accuracy: 0.646893418272515

# %% [markdown]
# ### testing

# %%
y_abb = abb.predict(x_testb)
print('AdaBoost: Testing accuracy:',accuracy_score(y_testb,y_abb))
# Out:
# AdaBoost: Testing accuracy: 0.6440554108152761

# %% [markdown]
# ### evaluation

# %%
sns.heatmap(confusion_matrix(y_testb,y_abb),annot=True,fmt='d')
plt.xlabel('\nPredicted',fontsize=15)
plt.ylabel('Actual\n',fontsize=15)
plt.title('\nConfusion matrix\n',fontsize=15)
# Out:
# Text(0.5, 1.0, '\nConfusion matrix\n')

# %%
print('\nClassification report:')
print(classification_report(y_testb,y_abb))
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.71      0.67     10485
#            1       0.64      0.36      0.46     10546
#            2       0.65      0.86      0.74     10443
#
#     accuracy                           0.64     31474
#    macro avg       0.64      0.64      0.63     31474
# weighted avg       0.64      0.64      0.63     31474

# %%
bal['AdaBoost'] = [accuracy_score(y_testb,y_abb),precision_score(y_testb,y_abb,average='weighted'),
                    recall_score(y_testb,y_abb,average='weighted'), f1_score(y_testb,y_abb,average='weighted')]

# %% [markdown]
# # Stacking
# ensemble method in which the predictions, generated by using various machine learning algorithms, are used as inputs in a second-layer learning algorithm. This second-layer algorithm is trained to optimally combine the model predictions to form a new set of predictions

# %% [markdown]
# ### training

# %%
level0=[('dtree', DecisionTreeClassifier()),('nb',MultinomialNB())] 
level1 = LogisticRegression()

scb = StackingClassifier(estimators=level0,final_estimator=level1,cv=3).fit(x_trainb,y_trainb)
print('StackingClassifier: Training accuracy:',scb.score(x_trainb,y_trainb))
# Out:
# StackingClassifier: Training accuracy: 0.9690851033409058

# %% [markdown]
# ### testing

# %%
y_scb = scb.predict(x_testb)
print('StackingClassifier: Testing accuracy:',accuracy_score(y_testb,y_scb))
# Out:
# StackingClassifier: Testing accuracy: 0.9084323568659847

# %% [markdown]
# ### evaluation

# %%
sns.heatmap(confusion_matrix(y_testb,y_scb),annot=True,fmt='d')
plt.xlabel('\nPredicted',fontsize=15)
plt.ylabel('Actual\n',fontsize=15)
plt.title('\nConfusion matrix\n',fontsize=15)
# Out:
# Text(0.5, 1.0, '\nConfusion matrix\n')

# %%
print('\nClassification report:')
print(classification_report(y_testb,y_scb))
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94     10485
#            1       0.88      0.89      0.88     10546
#            2       0.91      0.90      0.90     10443
#
#     accuracy                           0.91     31474
#    macro avg       0.91      0.91      0.91     31474
# weighted avg       0.91      0.91      0.91     31474

# %%
bal['StackingClassifier'] = [accuracy_score(y_testb,y_scb),precision_score(y_testb,y_scb,average='weighted'),
                    recall_score(y_testb,y_scb,average='weighted'), f1_score(y_testb,y_scb,average='weighted')]

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ### training

# %%
score = dict()
up = 200

for i in range(100,up,50):
    temp_lr = LogisticRegression(max_iter=i)
    temp_ovr = OneVsRestClassifier(temp_lr).fit(x_trainb,y_trainb) 
    
    temp_score = temp_ovr.score(x_testb,y_testb)
    score[i] = temp_score
    
best_i = max(score,key=lambda i:score[i])
print('Best i =',best_i)
# Out:
# Best i = 100

# %%
lrb = LogisticRegression(max_iter=best_i)
ovrb = OneVsRestClassifier(lrb)
ovrb.fit(x_trainb, y_trainb)

print('StackingClassifier: Training accuracy:',ovrb.score(x_trainb,y_trainb))
# Out:
# StackingClassifier: Training accuracy: 0.8734252625224395

# %% [markdown]
# ### testing

# %%
y_lrb = ovrb.predict(x_testb)
print('LogisticRegression: Testing accuracy:',accuracy_score(y_testb,y_lrb))
# Out:
# LogisticRegression: Testing accuracy: 0.8606151108851751

# %% [markdown]
# ### evaluation

# %%
sns.heatmap(confusion_matrix(y_testb,y_lrb),annot=True,fmt='d')
plt.xlabel('\nPredicted',fontsize=15)
plt.ylabel('Actual\n',fontsize=15)
plt.title('\nConfusion matrix\n',fontsize=15)
# Out:
# Text(0.5, 1.0, '\nConfusion matrix\n')

# %%
print('\nClassification report:')
print(classification_report(y_testb,y_lrb))
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.90     10485
#            1       0.82      0.81      0.81     10546
#            2       0.89      0.86      0.87     10443
#
#     accuracy                           0.86     31474
#    macro avg       0.86      0.86      0.86     31474
# weighted avg       0.86      0.86      0.86     31474

# %%
bal['LogisticRegression'] = [accuracy_score(y_testb,y_lrb),precision_score(y_testb,y_lrb,average='weighted'),
                    recall_score(y_testb,y_lrb,average='weighted'), f1_score(y_testb,y_lrb,average='weighted')]

# %% [markdown]
# ## Comparison

# %% [markdown]
# on unbalanced data

# %%
imbal.T.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_12cca_row0_col0, #T_12cca_row0_col2 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_12cca_row0_col1 {
#   background-color: #fb7757;
#   color: #f1f1f1;
# }
# #T_12cca_row0_col3 {
#   background-color: #fdd3c1;
#   color: #000000;
# }
# #T_12cca_row1_col0, #T_12cca_row1_col2, #T_12cca_row1_col3, #T_12cca_row2_col1, #T_12cca_row4_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_12cca_row1_col1 {
#   background-color: #fcb79c;
#   color: #000000;
# }
# #T_12cca_row2_col0, #T_12cca_row2_col2, #T_12cca_row3_col0, #T_12cca_row3_col2, #T_12cca_row4_col0, #T_12cca_row4_col2 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_12cca_row2_col3, #T_12cca_row3_col1, #T_12cca_row4_col3 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_12cca_row3_col3 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_12cca_row5_col0, #T_12cca_row5_col2 {
#   background-color: #f7593f;
#   color: #f1f1f1;
# }
# #T_12cca_row5_col1 {
#   background-color: #c8171c;
#   color: #f1f1f1;
# }
# #T_12cca_row5_col3 {
#   background-color: #e43027;
#   color: #f1f1f1;
# }
# #T_12cca_row6_col0, #T_12cca_row6_col1, #T_12cca_row6_col2, #T_12cca_row6_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_12cca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12cca_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_12cca_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_12cca_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_12cca_level0_col3" class="col_heading level0 col3" >f1_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12cca_level0_row0" class="row_heading level0 row0" >KNeighborsClassifier</th>
#       <td id="T_12cca_row0_col0" class="data row0 col0" >0.873445</td>
#       <td id="T_12cca_row0_col1" class="data row0 col1" >0.829625</td>
#       <td id="T_12cca_row0_col2" class="data row0 col2" >0.873445</td>
#       <td id="T_12cca_row0_col3" class="data row0 col3" >0.822567</td>
#     </tr>
#     <tr>
#       <th id="T_12cca_level0_row1" class="row_heading level0 row1" >MultinomialNB</th>
#       <td id="T_12cca_row1_col0" class="data row1 col0" >0.870957</td>
#       <td id="T_12cca_row1_col1" class="data row1 col1" >0.812864</td>
#       <td id="T_12cca_row1_col2" class="data row1 col2" >0.870957</td>
#       <td id="T_12cca_row1_col3" class="data row1 col3" >0.811842</td>
#     </tr>
#     <tr>
#       <th id="T_12cca_level0_row2" class="row_heading level0 row2" >DecisionTreeClassifier</th>
#       <td id="T_12cca_row2_col0" class="data row2 col0" >0.871289</td>
#       <td id="T_12cca_row2_col1" class="data row2 col1" >0.790493</td>
#       <td id="T_12cca_row2_col2" class="data row2 col2" >0.871289</td>
#       <td id="T_12cca_row2_col3" class="data row2 col3" >0.813913</td>
#     </tr>
#     <tr>
#       <th id="T_12cca_level0_row3" class="row_heading level0 row3" >RandomForestClassifier</th>
#       <td id="T_12cca_row3_col0" class="data row3 col0" >0.871289</td>
#       <td id="T_12cca_row3_col1" class="data row3 col1" >0.793411</td>
#       <td id="T_12cca_row3_col2" class="data row3 col2" >0.871289</td>
#       <td id="T_12cca_row3_col3" class="data row3 col3" >0.813380</td>
#     </tr>
#     <tr>
#       <th id="T_12cca_level0_row4" class="row_heading level0 row4" >AdaBoost</th>
#       <td id="T_12cca_row4_col0" class="data row4 col0" >0.871289</td>
#       <td id="T_12cca_row4_col1" class="data row4 col1" >0.790493</td>
#       <td id="T_12cca_row4_col2" class="data row4 col2" >0.871289</td>
#       <td id="T_12cca_row4_col3" class="data row4 col3" >0.813913</td>
#     </tr>
#     <tr>
#       <th id="T_12cca_level0_row5" class="row_heading level0 row5" >StackingClassifier</th>
#       <td id="T_12cca_row5_col0" class="data row5 col0" >0.886797</td>
#       <td id="T_12cca_row5_col1" class="data row5 col1" >0.855225</td>
#       <td id="T_12cca_row5_col2" class="data row5 col2" >0.886797</td>
#       <td id="T_12cca_row5_col3" class="data row5 col3" >0.853662</td>
#     </tr>
#     <tr>
#       <th id="T_12cca_level0_row6" class="row_heading level0 row6" >LogisticRegression</th>
#       <td id="T_12cca_row6_col0" class="data row6 col0" >0.899983</td>
#       <td id="T_12cca_row6_col1" class="data row6 col1" >0.875804</td>
#       <td id="T_12cca_row6_col2" class="data row6 col2" >0.899983</td>
#       <td id="T_12cca_row6_col3" class="data row6 col3" >0.875003</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# on balanced data

# %%
bal.T.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_b7664_row0_col0, #T_b7664_row0_col2 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_b7664_row0_col1 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_b7664_row0_col3 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_b7664_row1_col0, #T_b7664_row1_col2, #T_b7664_row3_col0, #T_b7664_row3_col2 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_b7664_row1_col1, #T_b7664_row3_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_b7664_row1_col3, #T_b7664_row3_col3 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_b7664_row2_col0, #T_b7664_row2_col1, #T_b7664_row2_col2, #T_b7664_row2_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b7664_row4_col0, #T_b7664_row4_col1, #T_b7664_row4_col2, #T_b7664_row4_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b7664_row5_col0, #T_b7664_row5_col2 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_b7664_row5_col1 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_b7664_row5_col3 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b7664">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7664_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_b7664_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_b7664_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_b7664_level0_col3" class="col_heading level0 col3" >f1_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7664_level0_row0" class="row_heading level0 row0" >MultinomialNB</th>
#       <td id="T_b7664_row0_col0" class="data row0 col0" >0.826301</td>
#       <td id="T_b7664_row0_col1" class="data row0 col1" >0.827230</td>
#       <td id="T_b7664_row0_col2" class="data row0 col2" >0.826301</td>
#       <td id="T_b7664_row0_col3" class="data row0 col3" >0.826419</td>
#     </tr>
#     <tr>
#       <th id="T_b7664_level0_row1" class="row_heading level0 row1" >DecisionTreeClassifier</th>
#       <td id="T_b7664_row1_col0" class="data row1 col0" >0.643833</td>
#       <td id="T_b7664_row1_col1" class="data row1 col1" >0.643441</td>
#       <td id="T_b7664_row1_col2" class="data row1 col2" >0.643833</td>
#       <td id="T_b7664_row1_col3" class="data row1 col3" >0.624786</td>
#     </tr>
#     <tr>
#       <th id="T_b7664_level0_row2" class="row_heading level0 row2" >RandomForestClassifier</th>
#       <td id="T_b7664_row2_col0" class="data row2 col0" >0.574538</td>
#       <td id="T_b7664_row2_col1" class="data row2 col1" >0.586402</td>
#       <td id="T_b7664_row2_col2" class="data row2 col2" >0.574538</td>
#       <td id="T_b7664_row2_col3" class="data row2 col3" >0.566444</td>
#     </tr>
#     <tr>
#       <th id="T_b7664_level0_row3" class="row_heading level0 row3" >AdaBoost</th>
#       <td id="T_b7664_row3_col0" class="data row3 col0" >0.644055</td>
#       <td id="T_b7664_row3_col1" class="data row3 col1" >0.643626</td>
#       <td id="T_b7664_row3_col2" class="data row3 col2" >0.644055</td>
#       <td id="T_b7664_row3_col3" class="data row3 col3" >0.625066</td>
#     </tr>
#     <tr>
#       <th id="T_b7664_level0_row4" class="row_heading level0 row4" >StackingClassifier</th>
#       <td id="T_b7664_row4_col0" class="data row4 col0" >0.908432</td>
#       <td id="T_b7664_row4_col1" class="data row4 col1" >0.908495</td>
#       <td id="T_b7664_row4_col2" class="data row4 col2" >0.908432</td>
#       <td id="T_b7664_row4_col3" class="data row4 col3" >0.908427</td>
#     </tr>
#     <tr>
#       <th id="T_b7664_level0_row5" class="row_heading level0 row5" >LogisticRegression</th>
#       <td id="T_b7664_row5_col0" class="data row5 col0" >0.860615</td>
#       <td id="T_b7664_row5_col1" class="data row5 col1" >0.860429</td>
#       <td id="T_b7664_row5_col2" class="data row5 col2" >0.860615</td>
#       <td id="T_b7664_row5_col3" class="data row5 col3" >0.860345</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### OBSERVATION
# inorder to decide the best comparitive model:
# 1. overall metrics
# 2. individual f1 scores
#
# after balancing all the evaluations metrics have decreased for all the models except StackingClassifier \
# though the evaluation metrics has decreased
#
# on comparing the confusion matrices and the evaluation metrics- **StackingClassifier** trained on balanced data is comparitively the best model

# %% [markdown]
# ---

# %%
# for reusability
df = data.copy()

# %%
xp = df['reviewText']
Xp = tfidf.transform(xp)

# %%
df['predicted'] = scb.predict(Xp)

# %%
df['predicted'].replace({2:'Positive',1:'Neutral',0:'Negative'},inplace=True)
df.head()
# Out:
#    overall  verified reviewTime        asin  \
# 0      3.0      True 2014-02-23  0545346193
# 1      4.0      True 2012-11-14  0545346193
# 2      5.0      True 2015-02-11  0545346193
# 3      5.0      True 2015-01-04  0545346193
# 4      4.0      True 2016-02-14  0545346193
#
#                                           reviewText  \
# 0  packaging draw dc universe look easy think twi...
# 1  year old took drawing time high school wa not ...
# 2                        little artist love kit star
# 3                           love delivered time star
# 4  useful want train muscle memory tracing improv...
#
#                                              summary  \
# 0  Great Idea But Needs More Instructions & Detai...
# 1                                 Good for beginners
# 2                                         Five Stars
# 3                                         Five Stars
# 4                             Great Drawing Practice
#
#                                           category  brand  price sentiment  \
# 0  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92   Neutral
# 1  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92  Positive
# 2  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92  Positive
# 3  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92  Positive
# 4  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92  Positive
#
#   predicted
# 0  Positive
# 1   Neutral
# 2  Positive
# 3  Positive
# 4  Positive

# %% [markdown]
# ### Products with positive sentiment

# %%
Positive = df[df['predicted']=='Positive']
Positive.head()
# Out:
#    overall  verified reviewTime        asin  \
# 0      3.0      True 2014-02-23  0545346193
# 2      5.0      True 2015-02-11  0545346193
# 3      5.0      True 2015-01-04  0545346193
# 4      4.0      True 2016-02-14  0545346193
# 5      5.0      True 2015-10-16  0545346193
#
#                                           reviewText  \
# 0  packaging draw dc universe look easy think twi...
# 2                        little artist love kit star
# 3                           love delivered time star
# 4  useful want train muscle memory tracing improv...
# 5                       daughter loved dc comic star
#
#                                              summary  \
# 0  Great Idea But Needs More Instructions & Detai...
# 2                                         Five Stars
# 3                                         Five Stars
# 4                             Great Drawing Practice
# 5                                         Five Stars
#
#                                           category  brand  price sentiment  \
# 0  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92   Neutral
# 2  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92  Positive
# 3  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92  Positive
# 4  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92  Positive
# 5  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92  Positive
#
#   predicted
# 0  Positive
# 2  Positive
# 3  Positive
# 4  Positive
# 5  Positive

# %% [markdown]
# Wordcloud is a visualization technique to represent the frequency of words in a text where the size of the word represents its frequency

# %%
from wordcloud import WordCloud,STOPWORDS

# %%
print('Most frequent words of review that classifies the product as Positive:')
wordcloud = WordCloud( width = 3000, height = 1000, background_color = 'black', 
                      stopwords = STOPWORDS).generate(str(Positive['reviewText']))

fig = plt.figure( figsize = (40, 20), facecolor = 'k', edgecolor = 'k')
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
# Out:
# Most frequent words of review that classifies the product as Positive:

# %%
print('Of AMAZON number of products with positive sentiment')
len(Positive['asin'])/len(df)*100
# Out:
# Of AMAZON number of products with positive sentiment
# 81.7007498380645

# %%
print('Of AMAZON number of categories with positive sentiment')
len(Positive['category'])/len(df)*100
# Out:
# Of AMAZON number of categories with positive sentiment
# 81.7007498380645

# %%
print('Of AMAZON number of brands with positive sentiment')
len(Positive['brand'])/len(df)*100
# Out:
# Of AMAZON number of brands with positive sentiment
# 81.7007498380645

# %%
pos_cat = dict()
for i in Positive['category'].unique():
    pos_cat[i] = Positive.groupby('category').get_group(i)['overall'].mean()

# %%
print('Top 5 categories with positive products:')
sorted(pos_cat,key=lambda i:pos_cat[i],reverse=True)[:5]
# Out:
# Top 5 categories with positive products:
# ['[\'Toys & Games\', \'Party Supplies\', \'Party Hats\', \'38.1 centimeters high\', \'20.32 centimeters wide\', \'Fabric lining, secret pocket with fortune\', \'Velcro size adjuster\', \'Kids\\\' size, ages 3-12, fits 5556 cm heads 21.75"\', \'Velvet, satin\']',
#  "['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Remote & App Controlled Vehicle Parts', 'Power Plant & Driveline Systems', 'Brakes']",
#  '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Accessories\', \'Polyester\', \'Imported\', \'1" high\', \'6" wide\', \'Costume sound effect creating accessory\', \'Star Wars is officially licensed by Lucasfilms\', \'Produces the distinctive heavy breathing sound from the original movie\']',
#  '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Hats\', \'Includes cap with elastic back, propeller.\', \'This Tweedledee Twill is an officially licensed Alice In Wonderland costume accessory.\', "Please note: This item\'s color may vary due to inherent manufacturing variations or your computer monitor\'s color settings. The item you receive will be identical or substantially similar to the item pictured in this listing.", \'elope, Inc.\', \'Spot clean air dry only\', \'Costumes\']',
#  "['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play', 'Plastic', 'Silver rings that slide over nose or lip to look like piercings.Silver color.', 'Manufacturer minimum age: 48 Months']"]

# %%
print('Bottom 5 categories with positive products:')
sorted(pos_cat,key=lambda i:pos_cat[i],reverse=False)[:5]
# Out:
# Bottom 5 categories with positive products:
# ['[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Costumes\', \'100% Synthetic Fiber\', \'Imported\', \'3-Piece face and body hair kit\', \'Includes moustache, chest hair and sideburns\', "Black 70\'s Afro wig available separately from Forum", "Part of the 70\'s Disco Fever collection", "Look to Forum Novelties for all your Halloween, Luau, Easter, Mardi Gras and St. Patrick\'s Day supplies", \'Designed for ages 14 + adult\']',
#  '[\'Toys & Games\', \'Novelty & Gag Toys\', \'Gag Toys & Practical Jokes\', \'Plastic\', \'1.5" high\', \'7" wide\', \'Change your voice to match your costume with this Voice Disguiser with Microphone\', \'Features four different voices: Space Alien, Witch, Voice from Beyond, Scary Monster\', \'Fun for Halloween or any other day\', \'Includes special effects sound box and microphone\']',
#  '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Accessories\', \'Plastic\', \'Imported\', \'3.04 centimeters high\', \'3.04 centimeters wide\', "Rubie\'s Costume Harry Potter, Ron Weasley Wand", "Ron Weasley\'s wand", \'13.675-Inches Long\']',
#  '[\'Toys & Games\', \'Party Supplies\', \'Plastic\', \'Latex winged costume helmet\', \'Officially licensed Marvel Universe merchandise inspired by the Disney XD cartoon Avengers Assemble\', \'One size fits most children under 10 years old\', \'Rubies and Marvel have teamed up to bring you costumes and accessories featuring all of your favorite heroes and villains\', "Family owned and family focused, Rubies\' has been a world leader in bringing you fun for every season since 1950"]',
#  '[\'Toys & Games\', \'Action Figures & Statues\', \'Playsets & Vehicles\', \'Playsets\', \'17" high\', \'2.5" wide\', \'Includes holster\', \'Includes blaster\', \'One size fits most adults and big kids\', \'Officially licensed Star Wars costume\', \'Rubies makes dress-up fun for all ages\']']

# %%
pos_brand = dict()
for i in Positive['brand'].unique():
    pos_brand[i] = Positive.groupby('brand').get_group(i)['overall'].mean()

# %%
print('Top 5 brands with positive products:')
sorted(pos_brand,key=lambda i:pos_brand[i],reverse=True)[:5]
# Out:
# Top 5 brands with positive products:
# ['Galison',
#  'Ditty Bird',
#  'Beanie Baby',
#  'Beanie Babies - Sea Life',
#  'eaglecollector83']

# %%
print('Bottom 5 brands with positive products:')
sorted(pos_brand,key=lambda i:pos_brand[i],reverse=False)[:5]
# Out:
# Bottom 5 brands with positive products:
# ['Insect House', 'Girl Gourmet', 'Artesania Latina', 'Assortmart', 'Winlow']

# %% [markdown]
# ---

# %% [markdown]
# ### Products with negative sentiment

# %%
Negative = df[df['predicted']=='Negative']
Negative.head()
# Out:
#      overall  verified reviewTime        asin  \
# 6        4.0      True 2017-08-18  0545561647
# 17       1.0      True 2017-01-17  0545561647
# 46       5.0      True 2015-06-19  0545561647
# 95       2.0      True 2015-03-13  0615638996
# 107      3.0      True 2017-01-19  0641869665
#
#                                             reviewText  \
# 6    need hobby bought kit instruction easy follow ...
# 17   booo unles patient know measure not patience n...
# 46   gift packaging product good packaging product ...
# 95   uno type game anger control stuff not like you...
# 107  son love book wa disappointed cheaply wing wa ...
#
#                                                summary  \
# 6                      Need more yarn & a hot glue gun
# 17   BORING UNLESS YOU ARE A CRAFT PERSON WHICH I A...
# 46                      packaging and product is good!
# 95                                   Bit dissapointed.
# 107  Poorly Made and will require needle/thread rep...
#
#                                               category            brand  \
# 6      ['Toys & Games', 'Arts & Crafts', 'Craft Kits']            Klutz
# 17     ['Toys & Games', 'Arts & Crafts', 'Craft Kits']            Klutz
# 46     ['Toys & Games', 'Arts & Crafts', 'Craft Kits']            Klutz
# 95             ['Toys & Games', 'Games', 'Card Games']  Therapy Game HQ
# 107  ['Toys & Games', 'Stuffed Animals & Plush Toys...           Yottoy
#
#      price sentiment predicted
# 6    17.45  Positive  Negative
# 17   17.45  Negative  Negative
# 46   17.45  Positive  Negative
# 95   19.95  Negative  Negative
# 107  22.51   Neutral  Negative

# %%
print('Most frequent words of review that classifies the product as Negative:')
wordcloud = WordCloud( width = 3000, height = 1000, background_color = 'black', 
                      stopwords = STOPWORDS).generate(str(Negative['reviewText']))

fig = plt.figure( figsize = (40, 20), facecolor = 'k', edgecolor = 'k')
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
# Out:
# Most frequent words of review that classifies the product as Negative:

# %%
print('Of AMAZON number of products with negative sentiment')
len(Negative['asin'])/len(df)*100
# Out:
# Of AMAZON number of products with negative sentiment
# 7.281996670888185

# %%
print('Of AMAZON number of categories with negative sentiment')
len(Negative['category'])/len(df)*100
# Out:
# Of AMAZON number of categories with negative sentiment
# 7.281996670888185

# %%
print('Of AMAZON number of brands with negative sentiment')
len(Negative['brand'])/len(df)*100
# Out:
# Of AMAZON number of brands with negative sentiment
# 7.281996670888185

# %%
neg_cat = dict()
for i in Negative['category'].unique():
    neg_cat[i] = Negative.groupby('category').get_group(i)['overall'].mean()

# %%
print('Top 5 categories with negative products:')
sorted(neg_cat,key=lambda i:neg_cat[i],reverse=True)[:5]
# Out:
# Top 5 categories with negative products:
# ['[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Wigs\', \'Synthetic Acrylic Hair\', \'Made in USA or Imported\', \'1.5" high\', \'7.5" wide\', \'Give every little girl Dorothy hair\', \'Brown with braids\', \'One size fits most children\']',
#  "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', '100% Woven poly poplin, washable', 'Does not include Hat And Sword']",
#  "['Toys & Games', 'Party Supplies', 'plastic', 'Plastic. Phoney Dynamite party accessory']",
#  '[\'Toys & Games\', \'Dolls & Accessories\', \'Doll Accessories\', \'Plastic.\', \'Imported\', \'1.5" high\', \'9.75" wide\', \'Plastic construction\', \'The weapon of choice to fight the Dark Side\', \'Black and silver with orange tip for safe play\']',
#  "['Toys & Games', 'Baby & Toddler Toys', 'Mirrors']"]

# %%
print('Bottom 5 categories with negative products:')
sorted(neg_cat,key=lambda i:neg_cat[i],reverse=False)[:5]
# Out:
# Bottom 5 categories with negative products:
# ["['Toys & Games', 'Hobbies', 'Remote & App Controlled Vehicles & Parts', 'Fuel']",
#  "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', '100% acrylic', 'Tiger Costume for Children.', 'Four sizes. 4-6, 6-8, 8-10 and 10-12 Years.', 'Costume includes jumpsuit with tail , mittens and hood.', 'Machine washable. 100% Acrylic.', 'Conforms to European & North American safety regulations. As a precaution keep away from fire. For more information view the product details below.']",
#  "['Toys & Games', 'Party Supplies', 'Looks like a gold chain']",
#  "['Toys & Games', 'Hobbies', 'Trains & Accessories', 'Accessories', 'Vehicles, Boats & Airplanes']",
#  '[\'Toys & Games\', \'Novelty & Gag Toys\', \'Gag Toys & Practical Jokes\', \'Plastic\', \'0.75" high\', \'5.2" wide\', \'Prop lollipop in light-weight plastic\', \'9-inches tall x 5-inches wide\', \'Brightly colored\', \'Great for munchkins of all ages\', \'Look to Forum Novelties for gag gifts and other fun party props\']']

# %%
neg_brand = dict()
for i in Negative['brand'].unique():
    neg_brand[i] = Negative.groupby('brand').get_group(i)['overall'].mean()

# %%
print('Top 5 brands with negative products:')
sorted(neg_brand,key=lambda i:neg_brand[i],reverse=True)[:5]
# Out:
# Top 5 brands with negative products:
# ['Ditty Bird', 'Paizo Inc.', 'Pockets Of Learning', 'Zomma', 'Playstar']

# %%
print('Bottom 5 brands with negative products:')
sorted(neg_brand,key=lambda i:neg_brand[i],reverse=False)[:5]
# Out:
# Bottom 5 brands with negative products:
# ['STORY EGG',
#  'Jakks',
#  'Vintage Sports Cards',
#  'Professor Noggin',
#  'Bob Smith Ind Glue']

# %% [markdown]
# ---

# %% [markdown]
# ### Products with neutral sentiment

# %%
Neutral = df[df['predicted']=='Neutral']
Neutral.head()
# Out:
#     overall  verified reviewTime        asin  \
# 1       4.0      True 2012-11-14  0545346193
# 11      3.0      True 2017-03-01  0545561647
# 16      2.0     False 2017-01-21  0545561647
# 20      3.0      True 2016-09-15  0545561647
# 24      4.0      True 2016-07-18  0545561647
#
#                                            reviewText  \
# 1   year old took drawing time high school wa not ...
# 11  okay rate not easy apply ear eye stay definite...
# 16  cute idea basic step sense easy follow parent ...
# 20  hard year old supervision wa frustrating know ...
# 24  wa present year old daughter far puppy yes klu...
#
#                                               summary  \
# 1                                  Good for beginners
# 11  it isn't easy to apply the ears and eyes and h...
# 16  and the basic steps make sense are are easy to...
# 20                        Cute but a little difficult
# 24                    Fun craft to to with older kids
#
#                                            category  brand  price sentiment  \
# 1   ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  12.92  Positive
# 11  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  17.45   Neutral
# 16  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  17.45  Negative
# 20  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  17.45   Neutral
# 24  ['Toys & Games', 'Arts & Crafts', 'Craft Kits']  Klutz  17.45  Positive
#
#    predicted
# 1    Neutral
# 11   Neutral
# 16   Neutral
# 20   Neutral
# 24   Neutral

# %%
print('Most frequent words of review that classifies the product as Neutral:')
wordcloud = WordCloud( width = 3000, height = 1000, background_color = 'black', 
                      stopwords = STOPWORDS).generate(str(Neutral['reviewText']))

fig = plt.figure( figsize = (40, 20), facecolor = 'k', edgecolor = 'k')
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
# Out:
# Most frequent words of review that classifies the product as Neutral:

# %%
print('Of AMAZON number of products with neutral sentiment')
len(Neutral['asin'])/len(df)*100
# Out:
# Of AMAZON number of products with neutral sentiment
# 11.01725349104731

# %%
print('Of AMAZON number of categories with neutral sentiment')
len(Neutral['category'])/len(df)*100
# Out:
# Of AMAZON number of categories with neutral sentiment
# 11.01725349104731

# %%
print('Of AMAZON number of brands with neutral sentiment')
len(Neutral['brand'])/len(df)*100
# Out:
# Of AMAZON number of brands with neutral sentiment
# 11.01725349104731

# %%
neu_cat = dict()
for i in Neutral['category'].unique():
    neu_cat[i] = Neutral.groupby('category').get_group(i)['overall'].mean()

# %%
print('Top 5 categories with neutral products:')
sorted(neu_cat,key=lambda i:neu_cat[i],reverse=True)[:5]
# Out:
# Top 5 categories with neutral products:
# ["['Toys & Games', 'Hobbies', 'Hobby Building Tools & Hardware', 'RC Linkages']",
#  '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Hats\', \'Includes cap with elastic back, propeller.\', \'This Tweedledee Twill is an officially licensed Alice In Wonderland costume accessory.\', "Please note: This item\'s color may vary due to inherent manufacturing variations or your computer monitor\'s color settings. The item you receive will be identical or substantially similar to the item pictured in this listing.", \'elope, Inc.\', \'Spot clean air dry only\', \'Costumes\']',
#  "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', '100% acrylic', 'Tiger Costume for Children.', 'Four sizes. 4-6, 6-8, 8-10 and 10-12 Years.', 'Costume includes jumpsuit with tail , mittens and hood.', 'Machine washable. 100% Acrylic.', 'Conforms to European & North American safety regulations. As a precaution keep away from fire. For more information view the product details below.']",
#  "['Toys & Games', 'Novelty & Gag Toys', 'Very Soft and Absorbent', 'Wears for hours without discomfort', 'Made of ultra lite poly foam', 'Pre-slit', 'Made in USA']",
#  "['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', 'Polyester', 'Product comes complete with: Plush Jumpsuit with attached head', 'Set packaged in durable snap-sealed poly bag', 'Gentle Machine Washable ~ Flame Retardant', 'Costume is made of a soft high quality fabric']"]

# %%
print('Bottom 5 categories with neutral products:')
sorted(neu_cat,key=lambda i:neu_cat[i],reverse=False)[:5]
# Out:
# Bottom 5 categories with neutral products:
# ['[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Accessories\', \'Fun costumes for kids and adults\', "Whether it\'s for Halloween, a themed party, or even for giggles", \'Beautiful colors, hand-wash needed, excellent for dress up\']',
#  '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Beauty & Fashion\', \'Includes 4 sets of clip-on earrings jewelry; Shown as picture\', \'Perfect accessories for dressing up your girl for birthday parties and other fanciful occasions\', "It\'s a good gift to your princess."]',
#  '[\'Toys & Games\', \'Dress Up & Pretend Play\', \'Costumes\', \'100% Synthetic Fiber\', \'Imported\', \'3-Piece face and body hair kit\', \'Includes moustache, chest hair and sideburns\', "Black 70\'s Afro wig available separately from Forum", "Part of the 70\'s Disco Fever collection", "Look to Forum Novelties for all your Halloween, Luau, Easter, Mardi Gras and St. Patrick\'s Day supplies", \'Designed for ages 14 + adult\']',
#  "['Toys & Games', 'Hobbies', 'Trains & Accessories', 'Accessories', 'Bridges & Tunnels', 'Bridges']",
#  '[\'Toys & Games\', \'Action Figures & Statues\', \'Action Figures\', \'Polyester\', \'Made in USA or Imported\', \'1" high\', \'12" wide\', \'Inflatable jetpack\', \'Suitable for ages 4 and up\', \'Measures 30" in length\']']

# %%
neu_brand = dict()
for i in Neutral['brand'].unique():
    neu_brand[i] = Neutral.groupby('brand').get_group(i)['overall'].mean()

# %%
print('Top 5 brands with neutral products:')
sorted(neu_brand,key=lambda i:neu_brand[i],reverse=True)[:5]
# Out:
# Top 5 brands with neutral products:
# ['Galison',
#  'US Games',
#  'Beyond123',
#  'Daron Worldwide Trading inc',
#  'Smethport']

# %%
print('Bottom 5 brands with neutral products:')
sorted(neu_brand,key=lambda i:neu_brand[i],reverse=False)[:5]
# Out:
# Bottom 5 brands with neutral products:
# ['G.I. Joe',
#  'PL',
#  'Roy Toy',
#  'Ty Chance / Holsteiner (Brown)',
#  'Selchow & Righter']

# %% [raw]
# Positive.to_csv('F:/NIIT/Capstone Project/Positive.csv')
# Negative.to_csv('F:/NIIT/Capstone Project/Negative.csv')
# Neutral.to_csv('F:/NIIT/Capstone Project/Neutral.csv')

# %% [markdown]
# ---

# %% [markdown]
# # Inventory optimization: Clustering
# Clustering is grouping of like objects together
# Clustering of categories on the basis of rating and Total Sales

# %% [markdown]
# ### Clustering with respect to category

# %%
cat_count = df['category'].value_counts().to_frame()
cat_rating = df.groupby('category')['overall'].mean().to_frame()
cat_price = df.groupby('category')['price'].mean().to_frame()
cat_sales = df.groupby('category')['price'].sum().to_frame().rename(columns={'price':'sales'})

df_cat = cat_count.join(cat_rating).join(cat_price).join(cat_sales)
df_cat.head()
# Out:
#                                                     category   overall  \
# ['Toys & Games', 'Action Figures & Statues', 'A...     87998  4.558592
# ['Toys & Games', 'Building Toys', 'Building Sets']     72554  4.683794
# ['Toys & Games', 'Dolls & Accessories', 'Dolls']       63726  4.612136
# ['Toys & Games', 'Games', 'Board Games']               58258  4.496430
# ['Toys & Games', 'Stuffed Animals & Plush Toys'...     41665  4.711076
#
#                                                         price       sales
# ['Toys & Games', 'Action Figures & Statues', 'A...  39.438923  3470546.36
# ['Toys & Games', 'Building Toys', 'Building Sets']  64.467419  4677369.12
# ['Toys & Games', 'Dolls & Accessories', 'Dolls']    43.029306  2742085.58
# ['Toys & Games', 'Games', 'Board Games']            28.385488  1653681.75
# ['Toys & Games', 'Stuffed Animals & Plush Toys'...  20.734315   863895.23

# %%
df_cat = df_cat.reset_index().rename(columns={'index':'category','category':'Freq'})
df_cat.head(3)
# Out:
#                                             category   Freq   overall  \
# 0  ['Toys & Games', 'Action Figures & Statues', '...  87998  4.558592
# 1  ['Toys & Games', 'Building Toys', 'Building Se...  72554  4.683794
# 2   ['Toys & Games', 'Dolls & Accessories', 'Dolls']  63726  4.612136
#
#        price       sales
# 0  39.438923  3470546.36
# 1  64.467419  4677369.12
# 2  43.029306  2742085.58

# %% [markdown]
# ### Feature engineering
# transforming data to machine understandable and processable form

# %%
df_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 642 entries, 0 to 641
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  642 non-null    object
#  1   Freq      642 non-null    int64
#  2   overall   642 non-null    float64
#  3   price     642 non-null    float64
#  4   sales     642 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 25.2+ KB

# %% [markdown]
# ### Feature scaling
# the numeric distribution is normalized/standardized to boost the model performance

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

df_cat_num = df_cat.select_dtypes('number')
df_cat_num=df_cat_num.drop(['Freq','price'],axis=1)
df_cat_num_scaled = scaler.fit_transform(df_cat_num)

# %% [markdown]
# ### Feature selection
# method of reducing the input variable to the model by using only relevant data and getting rid of noise in data

# %%
df_cat.corr().style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_857b7_row0_col0, #T_857b7_row1_col1, #T_857b7_row2_col2, #T_857b7_row3_col3 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_857b7_row0_col1, #T_857b7_row1_col2 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_857b7_row0_col2, #T_857b7_row1_col3, #T_857b7_row2_col0, #T_857b7_row2_col1, #T_857b7_row3_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_857b7_row0_col3, #T_857b7_row3_col0 {
#   background-color: #4b1687;
#   color: #f1f1f1;
# }
# #T_857b7_row1_col0 {
#   background-color: #f8f7fb;
#   color: #000000;
# }
# #T_857b7_row2_col3 {
#   background-color: #f8f6fa;
#   color: #000000;
# }
# #T_857b7_row3_col2 {
#   background-color: #f6f4f9;
#   color: #000000;
# }
# </style>
# <table id="T_857b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_857b7_level0_col0" class="col_heading level0 col0" >Freq</th>
#       <th id="T_857b7_level0_col1" class="col_heading level0 col1" >overall</th>
#       <th id="T_857b7_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_857b7_level0_col3" class="col_heading level0 col3" >sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_857b7_level0_row0" class="row_heading level0 row0" >Freq</th>
#       <td id="T_857b7_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_857b7_row0_col1" class="data row0 col1" >0.106723</td>
#       <td id="T_857b7_row0_col2" class="data row0 col2" >0.072316</td>
#       <td id="T_857b7_row0_col3" class="data row0 col3" >0.933295</td>
#     </tr>
#     <tr>
#       <th id="T_857b7_level0_row1" class="row_heading level0 row1" >overall</th>
#       <td id="T_857b7_row1_col0" class="data row1 col0" >0.106723</td>
#       <td id="T_857b7_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_857b7_row1_col2" class="data row1 col2" >0.088326</td>
#       <td id="T_857b7_row1_col3" class="data row1 col3" >0.089658</td>
#     </tr>
#     <tr>
#       <th id="T_857b7_level0_row2" class="row_heading level0 row2" >price</th>
#       <td id="T_857b7_row2_col0" class="data row2 col0" >0.072316</td>
#       <td id="T_857b7_row2_col1" class="data row2 col1" >0.088326</td>
#       <td id="T_857b7_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_857b7_row2_col3" class="data row2 col3" >0.129263</td>
#     </tr>
#     <tr>
#       <th id="T_857b7_level0_row3" class="row_heading level0 row3" >sales</th>
#       <td id="T_857b7_row3_col0" class="data row3 col0" >0.933295</td>
#       <td id="T_857b7_row3_col1" class="data row3 col1" >0.089658</td>
#       <td id="T_857b7_row3_col2" class="data row3 col2" >0.129263</td>
#       <td id="T_857b7_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Modelling
# Models: KMeans (distance), Heirarchial Agglomerative Clustering (heirarchy), DBSCAN (density)

# %%
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.metrics import silhouette_samples, silhouette_score

import scipy.cluster.hierarchy as sch
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# ### KMeans

# %%
sil_score=dict()
for i in range(2,11):
    temp=KMeans(n_clusters=i).fit(df_cat_num_scaled)
    labels=temp.labels_
    sil_score[i]=silhouette_score(df_cat_num_scaled,labels)
    
# best k unsing elbow method
wcss=dict()
for i in range(2,11):
    temp=KMeans(n_clusters=i).fit(df_cat_num_scaled)
    wcss[i]=temp.inertia_

# %%
fig,ax=plt.subplots(1,2,figsize=(17,5))

# plotting silhouette_score vs k
ax[0].plot(list(sil_score.keys()),list(sil_score.values()),marker='o',linewidth=2,markersize=10,color='r')
ax[0].set_xlabel('n_clusters')
ax[0].set_ylabel('silhouette_score')
ax[0].set_title('silhouette_score method')  
ax[0].grid()

# plotting wcss vs k
ax[1].plot(list(wcss.keys()), list(wcss.values()),marker='o',color='r',linewidth=2, markersize=10)  
ax[1].set_xlabel('n_clusters')  
ax[1].set_ylabel('wcss')
ax[1].set_title('elobw method')  
ax[1].grid()

# %% [markdown]
# From both silhouette score and elbow method:
#
# best kmeans model k = 3

# %%
kmeans = KMeans(n_clusters=3, random_state=777)
y_kmeans = kmeans.fit_predict(df_cat_num_scaled)

df_cat['pred']=y_kmeans
df_pred = pd.DataFrame({'y_kmeans':y_kmeans})

sns.relplot(data=df_cat,x='sales',y='overall',hue='pred',palette='colorblind',aspect=2)

# %% [markdown]
# ### Agglomerative Clustering

# %%
plt.figure(figsize=(30,10))
dendrogram = sch.dendrogram(sch.linkage(df_cat_num_scaled,method='ward'))

ax = plt.gca()
ax.tick_params(axis='x',which='major')

plt.axhline(y=25,linestyle='--',color='k')

plt.ylabel('Euclidian distance')
plt.title('Dendrogram')
# Out:
# Text(0.5, 1.0, 'Dendrogram')

# %% [markdown]
# #### INFERENCE
# from dendogram k = 3

# %%
hc = AgglomerativeClustering(n_clusters = 3, affinity = 'euclidean', linkage = 'ward')
y_hc = hc.fit_predict(df_cat_num_scaled)

df_cat['pred'] = y_hc
df_pred['y_hc'] = y_hc

sns.relplot(data=df_cat,x='sales',y='overall',hue='pred',palette='colorblind',aspect=2)

# %% [markdown]
# ### DBSCAN

# %%
knn = NearestNeighbors(n_neighbors=2)
neighbors = knn.fit(df_cat_num_scaled)
distances, indices = neighbors.kneighbors(df_cat_num_scaled)

# Plotting K-distance Graph
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.figure(figsize=(8,5))
plt.plot(distances)

plt.axhline(y=0.2, color='r', linestyle='--')
plt.title('K-distance Graph',fontsize=20)
plt.xlabel('Data Points sorted by distance',fontsize=14)
plt.ylabel('Epsilon',fontsize=14)
plt.show()

# %% [markdown]
# #### INFERENCE
# breaking point at epsilon = 0.2

# %%
eps = 0.2

for min_samples in range(2,50):
    
    clusterer = DBSCAN(eps=eps, min_samples=min_samples)
    cluster_labels = clusterer.fit_predict(df_cat_num_scaled)

    X = cluster_labels + 2
    y = np.bincount(X)
    i = np.nonzero(y)[0]
    results = list(zip(i,y[i]) )
    
    print('eps =',eps,'min_samples =', min_samples)
    print('obtained clusters:', results)
    print('---'*30)
# Out:
# eps = 0.2 min_samples = 2
# obtained clusters: [(1, 15), (2, 4), (3, 2), (4, 3), (5, 599), (6, 4), (7, 2), (8, 2), (9, 7), (10, 4)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 3
# obtained clusters: [(1, 21), (2, 4), (3, 599), (4, 3), (5, 4), (6, 7), (7, 4)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 4
# obtained clusters: [(1, 24), (2, 4), (3, 599), (4, 4), (5, 7), (6, 4)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 5
# obtained clusters: [(1, 38), (2, 593), (3, 5), (4, 6)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 6
# obtained clusters: [(1, 49), (2, 593)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 7
# obtained clusters: [(1, 49), (2, 593)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 8
# obtained clusters: [(1, 50), (2, 578), (3, 14)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 9
# obtained clusters: [(1, 58), (2, 572), (3, 12)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 10
# obtained clusters: [(1, 58), (2, 572), (3, 12)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 11
# obtained clusters: [(1, 71), (2, 571)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 12
# obtained clusters: [(1, 73), (2, 569)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 13
# obtained clusters: [(1, 74), (2, 568)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 14
# obtained clusters: [(1, 76), (2, 566)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 15
# obtained clusters: [(1, 78), (2, 545), (3, 19)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 16
# obtained clusters: [(1, 78), (2, 545), (3, 19)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 17
# obtained clusters: [(1, 97), (2, 545)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 18
# obtained clusters: [(1, 97), (2, 545)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 19
# obtained clusters: [(1, 97), (2, 545)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 20
# obtained clusters: [(1, 110), (2, 532)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 21
# obtained clusters: [(1, 111), (2, 531)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 22
# obtained clusters: [(1, 111), (2, 531)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 23
# obtained clusters: [(1, 111), (2, 531)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 24
# obtained clusters: [(1, 111), (2, 531)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 25
# obtained clusters: [(1, 113), (2, 529)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 26
# obtained clusters: [(1, 113), (2, 529)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 27
# obtained clusters: [(1, 115), (2, 527)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 28
# obtained clusters: [(1, 117), (2, 525)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 29
# obtained clusters: [(1, 117), (2, 525)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 30
# obtained clusters: [(1, 128), (2, 514)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 31
# obtained clusters: [(1, 128), (2, 514)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 32
# obtained clusters: [(1, 128), (2, 514)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 33
# obtained clusters: [(1, 129), (2, 513)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 34
# obtained clusters: [(1, 129), (2, 513)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 35
# obtained clusters: [(1, 131), (2, 511)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 36
# obtained clusters: [(1, 131), (2, 511)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 37
# obtained clusters: [(1, 132), (2, 510)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 38
# obtained clusters: [(1, 132), (2, 510)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 39
# obtained clusters: [(1, 133), (2, 509)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 40
# obtained clusters: [(1, 133), (2, 509)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 41
# obtained clusters: [(1, 133), (2, 509)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 42
# obtained clusters: [(1, 134), (2, 508)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 43
# obtained clusters: [(1, 134), (2, 508)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 44
# obtained clusters: [(1, 134), (2, 508)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 45
# obtained clusters: [(1, 139), (2, 503)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 46
# obtained clusters: [(1, 145), (2, 497)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 47
# obtained clusters: [(1, 145), (2, 497)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 48
# obtained clusters: [(1, 146), (2, 496)]
# ------------------------------------------------------------------------------------------
# eps = 0.2 min_samples = 49
# obtained clusters: [(1, 147), (2, 495)]
# ------------------------------------------------------------------------------------------

# %%
eps = 0.2; min_samples = 6

dbscan = DBSCAN(eps=eps, min_samples=min_samples)
y_dbscan = dbscan.fit_predict(df_cat_num_scaled)

df_cat['pred'] = y_dbscan
df_pred['y_dbscan'] = y_dbscan

sns.relplot(data=df_cat,x='sales',y='overall',hue='pred',palette='colorblind',aspect=2)

# %% [markdown]
# ### Comparison

# %%
df_pred.head()
# Out:
#    y_kmeans  y_hc  y_dbscan
# 0         2     1        -1
# 1         2     1        -1
# 2         2     1        -1
# 3         0     0        -1
# 4         0     0        -1

# %% [markdown]
# silhouette_score is a clustering metric- measure of how well the clusters are formed
# it explains how close intra-cluster points are and how far far clusters are

# %%
sil_kmeans = silhouette_score(df_cat_num_scaled,y_kmeans)
sil_hc = silhouette_score(df_cat_num_scaled,y_hc)
sil_dbscan = silhouette_score(df_cat_num_scaled,y_dbscan)

print('Silhouette score:')
print('Kmeans: {:.3f}'.format(sil_kmeans))
print('AgglomerativeClustering: {:.3f}'.format(sil_hc))
print('DBSCAN: {:.3f}'.format(sil_dbscan))
# Out:
# Silhouette score:
# Kmeans: 0.586
# AgglomerativeClustering: 0.671
# DBSCAN: 0.647

# %% [markdown]
# #### INFERENCE
# On comparing the silhouette scores best model: AgglomerativeClustering

# %%
hc = AgglomerativeClustering(n_clusters = 3, affinity = 'euclidean', linkage = 'ward')
y_hc = hc.fit_predict(df_cat_num_scaled)

df_cat['pred'] = y_hc

# %% [markdown]
# ## Characteristics of Clusters

# %%
clusters = df_cat.groupby('pred')
for i in range(3):
    print(f'Cluster {i}:',len(clusters.get_group(i)),'Categories')
# Out:
# Cluster 0: 592 Categories
# Cluster 1: 3 Categories
# Cluster 2: 47 Categories

# %% [markdown]
# ### Cluster 0: Modrate performing

# %%
cluster_0 = clusters.get_group(0).sort_values(by='overall',ascending=True).drop(['pred'],axis=1)

print('Cluster Discription:')
display(cluster_0.describe())

print('\n\nTop 3 categories based on rating:')
display(cluster_0.loc[:,['category']].tail(3).style.hide_index())

print('\n\nBottom 3 categories based on rating:')
display(cluster_0.loc[:,['category']].head(3).style.hide_index())
# Out:
# Cluster Discription:
#                Freq     overall       price         sales
# count    592.000000  592.000000  592.000000  5.920000e+02
# mean    1651.922297    4.438617   24.465331  4.500662e+04
# std     4255.613971    0.236456   30.386665  1.379478e+05
# min        1.000000    3.833333    0.990000  9.900000e+00
# 25%       37.000000    4.285456   11.487500  6.348900e+02
# 50%      298.500000    4.456055   17.878502  5.802555e+03
# 75%     1352.500000    4.586094   26.496167  3.433773e+04
# max    58258.000000    5.000000  522.990000  1.653682e+06
# Top 3 categories based on rating:
# <style type="text/css">
# </style>
# <table id="T_c84cb">
#   <thead>
#     <tr>
#       <th id="T_c84cb_level0_col0" class="col_heading level0 col0" >category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c84cb_row0_col0" class="data row0 col0" >['Toys & Games', 'Sports & Outdoor Play', 'Sports', 'Boxing', 'Boxing Gloves']</td>
#     </tr>
#     <tr>
#       <td id="T_c84cb_row1_col0" class="data row1 col0" >['Toys & Games', 'Dress Up & Pretend Play', 'Accessories', 'Gel', 'Quality materials used to make Disguise products', 'Fun, Colorful, Inventive designs to put you in the world of role play', "Whether it's Halloween, birthday parties, or even a fun filled night, disguise is good for everything!", 'Official Licensed Disney Accessory', 'Character cameo', 'Adjustable strap']</td>
#     </tr>
#     <tr>
#       <td id="T_c84cb_row2_col0" class="data row2 col0" >['Toys & Games', 'Party Supplies', 'Party Favors', 'Size: 8oz.']</td>
#     </tr>
#   </tbody>
# </table>
# Bottom 3 categories based on rating:
# <style type="text/css">
# </style>
# <table id="T_b171b">
#   <thead>
#     <tr>
#       <th id="T_b171b_level0_col0" class="col_heading level0 col0" >category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b171b_row0_col0" class="data row0 col0" >['Toys & Games', 'Party Supplies', 'Piatas', '8.5" high', '9.75" wide', 'On each pinata there is a clear sticker labeled "Insert candy here."', 'Under that sticker and a layer of tissue, there is a pre-made hole. Press sticker or use scissors to create an opening.', 'All pinatas have a built-in hang loop at the top.', 'Holds 2lbs of candy/toys']</td>
#     </tr>
#     <tr>
#       <td id="T_b171b_row1_col0" class="data row1 col0" >['Toys & Games', 'Dress Up & Pretend Play', 'Beauty & Fashion', 'Makeup', '1" high', '6" wide', '12 Color makeup palette, 5 colored makeup pencils, tooth black out, fake blood, glitter gel makeup, fake skin and applicators', 'Great for Halloween, party time, play time or any time', 'Everything in the kit washes off with warm water and soap', 'Also great for a stage makeup starter kit']</td>
#     </tr>
#     <tr>
#       <td id="T_b171b_row2_col0" class="data row2 col0" >['Toys & Games', 'Sports & Outdoor Play', 'Pools & Water Fun', 'Sprinklers']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Cluster 1: Best Performing

# %%
cluster_1 = clusters.get_group(1).sort_values(by='overall',ascending=True).drop(['pred'],axis=1)

print('Cluster Discription:')
display(cluster_1.describe())

print('\n\ncategories based on rating:')
display(cluster_1.loc[:,['category']].style.hide_index())
# Out:
# Cluster Discription:
#                Freq   overall      price         sales
# count      3.000000  3.000000   3.000000  3.000000e+00
# mean   74759.333333  4.618174  48.978550  3.630000e+06
# std    12285.361913  0.062819  13.533349  9.774455e+05
# min    63726.000000  4.558592  39.438923  2.742086e+06
# 25%    68140.000000  4.585364  41.234115  3.106316e+06
# 50%    72554.000000  4.612136  43.029306  3.470546e+06
# 75%    80276.000000  4.647965  53.748363  4.073958e+06
# max    87998.000000  4.683794  64.467419  4.677369e+06
# categories based on rating:
# <style type="text/css">
# </style>
# <table id="T_36245">
#   <thead>
#     <tr>
#       <th id="T_36245_level0_col0" class="col_heading level0 col0" >category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_36245_row0_col0" class="data row0 col0" >['Toys & Games', 'Action Figures & Statues', 'Action Figures']</td>
#     </tr>
#     <tr>
#       <td id="T_36245_row1_col0" class="data row1 col0" >['Toys & Games', 'Dolls & Accessories', 'Dolls']</td>
#     </tr>
#     <tr>
#       <td id="T_36245_row2_col0" class="data row2 col0" >['Toys & Games', 'Building Toys', 'Building Sets']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Cluster 2: Needs Improvement

# %%
cluster_2 = clusters.get_group(2).sort_values(by='overall',ascending=True).drop(['pred'],axis=1)

print('Cluster Discription:')
display(cluster_2.describe())

print('\n\nTop 3 categories based on rating:')
display(cluster_2.loc[:,['category']].tail(3).style.hide_index())

print('\n\nBottom 3 categories based on rating:')
display(cluster_2.loc[:,['category']].head(3).style.hide_index())
# Out:
# Cluster Discription:
#              Freq    overall      price         sales
# count   47.000000  47.000000  47.000000     47.000000
# mean    74.702128   3.370894  13.687008   1672.982553
# std    138.853209   0.443647  13.836650   4008.675040
# min      5.000000   1.600000   0.990000      9.950000
# 25%      8.000000   3.188596   5.965000     61.465000
# 50%     17.000000   3.500000   9.960000    136.440000
# 75%     65.000000   3.710084  15.718172    845.780000
# max    760.000000   3.800000  86.766987  20737.310000
# Top 3 categories based on rating:
# <style type="text/css">
# </style>
# <table id="T_658f6">
#   <thead>
#     <tr>
#       <th id="T_658f6_level0_col0" class="col_heading level0 col0" >category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_658f6_row0_col0" class="data row0 col0" >['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', 'Decorative play sword is a great addition to your Clone Wars wardrobe', 'Pre Vizsla costume accessory', 'Look for all of The Clone Wars costumes and accessories, great choice for coordinated family or group costumes', 'Officially licensed Star Wars costume', "Rubie's brings fun to dress-up with costumes and accessories kids play with all year long"]</td>
#     </tr>
#     <tr>
#       <td id="T_658f6_row1_col0" class="data row1 col0" >['Toys & Games', 'Learning & Education', 'Musical Instruments', 'Guitars & Strings']</td>
#     </tr>
#     <tr>
#       <td id="T_658f6_row2_col0" class="data row2 col0" >['Toys & Games', 'Dress Up & Pretend Play', 'Pretend Play', 'Toy Police Gear - Police Swat Toys; 14 Police Toys Included; Police Toys for Toddlers & Older Kids; Toy Police Accessories', 'Great For Police Dress Up and Cop and Police Costumes; Toy Halloween Police Accessories; Toy Police Equipment; Great for Police Halloween Costumes', 'Toys for Boys - Kid Police Toys Includes: Flip Wallet Badge, Police Handcuffs, Baton, Glasses, Walkie Talkie, Keys, Knife', 'Compass, Binoculars, Police Badge, Whistle, Tweezers, Identity Card, and Watch; Boy Police Toys', 'Boys Toys; Police Toddler Toys; Police Kids Toys; Swat Police Toys; Police Force Toys; Child Police Toys; Kids Toys Police; Cheap Police Toys; Halloween Costumes Police Ideas']</td>
#     </tr>
#   </tbody>
# </table>
# Bottom 3 categories based on rating:
# <style type="text/css">
# </style>
# <table id="T_51a11">
#   <thead>
#     <tr>
#       <th id="T_51a11_level0_col0" class="col_heading level0 col0" >category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_51a11_row0_col0" class="data row0 col0" >['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', '100% Synthetic Fiber', 'Imported', '3-Piece face and body hair kit', 'Includes moustache, chest hair and sideburns', "Black 70's Afro wig available separately from Forum", "Part of the 70's Disco Fever collection", "Look to Forum Novelties for all your Halloween, Luau, Easter, Mardi Gras and St. Patrick's Day supplies", 'Designed for ages 14 + adult']</td>
#     </tr>
#     <tr>
#       <td id="T_51a11_row1_col0" class="data row1 col0" >['Toys & Games', 'Dress Up & Pretend Play', 'Accessories', 'Nylon Taffeta', 'Machine Washable.']</td>
#     </tr>
#     <tr>
#       <td id="T_51a11_row2_col0" class="data row2 col0" >['Toys & Games', 'Dress Up & Pretend Play', 'Costumes', '100% Polyester Exclusive of Decoration', 'Hand wash cold water. Do not bleach. Dry flat. Do not iron.', 'Size: Small (4-6), Medium (8-10), Large (12-14)', 'Includes: a hat, top with attached tie and hoop pants with attached suspenders.', 'Fake lollipop, wig, clown nose, makeup and gloves sold separately. Shoes not included.']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Suggestions
#   * First cluster (Moderate performing ) is having good ratings but average sales. As observed the categories with less price is giving better sales and purchase frequency of those products is also high, so to improve the sales it is recommended to drop the price.
#
#   * Second cluster (Best performing) is having good ratings as well as sales. So, these categories should not be tampered.
#
#   * Second cluster (Needs Improvement) is having worst response in terms of rating as well as sales. So, complete overhauling is required to improve their ratings.

# %% [markdown]
# ---

# %% [markdown]
# # Demand forecasting
# as per sentiments

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller,acf,pacf
from pmdarima.arima import auto_arima
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

import itertools
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Data preparation for time series analysis

# %%
Positive = df[df['predicted']=='Positive']
Negative = df[df['predicted']=='Negative']
Neutral = df[df['predicted']=='Neutral']

# %%
print('Positive reviews')
Positive.set_index('reviewTime',inplace=True)
Positive.sort_index(inplace=True)
display(Positive.head(3))

print('Negative reviews')
Negative.set_index('reviewTime',inplace=True)
Negative.sort_index(inplace=True)
display(Negative.head(3))

print('Neutral reviews')
Neutral.set_index('reviewTime',inplace=True)
Neutral.sort_index(inplace=True)
display(Neutral.head(3))
# Out:
# Positive reviews
#             overall  verified        asin  \
# reviewTime
# 1999-10-06      5.0     False  1572810939
# 2000-03-08      5.0     False  B00000IWFB
# 2000-03-08      5.0     False  B00000IWFB
#
#                                                    reviewText  \
# reviewTime
# 1999-10-06  ready heart meet spade whist ready play wizard...
# 2000-03-08  long ha toy yes awhile great play great stress...
# 2000-03-08  long ha toy yes awhile great play great stress...
#
#                                             summary  \
# reviewTime
# 1999-10-06  The game was a great time for everyone.
# 2000-03-08           Lots of fun for grown-ups too!
# 2000-03-08           Lots of fun for grown-ups too!
#
#                                            category           brand  price  \
# reviewTime
# 1999-10-06  ['Toys & Games', 'Games', 'Card Games']        US Games  12.72
# 2000-03-08                ['Toys & Games', 'Games']  Milton Bradley  39.63
# 2000-03-08                ['Toys & Games', 'Games']  Milton Bradley  39.63
#
#            sentiment predicted
# reviewTime
# 1999-10-06  Positive  Positive
# 2000-03-08  Positive  Positive
# 2000-03-08  Positive  Positive
# Negative reviews
#             overall  verified        asin  \
# reviewTime
# 2001-05-05      4.0     False  B000059LBN
# 2001-05-05      4.0     False  B000059LBN
# 2001-08-27      1.0     False  B00000ISUK
#
#                                                    reviewText  \
# reviewTime
# 2001-05-05  wa reluctant let year old twin spend week allo...
# 2001-05-05  wa reluctant let year old twin spend week allo...
# 2001-08-27  toy wa dissapointing son love thomas toy poorl...
#
#                                      summary  \
# reviewTime
# 2001-05-05                        Shark Park
# 2001-05-05                        Shark Park
# 2001-08-27  Great character, poorly made toy
#
#                                                      category       brand  \
# reviewTime
# 2001-05-05  ['Toys & Games', 'Toy Remote Control & Play Ve...  Hot Wheels
# 2001-05-05  ['Toys & Games', 'Toy Remote Control & Play Ve...  Hot Wheels
# 2001-08-27  ['Toys & Games', 'Toy Remote Control & Play Ve...        TOMY
#
#              price sentiment predicted
# reviewTime
# 2001-05-05  239.99  Positive  Negative
# 2001-05-05  239.99  Positive  Negative
# 2001-08-27   59.99  Negative  Negative
# Neutral reviews
#             overall  verified        asin  \
# reviewTime
# 2000-10-01      4.0     False  B00ESIWIO6
# 2000-10-10      5.0     False  B00000IWCY
# 2000-10-10      5.0     False  B00000IWCY
#
#                                                    reviewText  \
# reviewTime
# 2000-10-01  endless game ha bad habit good version game e ...
# 2000-10-10  paper pen hand cross suspect knew no longer su...
# 2000-10-10  paper pen hand cross suspect knew no longer su...
#
#                                 summary  \
# reviewTime
# 2000-10-01  Lets start the Family Feud!
# 2000-10-10     Mystery heaven for kids!
# 2000-10-10     Mystery heaven for kids!
#
#                                             category          brand  price  \
# reviewTime
# 2000-10-01   ['Toys & Games', 'Games', 'Card Games']  Endless Games  14.99
# 2000-10-10  ['Toys & Games', 'Games', 'Board Games']         Hasbro  79.99
# 2000-10-10  ['Toys & Games', 'Games', 'Board Games']         Hasbro  79.99
#
#            sentiment predicted
# reviewTime
# 2000-10-01  Positive   Neutral
# 2000-10-10  Positive   Neutral
# 2000-10-10  Positive   Neutral

# %% [markdown]
# ## Positive sentiment products

# %% [markdown]
# ### Resempling of data on monthly basis

# %%
Positive_resample = Positive['price'].resample('m').sum()

# for data continuity
Positive_resample = Positive_resample[Positive_resample.index>'2002-01-01']    # to avoid null values 
Positive_resample[:5]
# Out:
# reviewTime
# 2002-01-31     37.47
# 2002-02-28    286.02
# 2002-03-31    146.48
# 2002-04-30    456.05
# 2002-05-31    646.87
# Freq: M, Name: price, dtype: float64

# %% [markdown]
# ### Data decomposition

# %%
decomposition=seasonal_decompose(Positive_resample, period=30)
d_trend=decomposition.trend
d_seasonal=decomposition.seasonal
d_residual=decomposition.resid

# plotting all the 4 graphs
fig,ax = plt.subplots(4,1,figsize=(12,8))

plt.subplot(411)
plt.plot(Positive_resample,label='Actual')
plt.legend(loc='best')

plt.subplot(412)
plt.plot(d_trend,label='Trend')
plt.legend(loc='best')

plt.subplot(413)
plt.plot(d_seasonal,label='Seasonal')
plt.legend(loc='best')

plt.subplot(414)
plt.plot(d_residual,label='Residual')
plt.legend(loc='best')

plt.tight_layout()

# %% [markdown]
# #### Observations
# Trend: approaching inverted u trend
# Seasonality: additive seasonality is observed after every 12 months
# Residuals: magnitude of residuals correspond to the trend

# %% [markdown]
# #### Hypothesis behind the inverted u trend
# Increasing broadband internet and 4g advancement created more ecommerce platforms and thereby more competitiors. Also by this time the living standards of people had improved and people started looking for more options.

# %% [markdown]
# ### Data stationarity
# ADF test to check the stationarity of data

# %%
def checkStationarity(data):
    '''Returns str that explains the passsed data is stationary or not'''
    pvalue = adfuller(data)[1]
    if(pvalue>0.05):
        msg = 'p-value = {:.3f}. Data is not stationary'.format(pvalue)
    else:
        msg='p-value = {:.3f}. Data is stationary'.format(pvalue)
        
    return(msg)

# %%
checkStationarity(Positive_resample)
# Out:
# 'p-value = 0.322. Data is not stationary'

# %% [markdown]
# Data is not stationary i.e. data does not have constant mean and constant variance over the time. Data has to be made stationary for accurat statistical analysis.

# %% [markdown]
# ### Differencing method to make data stationary

# %%
shift1 = Positive_resample - Positive_resample.shift(8)
checkStationarity(shift1.dropna())
# Out:
# 'p-value = 0.001. Data is stationary'

# %%
Stationary_positive = shift1.dropna()

# %% [markdown]
# ### Plot of before and after stationary

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(15,5))

ax[0].plot(Positive_resample)
ax[0].set_title('Before making Data Stationary')

ax[1].plot(Stationary_positive)
ax[1].set_title('After making Data Stationary')

plt.show()

# %% [markdown]
# Before stationarity: The average value changes over time and the peaks in the seasonal periods seem to get only larger
# After stationarity treatment: The average value is not changing much, seasonal peaks over the time has decreased and trend component is not longer in data

# %% [markdown]
# ### ACF & PACF Plot

# %%
fig = plt.figure(figsize=(16,5))

# ACF
ax1 = fig.add_subplot(121)
sm.graphics.tsa.plot_acf(Stationary_positive, lags=8, ax=ax1)


# PACF
ax2 = fig.add_subplot(122)
sm.graphics.tsa.plot_pacf(Stationary_positive, lags=8, ax=ax2)
plt.tight_layout()

# %% [markdown]
# ### Train - Test split

# %%
train_size = int(0.9 * len(Positive_resample))

train = Positive_resample.iloc[:train_size]
test = Positive_resample.iloc[train_size:]
print("train = {}, test = {}".format(len(train), len(test)))
# Out:
# train = 181, test = 21

# %% [markdown]
# ## ARMA

# %% [markdown]
# ### Hyperparameters with lowest AIC score

# %%
for p in range(1,9):
    for q in range(1,9):
        m1 = ARIMA(Stationary_positive,order=(p,0,q))
        r1 = m1.fit()
        print(f'for AR{p,0,q} AIC score is {r1.aic}')
# Out:
# for AR(1, 0, 1) AIC score is 5097.133881829964
# for AR(1, 0, 2) AIC score is 5095.469998983457
# for AR(1, 0, 3) AIC score is 5059.152737842514
# for AR(1, 0, 4) AIC score is 5047.1005178346895
# for AR(1, 0, 5) AIC score is 5068.304532940081
# for AR(1, 0, 6) AIC score is 5076.586001483237
# for AR(1, 0, 7) AIC score is 5079.9403505757455
# for AR(1, 0, 8) AIC score is 5053.622474969638
# for AR(2, 0, 1) AIC score is 5113.809704137695
# for AR(2, 0, 2) AIC score is 5099.900101383599
# for AR(2, 0, 3) AIC score is 5042.869328954021
# for AR(2, 0, 4) AIC score is 5042.585160177465
# for AR(2, 0, 5) AIC score is 5054.064146952822
# for AR(2, 0, 6) AIC score is 5035.289938627549
# for AR(2, 0, 7) AIC score is 5037.560078126355
# for AR(2, 0, 8) AIC score is 5027.70247248273
# for AR(3, 0, 1) AIC score is 5088.179602382462
# for AR(3, 0, 2) AIC score is 5085.0968902178165
# for AR(3, 0, 3) AIC score is 5043.399343928801
# for AR(3, 0, 4) AIC score is 5044.575761988517
# for AR(3, 0, 5) AIC score is 5055.358206819332
# for AR(3, 0, 6) AIC score is 5037.37424397295
# for AR(3, 0, 7) AIC score is 5037.392751592701
# for AR(3, 0, 8) AIC score is 5028.727839142472
# for AR(4, 0, 1) AIC score is 5082.793178052636
# for AR(4, 0, 2) AIC score is 5077.305519964099
# for AR(4, 0, 3) AIC score is 5043.457286808622
# for AR(4, 0, 4) AIC score is 5044.502923501008
# for AR(4, 0, 5) AIC score is 5041.847789308573
# for AR(4, 0, 6) AIC score is 5032.87547087307
# for AR(4, 0, 7) AIC score is 5023.898183615978
# for AR(4, 0, 8) AIC score is 5022.1334696239655
# for AR(5, 0, 1) AIC score is 5079.844699682195
# for AR(5, 0, 2) AIC score is 5080.273194406282
# for AR(5, 0, 3) AIC score is 5041.023112179626
# for AR(5, 0, 4) AIC score is 5048.163474661867
# for AR(5, 0, 5) AIC score is 5029.540273362594
# for AR(5, 0, 6) AIC score is 5045.408819784823
# for AR(5, 0, 7) AIC score is 5033.359885471478
# for AR(5, 0, 8) AIC score is 5002.09260954942
# for AR(6, 0, 1) AIC score is 5079.959458788287
# for AR(6, 0, 2) AIC score is 5081.938859261504
# for AR(6, 0, 3) AIC score is 5055.687197516434
# for AR(6, 0, 4) AIC score is 5043.236822630121
# for AR(6, 0, 5) AIC score is 5014.802407525971
# for AR(6, 0, 6) AIC score is 5016.970489270358
# for AR(6, 0, 7) AIC score is 5014.433736600884
# for AR(6, 0, 8) AIC score is 4983.942490066059
# for AR(7, 0, 1) AIC score is 5082.823407677319
# for AR(7, 0, 2) AIC score is 5076.451016282193
# for AR(7, 0, 3) AIC score is 5007.739004756311
# for AR(7, 0, 4) AIC score is 5056.918932320649
# for AR(7, 0, 5) AIC score is 4998.409313198548
# for AR(7, 0, 6) AIC score is 5004.351163574833
# for AR(7, 0, 7) AIC score is 4984.388338057083
# for AR(7, 0, 8) AIC score is 4968.2667699612775
# for AR(8, 0, 1) AIC score is 5045.000341141418
# for AR(8, 0, 2) AIC score is 5006.928379016774
# for AR(8, 0, 3) AIC score is 4970.175523339846
# for AR(8, 0, 4) AIC score is 5015.2041637901275
# for AR(8, 0, 5) AIC score is 4999.892224765103
# for AR(8, 0, 6) AIC score is 4994.130491273214
# for AR(8, 0, 7) AIC score is 4962.568309838052
# for AR(8, 0, 8) AIC score is 4947.116301507018

# %% [markdown]
# ### Training of model

# %%
p,d,q = 8,0,7
arma_model1 = ARIMA(train,order=(p,d,q)).fit()

print(arma_model1.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  price   No. Observations:                  181
# Model:                 ARIMA(8, 0, 7)   Log Likelihood               -2272.038
# Date:                Wed, 01 Feb 2023   AIC                           4578.076
# Time:                        21:47:34   BIC                           4632.451
# Sample:                    01-31-2002   HQIC                          4600.121
#                          - 01-31-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.436e+05   4.58e-08   3.14e+12      0.000    1.44e+05    1.44e+05
# ar.L1          2.5410      0.275      9.224      0.000       2.001       3.081
# ar.L2         -2.9698      0.715     -4.153      0.000      -4.371      -1.568
# ar.L3          1.8556      1.036      1.790      0.073      -0.176       3.887
# ar.L4         -0.0094      1.189     -0.008      0.994      -2.340       2.321
# ar.L5         -1.5879      1.156     -1.374      0.169      -3.853       0.677
# ar.L6          2.0969      0.892      2.351      0.019       0.349       3.845
# ar.L7         -1.4807      0.478     -3.100      0.002      -2.417      -0.545
# ar.L8          0.5534      0.146      3.787      0.000       0.267       0.840
# ma.L1         -1.7024      0.385     -4.420      0.000      -2.457      -0.948
# ma.L2          1.2973      1.039      1.249      0.212      -0.739       3.334
# ma.L3         -0.3055      1.623     -0.188      0.851      -3.486       2.875
# ma.L4         -0.4400      1.584     -0.278      0.781      -3.544       2.664
# ma.L5          1.5026      0.998      1.506      0.132      -0.453       3.458
# ma.L6         -1.6283      0.413     -3.938      0.000      -2.439      -0.818
# ma.L7          0.6945      0.164      4.224      0.000       0.372       1.017
# sigma2      6.704e+09    6.2e-10   1.08e+19      0.000     6.7e+09     6.7e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.28   Jarque-Bera (JB):               620.90
# Prob(Q):                              0.60   Prob(JB):                         0.00
# Heteroskedasticity (H):            2281.69   Skew:                             1.57
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.17e+36. Standard errors may be unstable.

# %% [markdown]
# ### Predictions

# %%
start = len(train)
end = len(train)+len(test)-1

pred = arma_model1.predict(start=start,end=end)

# pred.index=Positive_resample.index[start:end+1]

DF_ARMA1 = pd.DataFrame({'Actual':test,'Predicted':pred,'Error':test-pred})
DF_ARMA1.head()
# Out:
#                Actual      Predicted          Error
# 2017-02-28  495870.80  908317.519617 -412446.719617
# 2017-03-31  438455.69  586506.731511 -148051.041511
# 2017-04-30  351062.03  511344.891798 -160282.861798
# 2017-05-31  298158.92  634562.982061 -336404.062061
# 2017-06-30  259863.83  687756.876972 -427893.046972

# %% [markdown]
# ### Actual vs predicted

# %%
plt.figure(figsize=(15,5))
plt.plot(test,'b--',linewidth=2,label='actual')
plt.plot(pred,'r-',linewidth=2,label='predicted')
plt.title(f'Actual vs Predicted for ARMA')
plt.legend()
plt.grid()

# %% [markdown]
# Key to read the graph:
# red corresponds to the model values and blue corresponds to the actual
#
# Model is predicting near to the actual values but not the exact values and predicting values following the pattern of actual values

# %% [markdown]
# ### Evaluation

# %%
mse = mean_squared_error(pred,test)
rmse = np.sqrt(mse)
print('Root Mean squarred error for ARMA model for positive sentiments  is : ',round(rmse,2))
# Out:
# Root Mean squarred error for ARMA model for positive sentiments  is :  431809.54

# %% [markdown]
# ### Ljung box test
# The test examines autocorrelations of the residuals to check the goodness of the model. If the autocorrelations are very small, it is a good model

# %%
pvalue = sm.stats.acorr_ljungbox(arma_model1.resid,lags=[1],return_df=True)['lb_pvalue'].values
if pvalue < 0.05:
    print("Reject H0. Bad model")
else:
    print("Fail-to-Reject H0. Good model")
# Out:
# Fail-to-Reject H0. Good model

# %% [markdown]
# ### ARIMA

# %%
for p in range(1,10):
    for q in range(1,10):
        m1 = ARIMA(Stationary_positive,order=(p,8,q))
        r1 = m1.fit()
        print(f'for AR{p,8,q} AIC score is {r1.aic}')
# Out:
# for AR(1, 8, 1) AIC score is 5973.739194338568
# for AR(1, 8, 2) AIC score is 5975.809111859669
# for AR(1, 8, 3) AIC score is 6003.646934214655
# for AR(1, 8, 4) AIC score is 5934.334404378402
# for AR(1, 8, 5) AIC score is 5952.818595801137
# for AR(1, 8, 6) AIC score is 6000.644884069352
# for AR(1, 8, 7) AIC score is 6000.711004806088
# for AR(1, 8, 8) AIC score is 6011.858513422048
# for AR(1, 8, 9) AIC score is 6004.484558980857
# for AR(2, 8, 1) AIC score is 5766.883389663999
# for AR(2, 8, 2) AIC score is 5753.9421145215
# for AR(2, 8, 3) AIC score is 5736.284991634828
# for AR(2, 8, 4) AIC score is 5721.537379541745
# for AR(2, 8, 5) AIC score is 5754.80780824501
# for AR(2, 8, 6) AIC score is 5780.628173265165
# for AR(2, 8, 7) AIC score is 5787.6315796811305
# for AR(2, 8, 8) AIC score is 5780.5302819388335
# for AR(2, 8, 9) AIC score is 5746.631749440104
# for AR(3, 8, 1) AIC score is 5718.137634919867
# for AR(3, 8, 2) AIC score is 5655.4672114236155
# for AR(3, 8, 3) AIC score is 5661.161915407132
# for AR(3, 8, 4) AIC score is 16.0
# for AR(3, 8, 5) AIC score is 5651.896631881675
# for AR(3, 8, 6) AIC score is 5667.938748996436
# for AR(3, 8, 7) AIC score is 5677.3707718484975
# for AR(3, 8, 8) AIC score is 5655.776268294783
# for AR(3, 8, 9) AIC score is 5615.2588251363995
# for AR(4, 8, 1) AIC score is 5528.200588563582
# for AR(4, 8, 2) AIC score is 5509.597088873675
# for AR(4, 8, 3) AIC score is 5522.123892532088
# for AR(4, 8, 4) AIC score is 5373.791348846562
# for AR(4, 8, 5) AIC score is 5377.020231099673
# for AR(4, 8, 6) AIC score is 5399.6466291387605
# for AR(4, 8, 7) AIC score is 5423.903118616179
# for AR(4, 8, 8) AIC score is 5408.496826716969
# for AR(4, 8, 9) AIC score is 5390.095468117159
# for AR(5, 8, 1) AIC score is 5529.661596609805
# for AR(5, 8, 2) AIC score is 5506.581982538712
# for AR(5, 8, 3) AIC score is 5392.947168825136
# for AR(5, 8, 4) AIC score is 5356.328873332173
# for AR(5, 8, 5) AIC score is 5379.417769879651
# for AR(5, 8, 6) AIC score is 5396.154715916871
# for AR(5, 8, 7) AIC score is 5433.511941994031
# for AR(5, 8, 8) AIC score is 5412.231450498999
# for AR(5, 8, 9) AIC score is 5392.692057307437
# for AR(6, 8, 1) AIC score is 5472.807129384221
# for AR(6, 8, 2) AIC score is 5433.422773842802
# for AR(6, 8, 3) AIC score is 5271.618419777571
# for AR(6, 8, 4) AIC score is 5322.467243329025
# for AR(6, 8, 5) AIC score is 5331.514023506368
# for AR(6, 8, 6) AIC score is 5410.128485436884
# for AR(6, 8, 7) AIC score is 5410.15635535486
# for AR(6, 8, 8) AIC score is 5384.766077645613
# for AR(6, 8, 9) AIC score is 5352.6992904434865
# for AR(7, 8, 1) AIC score is 5428.932839966814
# for AR(7, 8, 2) AIC score is 5393.198209138981
# for AR(7, 8, 3) AIC score is 5270.002201730229
# for AR(7, 8, 4) AIC score is 5191.164753400411
# for AR(7, 8, 5) AIC score is 5304.791548046229
# for AR(7, 8, 6) AIC score is 5340.625971079975
# for AR(7, 8, 7) AIC score is 5408.714295634742
# for AR(7, 8, 8) AIC score is 5340.7900709287915
# for AR(7, 8, 9) AIC score is 5315.653627651808
# for AR(8, 8, 1) AIC score is 5391.986156634701
# for AR(8, 8, 2) AIC score is 5357.317947233487
# for AR(8, 8, 3) AIC score is 5264.832649095677
# for AR(8, 8, 4) AIC score is 5213.126733836871
# for AR(8, 8, 5) AIC score is 28.0
# for AR(8, 8, 6) AIC score is 5273.528315626275
# for AR(8, 8, 7) AIC score is 5312.795864753101
# for AR(8, 8, 8) AIC score is 5307.751375215002
# for AR(8, 8, 9) AIC score is 5288.328338845111
# for AR(9, 8, 1) AIC score is 5295.46649684441
# for AR(9, 8, 2) AIC score is 5265.693403826666
# for AR(9, 8, 3) AIC score is 5263.113786551148
# for AR(9, 8, 4) AIC score is 5108.610436343736
# for AR(9, 8, 5) AIC score is 5150.686348406316
# for AR(9, 8, 6) AIC score is 5175.507741164315
# for AR(9, 8, 7) AIC score is 5225.482356358898
# for AR(9, 8, 8) AIC score is 5173.461292365605
# for AR(9, 8, 9) AIC score is 5180.476677376562

# %% [markdown]
# ### Training of model

# %%
p,d,q = 9,8,9
arima_model1 = ARIMA(train,order=(p,d,q)).fit()

print(arima_model1.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  price   No. Observations:                  181
# Model:                 ARIMA(9, 8, 9)   Log Likelihood               -2311.515
# Date:                Wed, 01 Feb 2023   AIC                           4661.030
# Time:                        21:48:45   BIC                           4720.943
# Sample:                    01-31-2002   HQIC                          4685.336
#                          - 01-31-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -3.2070      0.079    -40.513      0.000      -3.362      -3.052
# ar.L2         -5.8071      0.247    -23.550      0.000      -6.290      -5.324
# ar.L3         -7.9226      0.446    -17.779      0.000      -8.796      -7.049
# ar.L4         -9.1951      0.606    -15.169      0.000     -10.383      -8.007
# ar.L5         -9.1602      0.640    -14.317      0.000     -10.414      -7.906
# ar.L6         -7.8400      0.579    -13.535      0.000      -8.975      -6.705
# ar.L7         -5.7270      0.478    -11.982      0.000      -6.664      -4.790
# ar.L8         -3.1627      0.300    -10.543      0.000      -3.751      -2.575
# ar.L9         -0.9881      0.099     -9.969      0.000      -1.182      -0.794
# ma.L1         -2.2128      0.099    -22.460      0.000      -2.406      -2.020
# ma.L2          0.4128      0.179      2.309      0.021       0.062       0.763
# ma.L3          2.1539      0.387      5.571      0.000       1.396       2.912
# ma.L4         -1.3584      0.368     -3.692      0.000      -2.080      -0.637
# ma.L5         -1.1346      0.484     -2.346      0.019      -2.083      -0.186
# ma.L6          1.7761      0.408      4.356      0.000       0.977       2.575
# ma.L7          0.3542      0.325      1.089      0.276      -0.284       0.992
# ma.L8         -1.8071      0.301     -6.000      0.000      -2.397      -1.217
# ma.L9          0.8168      0.199      4.101      0.000       0.426       1.207
# sigma2      2.951e+10   3.84e-11   7.68e+20      0.000    2.95e+10    2.95e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                  28.46   Jarque-Bera (JB):               464.31
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):            4692.39   Skew:                            -0.44
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.98
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.67e+36. Standard errors may be unstable.

# %% [markdown]
# ### Predictions

# %%
start = len(train)
end = len(train)+len(test)-1
pred = arima_model1.predict(start=start,end=end)

DF_ARIMA1 = pd.DataFrame({'Actual':test,'Predicted':pred,'Error':test-pred})
DF_ARIMA1.head()
# Out:
#                Actual      Predicted          Error
# 2017-02-28  495870.80  788528.122934 -292657.322934
# 2017-03-31  438455.69  872048.176746 -433592.486746
# 2017-04-30  351062.03  628858.397898 -277796.367898
# 2017-05-31  298158.92  511632.767769 -213473.847769
# 2017-06-30  259863.83  118866.677706  140997.152294

# %% [markdown]
# ### Predicted vs actual

# %%
plt.figure(figsize=(15,5))

plt.plot(test,'b--',linewidth=2,label='actual')
plt.plot(pred,'r-',linewidth=2,label='predicted')
plt.title(f'ARIMA p={p} d={d} q={q})')
plt.legend()
plt.grid()

# %% [markdown]
# Key to read the graph:
# red corresponds to the model values and blue corresponds to the actual
#
# Here we can see as per the time increasing error in predictions is also increasing that means model have heteroscedasticity factor

# %% [markdown]
# ### Evaluation

# %%
mse = mean_squared_error(pred,test)
rmse = np.sqrt(mse)
print('Root Mean squarred error for ARMA model for positive sentiments  is : ',round(rmse,2))
# Out:
# Root Mean squarred error for ARMA model for positive sentiments  is :  37175869.98

# %% [markdown]
# ### Ljung box test

# %%
pvalue = sm.stats.acorr_ljungbox(arima_model1.resid,lags=[1],return_df=True)['lb_pvalue'].values
if pvalue < 0.05:
    print("Reject H0. Bad model")
else:
    print("Fail-to-Reject H0. Good model")
# Out:
# Reject H0. Bad model

# %% [markdown]
# ### SARIMA

# %%
p,d,q = (8, 0, 7)

sarima_model1 = SARIMAX(train, order=(p,d,q), seasonal_order=(p,d,q,24)).fit()
print(sarima_model1.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              price   No. Observations:                  181
# Model:             SARIMAX(8, 0, 7)x(8, 0, 7, 24)   Log Likelihood               -2256.440
# Date:                            Wed, 01 Feb 2023   AIC                           4574.881
# Time:                                    21:52:52   BIC                           4674.034
# Sample:                                01-31-2002   HQIC                          4615.080
#                                      - 01-31-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0598      1.596     -0.037      0.970      -3.188       3.069
# ar.L2         -0.6893      0.797     -0.865      0.387      -2.252       0.873
# ar.L3         -0.2476      0.844     -0.293      0.769      -1.903       1.407
# ar.L4         -0.0960      1.078     -0.089      0.929      -2.209       2.017
# ar.L5          0.4046      1.021      0.396      0.692      -1.596       2.405
# ar.L6          0.3403      1.104      0.308      0.758      -1.823       2.504
# ar.L7          0.2922      1.178      0.248      0.804      -2.017       2.601
# ar.L8          0.5518      0.772      0.715      0.475      -0.961       2.065
# ma.L1          1.1913      1.972      0.604      0.546      -2.673       5.056
# ma.L2          1.7094      2.647      0.646      0.518      -3.478       6.896
# ma.L3          2.0022      2.617      0.765      0.444      -3.126       7.131
# ma.L4          1.9632      3.023      0.649      0.516      -3.961       7.888
# ma.L5          1.3506      2.538      0.532      0.595      -3.625       6.326
# ma.L6          0.7841      1.707      0.459      0.646      -2.561       4.129
# ma.L7          0.6518      0.890      0.732      0.464      -1.093       2.397
# ar.S.L24       0.3629   9582.457   3.79e-05      1.000   -1.88e+04    1.88e+04
# ar.S.L48       0.0521   5755.164   9.06e-06      1.000   -1.13e+04    1.13e+04
# ar.S.L72      -0.0057   3756.925  -1.52e-06      1.000   -7363.443    7363.432
# ar.S.L96       0.0053   4232.084   1.26e-06      1.000   -8294.727    8294.737
# ar.S.L120     -0.0068   7200.782   -9.4e-07      1.000   -1.41e+04    1.41e+04
# ar.S.L144      0.0037   6410.817   5.83e-07      1.000   -1.26e+04    1.26e+04
# ar.S.L168     -0.0004   4634.569  -8.83e-08      1.000   -9083.589    9083.588
# ar.S.L192     -0.0007   1370.436  -4.76e-07      1.000   -2686.005    2686.004
# ma.S.L24       0.4636   9582.415   4.84e-05      1.000   -1.88e+04    1.88e+04
# ma.S.L48       0.0850   7872.297   1.08e-05      1.000   -1.54e+04    1.54e+04
# ma.S.L72       0.0230   3961.498    5.8e-06      1.000   -7764.370    7764.416
# ma.S.L96      -0.0012   3677.803  -3.39e-07      1.000   -7208.362    7208.359
# ma.S.L120      0.0007   7304.208   9.76e-08      1.000   -1.43e+04    1.43e+04
# ma.S.L144     -0.0013   7714.294  -1.69e-07      1.000   -1.51e+04    1.51e+04
# ma.S.L168     -0.0015   2191.322  -6.86e-07      1.000   -4294.915    4294.912
# sigma2      6.699e+09      0.025   2.72e+11      0.000     6.7e+09     6.7e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):              1925.41
# Prob(Q):                              0.85   Prob(JB):                         0.00
# Heteroskedasticity (H):            6959.92   Skew:                             2.07
# Prob(H) (two-sided):                  0.00   Kurtosis:                        18.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.44e+28. Standard errors may be unstable.

# %% [markdown]
# ### Predictions

# %%
start = len(train)
end = len(train)+len(test)-1

pred = sarima_model1.predict(start=start,end=end)

DF_SARIMA1 = pd.DataFrame({'Actual':test,'Predicted':pred,'Error':test-pred})
DF_SARIMA1.head()
# Out:
#                Actual      Predicted          Error
# 2017-02-28  495870.80  709629.813036 -213759.013036
# 2017-03-31  438455.69  528865.455981  -90409.765981
# 2017-04-30  351062.03  478183.075961 -127121.045961
# 2017-05-31  298158.92  479503.527986 -181344.607986
# 2017-06-30  259863.83  515527.086666 -255663.256666

# %% [markdown]
# ### Actual vs Predicted

# %%
plt.figure(figsize=(15,5))

plt.plot(test,'b--',linewidth=2,label='actual')
plt.plot(pred,'r-',linewidth=2,label='predicted')
plt.title(f'Actual vs Predicted SARIMA')
plt.legend()
plt.grid()

# %% [markdown]
# ### Evaluation

# %%
mse = mean_squared_error(pred,test)
rmse = np.sqrt(mse)
print('Root Mean squarred error for ARMA model for positive sentiments  is : ',round(rmse,2))
# Out:
# Root Mean squarred error for ARMA model for positive sentiments  is :  294919.88

# %% [markdown]
# ### Ljung box test

# %%
pvalue = sm.stats.acorr_ljungbox(sarima_model1.resid,lags=[1],return_df=True)['lb_pvalue'].values
if pvalue < 0.05:
    print("Reject H0. Bad model")
else:
    print("Fail-to-Reject H0. Good model")
# Out:
# Fail-to-Reject H0. Good model

# %% [markdown]
# Model is predicting near to the actual values but not the exact values and predicted values following the pattern of actual values
#
# SARIMA model giving the best predictions with compare to the other models as it have low RMSE value and the predicted values are following the actual values path and closed to it

# %% [markdown]
# ### Foresacting the total sales
# for next 1 years
#
# As SARIMA giving the best result with compare to ARIMA , ARMA i.e. SARIMA is using for forecasting

# %%
start = len(train)+len(test)
end = start + 12
future = sarima_model1.predict(start=start,end=end)
future
# Out:
# 2018-11-30    355137.602884
# 2018-12-31    707850.076670
# 2019-01-31    698453.788441
# 2019-02-28    441977.362038
# 2019-03-31    298468.581106
# 2019-04-30    294398.387422
# 2019-05-31    338549.374740
# 2019-06-30    376932.224553
# 2019-07-31    390271.623689
# 2019-08-31    306464.361450
# 2019-09-30    249232.352157
# 2019-10-31    275947.310332
# 2019-11-30    343809.194756
# Freq: M, Name: predicted_mean, dtype: float64

# %%
plt.figure(figsize=(16,5))

plt.plot(Positive_resample,color='black',label='Actual')
plt.plot(future,color='red',label='Forecast')
plt.title('Demand forecasting for 2019')

plt.legend()
plt.show()

# %% [markdown]
# #### Observation
# 2019 starts off with increase in sum(price) i.e sales from the previous year
# follows the seasonality- sale hits peak at the 1st quarter and declines as the year passes lowest in november 2019 and then again increased for december

# %% [markdown]
# ## Negative sentiment products

# %% [markdown]
# ### Resempling of data on monthly basis

# %%
Negative_resample = Negative['price'].resample('m').sum()

Negative_resample = Negative_resample[Negative_resample.index>='2008-01-01']
Negative_resample[:5]
# Out:
# reviewTime
# 2008-01-31    1151.68
# 2008-02-29     508.76
# 2008-03-31     289.00
# 2008-04-30     520.37
# 2008-05-31     636.43
# Freq: M, Name: price, dtype: float64

# %% [markdown]
# ### Data decomposition

# %%
decomposition=seasonal_decompose(Negative_resample, period=30)
d_trend=decomposition.trend
d_seasonal=decomposition.seasonal
d_residual=decomposition.resid

# plotting all the 4 graphs
fig,ax = plt.subplots(4,1,figsize=(12,8))

plt.subplot(411)
plt.plot(Negative_resample,label='Actual')
plt.legend(loc='best')

plt.subplot(412)
plt.plot(d_trend,label='Trend')
plt.legend(loc='best')

plt.subplot(413)
plt.plot(d_seasonal,label='Seasonal')
plt.legend(loc='best')

plt.subplot(414)
plt.plot(d_residual,label='Residual')
plt.legend(loc='best')

plt.tight_layout()

# %% [markdown]
# Trend: approaching inverted u trend
# Seasonality: additive seasonality is observed after every 12 months
# Residuals: magnitude of residuals correspond to the trend
#
# Hypothesis behind the inverted u trend:
# Increasing broadband internet and 4g advancement created more ecommerce platforms and thereby more competitiors. Also by this time the living standards of people had improved and people started looking for more options

# %% [markdown]
# ### ADF test ( Stationarity )

# %%
checkStationarity(Negative_resample)
# Out:
# 'p-value = 0.592. Data is not stationary'

# %% [markdown]
# ### Moving average technique to make data stationary

# %%
Stationary_negative = Negative_resample.rolling(window=12).mean().dropna()
checkStationarity(Stationary_negative)
# Out:
# 'p-value = 0.086. Data is not stationary'

# %% [markdown]
# ### Before & after data stationary

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(15,5))

ax[0].plot(Negative_resample)
ax[0].set_title('Before making Data Stationary')

ax[1].plot(Stationary_negative)
ax[1].set_title('After making Data Stationary')

plt.show()

# %% [markdown]
# Before stationarity: The average value changes over time and the peaks in the seasonal periods seem to get only larger
# After stationarity treatment: The average value is constant

# %% [markdown]
# ### ACF & PACF plot

# %%
fig = plt.figure(figsize=(16,5))

# ACF
ax1 = fig.add_subplot(121)
sm.graphics.tsa.plot_acf(Stationary_negative, lags=12, ax=ax1)

# PACF
ax2 = fig.add_subplot(122)
sm.graphics.tsa.plot_pacf(Stationary_negative, lags=12, ax=ax2)
plt.tight_layout()

# %% [markdown]
# ### Train - Test split

# %%
train_size = int(0.9 * len(Negative_resample))

train = Negative_resample.iloc[:train_size]
test = Negative_resample.iloc[train_size:]
print("train = {}, test = {}".format(len(train), len(test)))
# Out:
# train = 116, test = 13

# %% [markdown]
# ### ARMA

# %% [markdown]
# ### Hyperparameters with lowest AIC

# %%
for p in range(1,5):
    for q in range(1,12):
        m1 = ARIMA(Stationary_negative,order=(p,0,q))
        r1 = m1.fit()
        print(f'for AR{p,0,q} AIC score is {r1.aic}')
# Out:
# for AR(1, 0, 1) AIC score is 1900.178885386205
# for AR(1, 0, 2) AIC score is 1875.656939391761
# for AR(1, 0, 3) AIC score is 1859.1000159493951
# for AR(1, 0, 4) AIC score is 1851.8846146162168
# for AR(1, 0, 5) AIC score is 1851.2843984363526
# for AR(1, 0, 6) AIC score is 1847.581783686588
# for AR(1, 0, 7) AIC score is 1845.2634738844276
# for AR(1, 0, 8) AIC score is 1850.4899005878567
# for AR(1, 0, 9) AIC score is 1870.863693440873
# for AR(1, 0, 10) AIC score is 1844.539440890431
# for AR(1, 0, 11) AIC score is 1827.3294905381356
# for AR(2, 0, 1) AIC score is 1826.0975252493502
# for AR(2, 0, 2) AIC score is 1817.1068549093197
# for AR(2, 0, 3) AIC score is 1818.987874279533
# for AR(2, 0, 4) AIC score is 1821.4278940013596
# for AR(2, 0, 5) AIC score is 1853.5177394991126
# for AR(2, 0, 6) AIC score is 1823.7111192878374
# for AR(2, 0, 7) AIC score is 1825.6364034401456
# for AR(2, 0, 8) AIC score is 1829.0886834416892
# for AR(2, 0, 9) AIC score is 1831.918015054153
# for AR(2, 0, 10) AIC score is 1837.1604101032774
# for AR(2, 0, 11) AIC score is 1834.2157175002267
# for AR(3, 0, 1) AIC score is 1827.56993708279
# for AR(3, 0, 2) AIC score is 1818.9627335178398
# for AR(3, 0, 3) AIC score is 1821.1536742667492
# for AR(3, 0, 4) AIC score is 1821.4215676250262
# for AR(3, 0, 5) AIC score is 1854.4995146821193
# for AR(3, 0, 6) AIC score is 1825.498674691383
# for AR(3, 0, 7) AIC score is 1828.1350857850198
# for AR(3, 0, 8) AIC score is 1831.9020871764262
# for AR(3, 0, 9) AIC score is 1836.040632164815
# for AR(3, 0, 10) AIC score is 1837.931559587558
# for AR(3, 0, 11) AIC score is 1830.6556520306017
# for AR(4, 0, 1) AIC score is 1819.1891139661661
# for AR(4, 0, 2) AIC score is 1828.765707568624
# for AR(4, 0, 3) AIC score is 1828.2851007734153
# for AR(4, 0, 4) AIC score is 1821.9212983801983
# for AR(4, 0, 5) AIC score is 1828.5098540422766
# for AR(4, 0, 6) AIC score is 1854.5365550144807
# for AR(4, 0, 7) AIC score is 1825.5750435043194
# for AR(4, 0, 8) AIC score is 1827.0734600350067
# for AR(4, 0, 9) AIC score is 1829.6527626883708
# for AR(4, 0, 10) AIC score is 1843.2058922806225
# for AR(4, 0, 11) AIC score is 1829.1491787584794

# %% [markdown]
# ### Traing the model

# %%
p,d,q = 2,0,2
arma_model2 = ARIMA(train,order=(p,d,q)).fit()
print(arma_model2.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  price   No. Observations:                  116
# Model:                 ARIMA(2, 0, 2)   Log Likelihood               -1221.942
# Date:                Wed, 01 Feb 2023   AIC                           2455.883
# Time:                        21:53:17   BIC                           2472.405
# Sample:                    01-31-2008   HQIC                          2462.590
#                          - 08-31-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.936e+04   2.17e+04      0.891      0.373   -2.32e+04     6.2e+04
# ar.L1          1.2796      0.299      4.276      0.000       0.693       1.866
# ar.L2         -0.2914      0.293     -0.995      0.320      -0.866       0.283
# ma.L1         -0.2818      0.250     -1.127      0.260      -0.772       0.208
# ma.L2         -0.4714      0.097     -4.883      0.000      -0.661      -0.282
# sigma2      8.823e+07     26.389   3.34e+06      0.000    8.82e+07    8.82e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              1880.14
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):              32.34   Skew:                             3.82
# Prob(H) (two-sided):                  0.00   Kurtosis:                        21.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.62e+21. Standard errors may be unstable.

# %% [markdown]
# ### Predictions

# %%
start = len(train)
end =  len(train)+len(test)-1
pred = arma_model2.predict(start=start,end=end)

DF_ARMA2 = pd.DataFrame({'Actual':test,'Predicted':pred,'Error':test-pred})
DF_ARMA2.head()
# Out:
#               Actual     Predicted        Error
# 2017-09-30  20587.95  27160.023814 -6572.073814
# 2017-10-31  21489.62  31070.520354 -9580.900354
# 2017-11-30  22958.08  32071.625342 -9113.545342
# 2017-12-31  37410.06  32212.959387  5197.100613
# 2018-01-31  34952.69  32102.045512  2850.644488

# %% [markdown]
# ### Actual vs predicted

# %%
plt.figure(figsize=(15,5))

plt.plot(test,'b--',linewidth=2,label='actual')
plt.plot(pred,'r-',linewidth=2,label='predicted')

plt.title(f'ARMA Actual vs predicted')
plt.legend()
plt.grid()

# %% [markdown]
# ### Evaluation

# %%
mse = mean_squared_error(pred,test)
rmse = np.sqrt(mse)
print('\nRoot Mean squarred error for ARMA model for negative sentiments  is : ',round(rmse,2))
# Out:
# Root Mean squarred error for ARMA model for negative sentiments  is :  16103.83

# %% [markdown]
# ### Ljung box test

# %%
pvalue = sm.stats.acorr_ljungbox(arma_model2.resid,lags=[1],return_df=True)['lb_pvalue'].values
if pvalue < 0.05:
    print("Reject H0. Bad model")
else:
    print("Fail-to-Reject H0. Good model")
# Out:
# Fail-to-Reject H0. Good model

# %% [markdown]
# ### ARIMA model for negative sentiments

# %%
for p in range(1,5):
    for q in range(1,12):
        m1 = ARIMA(Stationary_negative,order=(p,12,q))
        r1 = m1.fit()
        print(f'for AR{p,12,q} AIC score is {r1.aic}')
# Out:
# for AR(1, 12, 1) AIC score is 2638.0350511726388
# for AR(1, 12, 2) AIC score is 2604.5046462225423
# for AR(1, 12, 3) AIC score is 2423.867105595619
# for AR(1, 12, 4) AIC score is 2577.062198308795
# for AR(1, 12, 5) AIC score is 2608.5574336689706
# for AR(1, 12, 6) AIC score is 2591.528428834647
# for AR(1, 12, 7) AIC score is 2607.015611993488
# for AR(1, 12, 8) AIC score is 2602.054573572848
# for AR(1, 12, 9) AIC score is 2620.2955860707107
# for AR(1, 12, 10) AIC score is 2622.215986540577
# for AR(1, 12, 11) AIC score is 2626.7012562179057
# for AR(2, 12, 1) AIC score is 2524.9295749827147
# for AR(2, 12, 2) AIC score is 10.0
# for AR(2, 12, 3) AIC score is 2315.7526723803317
# for AR(2, 12, 4) AIC score is 14.0
# for AR(2, 12, 5) AIC score is 2477.2866273110594
# for AR(2, 12, 6) AIC score is 2482.3722926479227
# for AR(2, 12, 7) AIC score is 2486.7252395262876
# for AR(2, 12, 8) AIC score is 2484.6039643558784
# for AR(2, 12, 9) AIC score is 2507.39077338435
# for AR(2, 12, 10) AIC score is 2507.8901518653843
# for AR(2, 12, 11) AIC score is 2526.899979474405
# for AR(3, 12, 1) AIC score is 2465.270683708515
# for AR(3, 12, 2) AIC score is 2352.6407929038273
# for AR(3, 12, 3) AIC score is 14.0
# for AR(3, 12, 4) AIC score is 2190.8421064890367
# for AR(3, 12, 5) AIC score is 2342.707264890904
# for AR(3, 12, 6) AIC score is 2351.6365947726226
# for AR(3, 12, 7) AIC score is 2362.8480604503065
# for AR(3, 12, 8) AIC score is 2364.2424089489828
# for AR(3, 12, 9) AIC score is 2397.456856363666
# for AR(3, 12, 10) AIC score is 2380.9331677914074
# for AR(3, 12, 11) AIC score is 2403.035801484213
# for AR(4, 12, 1) AIC score is 2409.1466976295105
# for AR(4, 12, 2) AIC score is 2279.827173394059
# for AR(4, 12, 3) AIC score is 2331.166287400408
# for AR(4, 12, 4) AIC score is 2309.1376550534046
# for AR(4, 12, 5) AIC score is 2292.139130798742
# for AR(4, 12, 6) AIC score is 2316.669224662978
# for AR(4, 12, 7) AIC score is 2317.37498447293
# for AR(4, 12, 8) AIC score is 2322.168380339754
# for AR(4, 12, 9) AIC score is 2340.676035525395
# for AR(4, 12, 10) AIC score is 2334.977750350577
# for AR(4, 12, 11) AIC score is 2355.27142915576

# %% [markdown]
# ### Training of model

# %%
p,d,q = 2,12,4

arima_model2 = ARIMA(train,order = (p,d,q)).fit()
print(arima_model2.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  price   No. Observations:                  116
# Model:                ARIMA(2, 12, 4)   Log Likelihood               -1562.745
# Date:                Wed, 01 Feb 2023   AIC                           3139.490
# Time:                        21:53:49   BIC                           3158.000
# Sample:                    01-31-2008   HQIC                          3146.989
#                          - 08-31-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.4170      1.239     -1.144      0.253      -3.845       1.011
# ar.L2         -0.7756      1.356     -0.572      0.567      -3.432       1.881
# ma.L1         -3.3413      1.853     -1.803      0.071      -6.974       0.291
# ma.L2          4.4530      5.062      0.880      0.379      -5.468      14.374
# ma.L3         -2.8030      6.145     -0.456      0.648     -14.847       9.241
# ma.L4          0.7031      3.435      0.205      0.838      -6.029       7.435
# sigma2      1.732e+12      9e-12   1.92e+23      0.000    1.73e+12    1.73e+12
# ===================================================================================
# Ljung-Box (L1) (Q):                  24.31   Jarque-Bera (JB):                38.24
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              36.86   Skew:                            -0.10
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.89e+39. Standard errors may be unstable.

# %% [markdown]
# ### Predictions

# %%
start = len(train)
end =  len(train)+len(test)-1
pred = arima_model2.predict(start=start,end=end)

DF_ARMA2 = pd.DataFrame({'Actual':test,'Predicted':pred,'Error':test-pred})
DF_ARMA2.head()
# Out:
#               Actual     Predicted         Error
# 2017-09-30  20587.95 -3.099833e+05  3.305713e+05
# 2017-10-31  21489.62 -2.104469e+06  2.125958e+06
# 2017-11-30  22958.08 -8.418342e+06  8.441300e+06
# 2017-12-31  37410.06 -2.624662e+07  2.628403e+07
# 2018-01-31  34952.69 -6.987494e+07  6.990989e+07

# %% [markdown]
# ### Actual vs predicted

# %%
plt.figure(figsize=(15,5))

plt.plot(test,'b--',linewidth=2,label='actual')
plt.plot(pred,'r-',linewidth=2,label='predicted')

plt.title(f'ARIMA Actual vs predicted')
plt.legend()
plt.grid()

# %% [markdown]
# Here we can see as per the time increasing error in predictions is also increasing that means model have heteroscedasticity factor

# %% [markdown]
# ### Evaluation

# %%
mse = mean_squared_error(pred,test)
rmse = np.sqrt(mse)
print('Root Mean squarred error for ARMA model for negative sentiments  is : ',round(rmse,2))
# Out:
# Root Mean squarred error for ARMA model for negative sentiments  is :  4683833107.67

# %% [markdown]
# ### Ljung box test

# %%
pvalue = sm.stats.acorr_ljungbox(arima_model2.resid,lags=[1],return_df=True)['lb_pvalue'].values
if pvalue < 0.05:
    print("Reject H0. Bad model")
else:
    print("Fail-to-Reject H0. Good model")
# Out:
# Reject H0. Bad model

# %% [markdown]
# ### SARIMA for negative sentiments

# %%
sarima_model2 = SARIMAX(train, order=(2,0,2), seasonal_order=(2,0,2,24)).fit()
pred=sarima_model2.predict(len(train),((len(train)+len(test)-1)))

# %% [markdown]
# ### Predictions

# %%
start = len(train)
end =  len(train)+len(test)-1
pred = sarima_model2.predict(start=start,end=end)

DF_SARMA2 = pd.DataFrame({'Actual':test,'Predicted':pred,'Error':test-pred})
DF_SARMA2.head()
# Out:
#               Actual     Predicted         Error
# 2017-09-30  20587.95  21076.462119   -488.512119
# 2017-10-31  21489.62  26931.250694  -5441.630694
# 2017-11-30  22958.08  29982.799486  -7024.719486
# 2017-12-31  37410.06  57414.778455 -20004.718455
# 2018-01-31  34952.69  56250.309101 -21297.619101

# %% [markdown]
# ### Actual vs predicted

# %%
plt.figure(figsize=(15,5))

plt.plot(test,'b--',linewidth=2,label='actual')
plt.plot(pred,'r-',linewidth=2,label='predicted')
plt.title(f'SARIMA actual vs predicted ')
plt.legend()
plt.grid()

# %% [markdown]
# ### Evaluation

# %%
mse = mean_squared_error(pred,test)
rmse = np.sqrt(mse)
print('Root Mean squarred error for ARMA model for negative sentiments  is : ',round(rmse,2))
# Out:
# Root Mean squarred error for ARMA model for negative sentiments  is :  16117.82

# %% [markdown]
# ### Ljung box test

# %%
pvalue = sm.stats.acorr_ljungbox(sarima_model2.resid,lags=[1],return_df=True)['lb_pvalue'].values
if pvalue < 0.05:
    print("Reject H0. Bad model")
else:
    print("Fail-to-Reject H0. Good model")
# Out:
# Fail-to-Reject H0. Good model

# %% [markdown]
# SARIMA model giving the best predictions with compare to the other models as it have low RMSE value and the predicted values are following the actual values path and closed to it

# %% [markdown]
# ### Forecasting the total sales for next year

# %%
start = len(train)+len(test)
end = start + 12
future = sarima_model2.predict(start=start,end=end)
future
# Out:
# 2018-10-31    25141.002420
# 2018-11-30    26302.300519
# 2018-12-31    57888.795135
# 2019-01-31    51156.975441
# 2019-02-28    22496.917032
# 2019-03-31    21627.578447
# 2019-04-30    19220.555369
# 2019-05-31    16231.632073
# 2019-06-30    14637.562407
# 2019-07-31    15379.579373
# 2019-08-31    13580.643346
# 2019-09-30    11899.132967
# 2019-10-31    15546.458872
# Freq: M, Name: predicted_mean, dtype: float64

# %%
plt.figure(figsize=(16,5))

plt.plot(Negative_resample,color='black',label='Actual')
plt.plot(future,color='red',label='Forecast')
plt.title('Demand forecasting for 2019')

plt.legend()
plt.show()

# %% [markdown]
# #### Observation
# 2019 starts off with increase in sum(price) i.e sales from the previous year
# follows the seasonality- sale hits peak at the 1st quarter and declines as the year passes reached lowest sales in november 2019 and then again increasd in december 2019

# %% [markdown]
# ## Demand forecasting for neutral sentiment products

# %% [markdown]
# ### Resempling on month basis

# %%
Neutral_resample = Neutral['price'].resample('m').sum()
Neutral_resample = Neutral_resample[Neutral_resample.index>'2007-01-01']
Neutral_resample
# Out:
# reviewTime
# 2007-01-31     2420.93
# 2007-02-28      321.43
# 2007-03-31     1285.47
# 2007-04-30     1323.72
# 2007-05-31      809.08
#                 ...
# 2018-06-30    16050.24
# 2018-07-31    12038.56
# 2018-08-31     5637.02
# 2018-09-30     1893.54
# 2018-10-31       20.99
# Freq: M, Name: price, Length: 142, dtype: float64

# %% [markdown]
# ### Decomposition plot for neutral sentiments

# %%
decomposition=seasonal_decompose(Neutral_resample, period=30)
d_trend=decomposition.trend
d_seasonal=decomposition.seasonal
d_residual=decomposition.resid

# plotting all the 4 graphs
fig,ax = plt.subplots(4,1,figsize=(12,8))

plt.subplot(411)
plt.plot(Neutral_resample,label='Actual')
plt.legend(loc='best')

plt.subplot(412)
plt.plot(d_trend,label='Trend')
plt.legend(loc='best')

plt.subplot(413)
plt.plot(d_seasonal,label='Seasonal')
plt.legend(loc='best')

plt.subplot(414)
plt.plot(d_residual,label='Residual')
plt.legend(loc='best')

plt.tight_layout()

# %% [markdown]
# Here we can see that the data have increasing trend after 2010 and start decreasing after 2015 as well as seasonality after every 2 years

# %% [markdown]
# ### ADF test (Stationarity)

# %%
checkStationarity(Neutral_resample)
# Out:
# 'p-value = 0.384. Data is not stationary'

# %% [markdown]
# ### Moving average to make data stationary

# %%
Stationary_neutral=Stationary_negative = Neutral_resample.rolling(window=15).mean().dropna()
checkStationarity(Stationary_neutral)
# Out:
# 'p-value = 0.032. Data is stationary'

# %% [markdown]
# ### Plot before & after data stationary

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(15,5))
ax[0].plot(Neutral_resample)
ax[0].set_title('Before making Data Stationary')
ax[1].plot(Stationary_neutral)
ax[1].set_title('After making Data Stationary')
plt.show()

# %% [markdown]
# ### ACF & PACF Plot

# %%
fig = plt.figure(figsize=(16,5))

# ACF
ax1 = fig.add_subplot(121)
sm.graphics.tsa.plot_acf(Stationary_neutral, lags=15, ax=ax1)

#  PACF
ax2 = fig.add_subplot(122)
sm.graphics.tsa.plot_pacf(Stationary_neutral, lags=15, ax=ax2)
plt.tight_layout()

# %% [markdown]
# ### Train - Test split

# %%
train_size = int(0.8 * len(Neutral_resample))

train = Neutral_resample.iloc[:train_size]
test = Neutral_resample.iloc[train_size:]
print("train = {}, test = {}".format(len(train), len(test)))
# Out:
# train = 113, test = 29

# %% [markdown]
# ### ARMA model for neutral sentiments

# %% [markdown]
# ### Hyperparameters with lowest AIC

# %%
for p in range(1,8):
    for q in range(1,10):
        model = ARIMA(Stationary_neutral,order=(p,0,q))
        result = model.fit()
        print(f'for {(p,0,q)} aic score is {result.aic}')
# Out:
# for (1, 0, 1) aic score is 2217.243720916559
# for (1, 0, 2) aic score is 2194.2269254805483
# for (1, 0, 3) aic score is 2185.377592796187
# for (1, 0, 4) aic score is 2182.1945789133842
# for (1, 0, 5) aic score is 2179.808999603245
# for (1, 0, 6) aic score is 2220.5540312665134
# for (1, 0, 7) aic score is 2236.8806074180143
# for (1, 0, 8) aic score is 2256.333352851591
# for (1, 0, 9) aic score is 2258.2389057486835
# for (2, 0, 1) aic score is 2188.426580505467
# for (2, 0, 2) aic score is 2182.86205320085
# for (2, 0, 3) aic score is 2179.440844986243
# for (2, 0, 4) aic score is 2178.996333324755
# for (2, 0, 5) aic score is 2166.7223619803244
# for (2, 0, 6) aic score is 2184.87811722847
# for (2, 0, 7) aic score is 2187.0351399445176
# for (2, 0, 8) aic score is 2188.8000969653635
# for (2, 0, 9) aic score is 2194.112324123685
# for (3, 0, 1) aic score is 2190.1594464209584
# for (3, 0, 2) aic score is 2191.055651026958
# for (3, 0, 3) aic score is 2181.548544814576
# for (3, 0, 4) aic score is 2174.496233742788
# for (3, 0, 5) aic score is 2168.6251616027594
# for (3, 0, 6) aic score is 2167.1249428018427
# for (3, 0, 7) aic score is 2171.4156228305005
# for (3, 0, 8) aic score is 2168.0306634155995
# for (3, 0, 9) aic score is 2170.4502379715786
# for (4, 0, 1) aic score is 2174.5430956139735
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Input In [288], in <cell line: 1>()
#       2 for q in range(1,10):
#       3     model = ARIMA(Stationary_neutral,order=(p,0,q))
# ----> 4     result = model.fit()
#       5     print(f'for {(p,0,q)} aic score is {result.aic}')
#
# File ~\anaconda3\lib\site-packages\statsmodels\tsa\arima\model.py:390, in ARIMA.fit(self, start_params, transformed, includes_fixed, method, method_kwargs, gls, gls_kwargs, cov_type, cov_kwds, return_params, low_memory)
#     387 else:
#     388     method_kwargs.setdefault('disp', 0)
# --> 390     res = super().fit(
#     391         return_params=return_params, low_memory=low_memory,
#     392         cov_type=cov_type, cov_kwds=cov_kwds, **method_kwargs)
#     393     if not return_params:
#     394         res.fit_details = res.mlefit
#
# File ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:704, in MLEModel.fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     702         flags['hessian_method'] = optim_hessian
#     703     fargs = (flags,)
# --> 704     mlefit = super(MLEModel, self).fit(start_params, method=method,
#     705                                        fargs=fargs,
#     706                                        maxiter=maxiter,
#     707                                        full_output=full_output,
#     708                                        disp=disp, callback=callback,
#     709                                        skip_hessian=True, **kwargs)
#     711 # Just return the fitted parameters if requested
#     712 if return_params:
#
# File ~\anaconda3\lib\site-packages\statsmodels\base\model.py:563, in LikelihoodModel.fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     560     del kwargs["use_t"]
#     562 optimizer = Optimizer()
# --> 563 xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     564                                                fargs, kwargs,
#     565                                                hessian=hess,
#     566                                                method=method,
#     567                                                disp=disp,
#     568                                                maxiter=maxiter,
#     569                                                callback=callback,
#     570                                                retall=retall,
#     571                                                full_output=full_output)
#     572 # Restore cov_type, cov_kwds and use_t
#     573 optim_settings.update(kwds)
#
# File ~\anaconda3\lib\site-packages\statsmodels\base\optimizer.py:241, in Optimizer._fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     238     fit_funcs.update(extra_fit_funcs)
#     240 func = fit_funcs[method]
# --> 241 xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     242                      disp=disp, maxiter=maxiter, callback=callback,
#     243                      retall=retall, full_output=full_output,
#     244                      hess=hessian)
#     246 optim_settings = {'optimizer': method, 'start_params': start_params,
#     247                   'maxiter': maxiter, 'full_output': full_output,
#     248                   'disp': disp, 'fargs': fargs, 'callback': callback,
#     249                   'retall': retall, "extra_fit_funcs": extra_fit_funcs}
#     250 optim_settings.update(kwargs)
#
# File ~\anaconda3\lib\site-packages\statsmodels\base\optimizer.py:651, in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     648 elif approx_grad:
#     649     func = f
# --> 651 retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     652                                  callback=callback, args=fargs,
#     653                                  bounds=bounds, disp=disp,
#     654                                  **extra_kwargs)
#     656 if full_output:
#     657     xopt, fopt, d = retvals
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py:197, in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     185     disp = iprint
#     186 opts = {'disp': disp,
#     187         'iprint': iprint,
#     188         'maxcor': m,
#    (...)
#     194         'callback': callback,
#     195         'maxls': maxls}
# --> 197 res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     198                        **opts)
#     199 d = {'grad': res['jac'],
#     200      'task': res['message'],
#     201      'funcalls': res['nfev'],
#     202      'nit': res['nit'],
#     203      'warnflag': res['status']}
#     204 f = res['fun']
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py:360, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     354 task_str = task.tobytes()
#     355 if task_str.startswith(b'FG'):
#     356     # The minimization routine wants f and g at the current x.
#     357     # Note that interruptions due to maxfun are postponed
#     358     # until the completion of the current minimization iteration.
#     359     # Overwrite f and g:
# --> 360     f, g = func_and_grad(x)
#     361 elif task_str.startswith(b'NEW_X'):
#     362     # new iteration
#     363     n_iterations += 1
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py:267, in ScalarFunction.fun_and_grad(self, x)
#     265 if not np.array_equal(x, self.x):
#     266     self._update_x_impl(x)
# --> 267 self._update_fun()
#     268 self._update_grad()
#     269 return self.f, self.g
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py:233, in ScalarFunction._update_fun(self)
#     231 def _update_fun(self):
#     232     if not self.f_updated:
# --> 233         self._update_fun_impl()
#     234         self.f_updated = True
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.update_fun()
#     136 def update_fun():
# --> 137     self.f = fun_wrapped(self.x)
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py:134, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     130 self.nfev += 1
#     131 # Send a copy because the user may overwrite it.
#     132 # Overwriting results in undefined behaviour because
#     133 # fun(self.x) will change self.x, with the two no longer linked.
# --> 134 return fun(np.copy(x), *args)
#
# File ~\anaconda3\lib\site-packages\statsmodels\base\model.py:531, in LikelihoodModel.fit.<locals>.f(params, *args)
#     530 def f(params, *args):
# --> 531     return -self.loglike(params, *args) / nobs
#
# File ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:939, in MLEModel.loglike(self, params, *args, **kwargs)
#     936 if complex_step:
#     937     kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
# --> 939 loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     941 # Koopman, Shephard, and Doornik recommend maximizing the average
#     942 # likelihood to avoid scale issues, but the averaging is done
#     943 # automatically in the base model `fit` method
#     944 return loglike
#
# File ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py:983, in KalmanFilter.loglike(self, **kwargs)
#     967 r"""
#     968 Calculate the loglikelihood associated with the statespace model.
#     969
#    (...)
#     979     The joint loglikelihood.
#     980 """
#     981 kwargs.setdefault('conserve_memory',
#     982                   MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD)
# --> 983 kfilter = self._filter(**kwargs)
#     984 loglikelihood_burn = kwargs.get('loglikelihood_burn',
#     985                                 self.loglikelihood_burn)
#     986 if not (kwargs['conserve_memory'] & MEMORY_NO_LIKELIHOOD):
#
# File ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py:903, in KalmanFilter._filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     900 kfilter = self._kalman_filters[prefix]
#     902 # Initialize the state
# --> 903 self._initialize_state(prefix=prefix, complex_step=complex_step)
#     905 # Run the filter
#     906 kfilter()
#
# File ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\representation.py:983, in Representation._initialize_state(self, prefix, complex_step)
#     981     if not self.initialization.initialized:
#     982         raise RuntimeError('Initialization is incomplete.')
# --> 983     self._statespaces[prefix].initialize(self.initialization,
#     984                                          complex_step=complex_step)
#     985 else:
#     986     raise RuntimeError('Statespace model not initialized.')
#
# File statsmodels\tsa\statespace\_representation.pyx:1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize()
#
# File statsmodels\tsa\statespace\_initialization.pyx:288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize()
#
# File statsmodels\tsa\statespace\_initialization.pyx:406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov()
#
# File statsmodels\tsa\statespace\_tools.pyx:1206, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov()
#
# LinAlgError: LU decomposition error.

# %% [markdown]
# ### Training the model

# %%
p=7;q=6
model = ARIMA(train,order=(p,0,q))
arma_model3 = model.fit()
arma_model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  price   No. Observations:                  113
# Model:                 ARIMA(7, 0, 6)   Log Likelihood               -1203.799
# Date:                Wed, 01 Feb 2023   AIC                           2437.598
# Time:                        21:56:10   BIC                           2478.509
# Sample:                    01-31-2007   HQIC                          2454.199
#                          - 05-31-2016
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        2.61e+04   2.62e+04      0.997      0.319   -2.52e+04    7.74e+04
# ar.L1          0.2887      0.825      0.350      0.726      -1.329       1.906
# ar.L2         -0.2250      0.981     -0.229      0.819      -2.148       1.698
# ar.L3         -0.2691      1.059     -0.254      0.799      -2.345       1.807
# ar.L4          0.5318      0.735      0.724      0.469      -0.908       1.972
# ar.L5         -0.1949      0.251     -0.777      0.437      -0.686       0.297
# ar.L6          0.1693      0.233      0.728      0.467      -0.287       0.625
# ar.L7          0.4120      0.300      1.375      0.169      -0.175       0.999
# ma.L1          0.7191      0.891      0.807      0.419      -1.026       2.465
# ma.L2          0.5993      0.455      1.319      0.187      -0.292       1.490
# ma.L3          0.9902      0.639      1.549      0.121      -0.263       2.243
# ma.L4          0.4625      0.420      1.101      0.271      -0.361       1.286
# ma.L5          0.9172      0.221      4.147      0.000       0.484       1.351
# ma.L6          0.7591      0.632      1.201      0.230      -0.480       1.998
# sigma2      9.335e+07      0.879   1.06e+08      0.000    9.34e+07    9.34e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               272.05
# Prob(Q):                              0.92   Prob(JB):                         0.00
# Heteroskedasticity (H):              18.53   Skew:                             1.54
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 9.02e+24. Standard errors may be unstable.
# """

# %% [markdown]
# ### Predictions

# %%
start = len(train)
end = len(train)+len(test)-1

pred = arma_model3.predict(start=start,end=end)

DF_ARMA3 = pd.DataFrame({ 'Actual':test, 'Predicted':pred, 'Error':test-pred})
DF_ARMA3.head()
# Out:
#               Actual     Predicted         Error
# 2016-06-30  60919.55  70938.372709 -10018.822709
# 2016-07-31  70344.84  62076.680303   8268.159697
# 2016-08-31  71818.64  58724.968767  13093.671233
# 2016-09-30  68539.70  42389.307829  26150.392171
# 2016-10-31  62694.58  37106.801853  25587.778147

# %% [markdown]
# ### Actual vs predicted

# %%
plt.figure(figsize=(15,5))

plt.plot(test,'b--',linewidth=2,label='actual')
plt.plot(pred,'r-',linewidth=2,label='predicted')

plt.title(f'ARMA actual vs predicted')
plt.legend()
plt.grid()

# %% [markdown]
# ### Evaluation

# %%
mse = mean_squared_error(pred,test)
rmse = np.sqrt(mse)
print('Root Mean squarred error for ARMA model for Neutral sentiments  is : ',round(rmse,2))
# Out:
# Root Mean squarred error for ARMA model for Neutral sentiments  is :  21654.88

# %% [markdown]
# ### Ljung box

# %%
pvalue = sm.stats.acorr_ljungbox(arma_model3.resid,lags=[1],return_df=True)['lb_pvalue'].values
if pvalue < 0.05:
    print("Reject H0. Bad model")
else:
    print("Fail-to-Reject H0. Good model")
# Out:
# Fail-to-Reject H0. Good model

# %% [markdown]
# ### ARIMA model for neutral sentiments

# %%
for p in range(1,3):
    for q in range(1,13):
        model = ARIMA(Stationary_neutral,order=(p,15,q))
        result = model.fit()
        print(f'for {(p,15,q)} aic score is {result.aic}')
# Out:
# for (1, 15, 1) aic score is 3390.1855805172454
# for (1, 15, 2) aic score is 3365.2332102678088
# for (1, 15, 3) aic score is 3348.636508347122
# for (1, 15, 4) aic score is 3344.173085311957
# for (1, 15, 5) aic score is 3346.1278298012016
# for (1, 15, 6) aic score is 3343.350034479452
# for (1, 15, 7) aic score is 3349.485853654479
# for (1, 15, 8) aic score is 3367.033741043735
# for (1, 15, 9) aic score is 3382.8740095493768
# for (1, 15, 10) aic score is 3402.3553666134717
# for (1, 15, 11) aic score is 3405.064744032577
# for (1, 15, 12) aic score is 3408.9981323436864
# for (2, 15, 1) aic score is 3133.2664477660196
# for (2, 15, 2) aic score is 3041.6065402147456
# for (2, 15, 3) aic score is 2955.4776195574946
# for (2, 15, 4) aic score is 2996.8616293549458
# for (2, 15, 5) aic score is 3040.027624041688
# for (2, 15, 6) aic score is 3006.8387983267257
# for (2, 15, 7) aic score is 3055.3827183185435
# for (2, 15, 8) aic score is 3093.52106991244
# for (2, 15, 9) aic score is 3106.636801075778
# for (2, 15, 10) aic score is 3103.3389460228996
# for (2, 15, 11) aic score is 3123.045104192501
# for (2, 15, 12) aic score is 3130.665840868973

# %% [markdown]
# ### training the model

# %%
p,d,q = 2,15,3

arima_model3 = ARIMA(train,order=(p,d,q)).fit()
print(arima_model3.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  price   No. Observations:                  113
# Model:                ARIMA(2, 15, 3)   Log Likelihood               -1603.860
# Date:                Wed, 01 Feb 2023   AIC                           3219.720
# Time:                        21:56:29   BIC                           3235.229
# Sample:                    01-31-2007   HQIC                          3225.993
#                          - 05-31-2016
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.5905      0.175     -9.108      0.000      -1.933      -1.248
# ar.L2         -0.8642      0.188     -4.596      0.000      -1.233      -0.496
# ma.L1         -2.8066      0.467     -6.014      0.000      -3.721      -1.892
# ma.L2          2.7062      0.910      2.975      0.003       0.923       4.489
# ma.L3         -0.8964      0.657     -1.364      0.172      -2.184       0.391
# sigma2      2.197e+13   8.22e-14   2.67e+26      0.000     2.2e+13     2.2e+13
# ===================================================================================
# Ljung-Box (L1) (Q):                  31.20   Jarque-Bera (JB):                60.59
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              17.24   Skew:                             0.17
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.23e+42. Standard errors may be unstable.

# %% [markdown]
# ### Predictions

# %%
start = len(train)
end = len(train)+len(test)-1

pred = arima_model3.predict(start=start,end=end)

DF_ARIMA3 = pd.DataFrame({ 'Actual':test, 'Predicted':pred, 'Error':test-pred})
DF_ARIMA3.head()
# Out:
#               Actual     Predicted         Error
# 2016-06-30  60919.55  6.751544e+06 -6.690624e+06
# 2016-07-31  70344.84  6.634188e+07 -6.627153e+07
# 2016-08-31  71818.64  3.713027e+08 -3.712309e+08
# 2016-09-30  68539.70  1.539281e+09 -1.539213e+09
# 2016-10-31  62694.58  5.247672e+09 -5.247609e+09

# %% [markdown]
# ### Actual vs Predicted

# %%
plt.figure(figsize=(15,5))

plt.plot(test,'b--',linewidth=2,label='actual')
plt.plot(pred,'r-',linewidth=2,label='predicted')

plt.title(f'ARIMA Actual vs predicted ')
plt.legend()
plt.grid()

# %% [markdown]
# ### Evaluation

# %%
mse = mean_squared_error(pred,test)
rmse = np.sqrt(mse)
print('Root Mean squarred error for ARIMA model for Neutral sentiments  is : ',round(rmse,2))
# Out:
# Root Mean squarred error for ARIMA model for Neutral sentiments  is :  1274218836552319.8

# %% [markdown]
# ### Ljung box test

# %%
pvalue = sm.stats.acorr_ljungbox(arima_model3.resid,lags=[1],return_df=True)['lb_pvalue'].values
if pvalue < 0.05:
    print("Reject H0. Bad model")
else:
    print("Fail-to-Reject H0. Good model")
# Out:
# Reject H0. Bad model

# %% [markdown]
# ### SARIMA model for neutral sentiments

# %%
p,d,q = (7, 0, 9)

sarima_model3 = SARIMAX(train,order=(p,d,q),seasonal_order=(p,d,q,24)).fit()
print(sarima_model3.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              price   No. Observations:                  113
# Model:             SARIMAX(7, 0, 9)x(7, 0, 9, 24)   Log Likelihood               -1191.181
# Date:                            Wed, 01 Feb 2023   AIC                           2448.363
# Time:                                    22:00:43   BIC                           2538.367
# Sample:                                01-31-2007   HQIC                          2484.885
#                                      - 05-31-2016
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2286      3.235      0.071      0.944      -6.112       6.570
# ar.L2         -0.5137      3.063     -0.168      0.867      -6.516       5.489
# ar.L3         -0.1342      3.424     -0.039      0.969      -6.845       6.577
# ar.L4          0.0595      2.523      0.024      0.981      -4.886       5.005
# ar.L5          0.4700      2.506      0.188      0.851      -4.441       5.381
# ar.L6         -0.2895      2.057     -0.141      0.888      -4.321       3.742
# ar.L7          0.6614      1.698      0.390      0.697      -2.666       3.988
# ma.L1          0.6952      3.558      0.195      0.845      -6.277       7.668
# ma.L2          1.1365      1.490      0.763      0.446      -1.784       4.057
# ma.L3          1.4978      3.301      0.454      0.650      -4.973       7.969
# ma.L4          1.3157      3.692      0.356      0.722      -5.920       8.552
# ma.L5          1.1061      1.630      0.678      0.497      -2.089       4.301
# ma.L6          1.4110      3.511      0.402      0.688      -5.471       8.293
# ma.L7          0.7797      1.931      0.404      0.686      -3.005       4.564
# ma.L8          0.6043      1.511      0.400      0.689      -2.357       3.565
# ma.L9          0.3924      1.856      0.211      0.833      -3.245       4.029
# ar.S.L24       0.2450   1.26e+04   1.95e-05      1.000   -2.47e+04    2.47e+04
# ar.S.L48       0.0765   1.19e+04   6.42e-06      1.000   -2.34e+04    2.34e+04
# ar.S.L72      -0.0007   1.35e+04  -5.49e-08      1.000   -2.64e+04    2.64e+04
# ar.S.L96      -0.0070   1.62e+04  -4.34e-07      1.000   -3.17e+04    3.17e+04
# ar.S.L120     -0.0041   8487.645  -4.79e-07      1.000   -1.66e+04    1.66e+04
# ar.S.L144     -0.0049   1.75e+04  -2.82e-07      1.000   -3.43e+04    3.43e+04
# ar.S.L168     -0.0029   1.65e+04  -1.73e-07      1.000   -3.24e+04    3.24e+04
# ma.S.L24       0.3061   1.26e+04   2.43e-05      1.000   -2.47e+04    2.47e+04
# ma.S.L48       0.1190   1.59e+04   7.48e-06      1.000   -3.12e+04    3.12e+04
# ma.S.L72       0.0857   1.15e+04   7.45e-06      1.000   -2.25e+04    2.25e+04
# ma.S.L96       0.0348   1.39e+04   2.51e-06      1.000   -2.72e+04    2.72e+04
# ma.S.L120      0.0139   7320.518   1.89e-06      1.000   -1.43e+04    1.43e+04
# ma.S.L144      0.0087   2.04e+04   4.29e-07      1.000   -3.99e+04    3.99e+04
# ma.S.L168      0.0051   1.28e+04   3.99e-07      1.000   -2.52e+04    2.52e+04
# ma.S.L192      0.0015   1.14e+04   1.36e-07      1.000   -2.23e+04    2.23e+04
# ma.S.L216      0.0004   1.08e+04   3.93e-08      1.000   -2.12e+04    2.12e+04
# sigma2      1.313e+08      0.813   1.61e+08      0.000    1.31e+08    1.31e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):               180.20
# Prob(Q):                              0.89   Prob(JB):                         0.00
# Heteroskedasticity (H):              10.82   Skew:                             1.25
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.32e+25. Standard errors may be unstable.

# %% [markdown]
# ### Predictions

# %%
start = len(train)
end = len(train)+len(test)-1

pred = sarima_model3.predict(start=start,end=end)

DF_SARIMA3 = pd.DataFrame({ 'Actual':test, 'Predicted':pred, 'Error':test-pred})
DF_SARIMA3.head()
# Out:
#               Actual     Predicted        Error
# 2016-06-30  60919.55  68385.416576 -7465.866576
# 2016-07-31  70344.84  67223.194027  3121.645973
# 2016-08-31  71818.64  74857.744331 -3039.104331
# 2016-09-30  68539.70  66152.340287  2387.359713
# 2016-10-31  62694.58  55169.635671  7524.944329

# %% [markdown]
# ### Actual vs predicted

# %%
plt.figure(figsize=(15,5))

plt.plot(test,'b--',linewidth=2,label='actual')
plt.plot(pred,'r-',linewidth=2,label='predicted')

plt.title(f'SARIMA Actual vs predicted')
plt.legend()
plt.grid()

# %% [markdown]
# ### Evaluation

# %%
mse = mean_squared_error(pred,test)
rmse = np.sqrt(mse)
print('Root Mean squarred error for SARIMA model for Neutral sentiments  is : ',round(rmse,2))
# Out:
# Root Mean squarred error for SARIMA model for Neutral sentiments  is :  21940.91

# %% [markdown]
# ### Ljung box test

# %%
pvalue = sm.stats.acorr_ljungbox(sarima_model3.resid,lags=[1],return_df=True)['lb_pvalue'].values
if pvalue < 0.05:
    print("Reject H0. Bad model")
else:
    print("Fail-to-Reject H0. Good model")
# Out:
# Fail-to-Reject H0. Good model

# %% [markdown]
# ### Forecasting the total sales for next year

# %%
start = len(train)+len(test)
end = start + 12
future = sarima_model3.predict(start=start,end=end)
future
# Out:
# 2018-11-30    34370.573975
# 2018-12-31    62119.808250
# 2019-01-31    63015.435238
# 2019-02-28    41315.984338
# 2019-03-31    31508.081697
# 2019-04-30    28293.961863
# 2019-05-31    28580.829440
# 2019-06-30    31703.539924
# 2019-07-31    34393.574974
# 2019-08-31    34764.793838
# 2019-09-30    30189.400610
# 2019-10-31    27723.292617
# 2019-11-30    30183.126417
# Freq: M, Name: predicted_mean, dtype: float64

# %%
plt.figure(figsize=(16,5))

plt.plot(Neutral_resample,color='black',label='Actual')
plt.plot(future,color='red',label='Forecast')
plt.title('Demand forecasting for 2019')

plt.legend()
plt.show()

# %% [markdown]
# #### Observation
# 2019 starts off with increase in sum(price) i.e sales from the previous year
# follows the seasonality- sale hits highest peak at the 1st quarter and 2nd highest peak at the end of the third quarter

# %% [markdown]
# ---

# %% [markdown]
# ### Forecasting the total sales of the category with highest reviews
# ['Toys & Games', 'Action Figures & Statues', 'Action Figures']

# %%
prod  = df[(df['category'] == "['Toys & Games', 'Action Figures & Statues', 'Action Figures']")]
prod.head(3)
# Out:
#       overall  verified reviewTime        asin  \
# 2586      5.0     False 2014-11-07  1616594985
# 2587      5.0      True 2014-10-30  1616594985
# 2588      5.0      True 2016-07-23  1616594985
#
#                                              reviewText  \
# 2586  cersei lannister finally dark horse treatment ...
# 2587  arrived today week finally jamie lannister com...
# 2588  div id video block r2trhl6l66yo8n class sectio...
#
#                                                 summary  \
# 2586       Beautiful and devious Cercei gets her figure
# 2587  It arrived today 3 weeks finally. It and Jamie...
# 2588                             All Hail Queen Cersei!
#
#                                                category              brand  \
# 2586  ['Toys & Games', 'Action Figures & Statues', '...  Dark Horse Deluxe
# 2587  ['Toys & Games', 'Action Figures & Statues', '...  Dark Horse Deluxe
# 2588  ['Toys & Games', 'Action Figures & Statues', '...  Dark Horse Deluxe
#
#        price sentiment predicted
# 2586  139.99  Positive  Positive
# 2587  139.99  Positive   Neutral
# 2588  139.99  Positive  Positive

# %%
prod = prod.sort_values(by='reviewTime',ascending=True)
prod = prod.set_index('reviewTime')
prod = prod['price']
prod.head(3)
# Out:
# reviewTime
# 2000-05-02    19.95
# 2000-05-02    19.95
# 2001-06-13    35.77
# Name: price, dtype: float64

# %% [markdown]
# ### weekly resempling

# %%
prod = prod.resample('W').sum().round(2)
prod.head()
# Out:
# reviewTime
# 2000-05-07    39.9
# 2000-05-14     0.0
# 2000-05-21     0.0
# 2000-05-28     0.0
# 2000-06-04     0.0
# Freq: W-SUN, Name: price, dtype: float64

# %% [markdown]
# ### Data continuity

# %%
category_resemple = prod[prod.index>'2009-05-24']
category_resemple[:5]
# Out:
# reviewTime
# 2009-05-31     707.13
# 2009-06-07     366.02
# 2009-06-14     125.66
# 2009-06-21    1145.75
# 2009-06-28     661.65
# Freq: W-SUN, Name: price, dtype: float64

# %% [markdown]
# ### Decomposition chart

# %%
decomposition=seasonal_decompose(category_resemple, period=30)
d_trend=decomposition.trend
d_seasonal=decomposition.seasonal
d_residual=decomposition.resid

# plotting all the 4 graphs
fig,ax = plt.subplots(4,1,figsize=(12,8))

plt.subplot(411)
plt.plot(Negative_resample,label='Actual')
plt.legend(loc='best')

plt.subplot(412)
plt.plot(d_trend,label='Trend')
plt.legend(loc='best')

plt.subplot(413)
plt.plot(d_seasonal,label='Seasonal')
plt.legend(loc='best')

plt.subplot(414)
plt.plot(d_residual,label='Residual')
plt.legend(loc='best')

plt.tight_layout()

# %% [markdown]
# ### Stationary check

# %%
checkStationarity(category_resemple)
# Out:
# 'p-value = 0.477. Data is not stationary'

# %% [markdown]
# ### making data stationary

# %%
category_resemple1 = category_resemple-category_resemple.shift(1)
category_resemple1 = category_resemple.dropna(axis=0)
category_resemple1
# Out:
# reviewTime
# 2009-05-31     707.13
# 2009-06-07     366.02
# 2009-06-14     125.66
# 2009-06-21    1145.75
# 2009-06-28     661.65
#                ...
# 2018-09-02     920.62
# 2018-09-09     246.23
# 2018-09-16     282.12
# 2018-09-23     296.84
# 2018-09-30     154.94
# Freq: W-SUN, Name: price, Length: 488, dtype: float64

# %%
checkStationarity(category_resemple1)
# Out:
# 'p-value = 0.477. Data is not stationary'

# %% [markdown]
# ### ACF & PACF Plot

# %%
fig = plt.figure(figsize=(16,5))

ax1 = fig.add_subplot(121)
sm.graphics.tsa.plot_acf(category_resemple, lags=12, ax=ax1)

ax2 = fig.add_subplot(122)
sm.graphics.tsa.plot_pacf(category_resemple, lags=12, ax=ax2)
plt.tight_layout()

# %% [markdown]
# ### Train -Test Split

# %%
train_size = int(0.90 * len(prod)) 
train = prod.iloc[:train_size]
test = prod.iloc[train_size:]
print("train = {}, test = {}".format(len(train), len(test)))
# Out:
# train = 864, test = 97

# %% [markdown]
# ### ARMA model for cateory sales forecasting

# %% [markdown]
# ### Hyperparameters for lowest AIC score

# %%
for p in range(1,8):
    for q in range(1,13):
        model = ARIMA(category_resemple1,order=(p,0,q))
        result = model.fit()
        print(f'for {(p,0,q)} aic score is {result.aic}')
# Out:
# for (1, 0, 1) aic score is 8984.690377055722
# for (1, 0, 2) aic score is 8982.022609205664
# for (1, 0, 3) aic score is 8983.341433838274
# for (1, 0, 4) aic score is 8985.478555213693
# for (1, 0, 5) aic score is 8984.386458412555
# for (1, 0, 6) aic score is 8985.060233743981
# for (1, 0, 7) aic score is 8985.537738211926
# for (1, 0, 8) aic score is 8982.45748134948
# for (1, 0, 9) aic score is 8982.400645432854
# for (1, 0, 10) aic score is 8984.088425027985
# for (1, 0, 11) aic score is 8981.469230949626
# for (1, 0, 12) aic score is 8983.91645284713
# for (2, 0, 1) aic score is 8980.035318234699
# for (2, 0, 2) aic score is 8979.523591112847
# for (2, 0, 3) aic score is 8983.47042444022
# for (2, 0, 4) aic score is 8985.578955081219
# for (2, 0, 5) aic score is 8987.209330551668
# for (2, 0, 6) aic score is 8985.690408828166
# for (2, 0, 7) aic score is 8982.231461973002
# for (2, 0, 8) aic score is 8982.841504315651
# for (2, 0, 9) aic score is 8981.527403573962
# for (2, 0, 10) aic score is 8983.648335519327
# for (2, 0, 11) aic score is 8983.396877425637
# for (2, 0, 12) aic score is 8984.404502874811
# for (3, 0, 1) aic score is 8980.001502678482
# for (3, 0, 2) aic score is 8984.035315347304
# for (3, 0, 3) aic score is 8983.570396633539
# for (3, 0, 4) aic score is 8984.88136711091
# for (3, 0, 5) aic score is 8983.593829071498
# for (3, 0, 6) aic score is 8986.5946616839
# for (3, 0, 7) aic score is 8981.72895270184
# for (3, 0, 8) aic score is 8984.623115797289
# for (3, 0, 9) aic score is 8980.81085283333
# for (3, 0, 10) aic score is 8981.552341190578
# for (3, 0, 11) aic score is 8976.109320778216
# for (3, 0, 12) aic score is 8977.134949344956
# for (4, 0, 1) aic score is 8984.656433686454
# for (4, 0, 2) aic score is 8983.32403969951
# for (4, 0, 3) aic score is 8976.834403724431
# for (4, 0, 4) aic score is 8976.983225570879
# for (4, 0, 5) aic score is 8985.57107780467
# for (4, 0, 6) aic score is 8987.603178259462
# for (4, 0, 7) aic score is 8975.324421771424
# for (4, 0, 8) aic score is 8979.43351082152
# for (4, 0, 9) aic score is 8980.913749413416
# for (4, 0, 10) aic score is 8982.77222573926
# for (4, 0, 11) aic score is 8971.908544696813
# for (4, 0, 12) aic score is 8973.949440989967
# for (5, 0, 1) aic score is 8986.498618451833
# for (5, 0, 2) aic score is 8982.171308818624
# for (5, 0, 3) aic score is 8980.528141126597
# for (5, 0, 4) aic score is 8977.247694409794
# for (5, 0, 5) aic score is 8975.624150063473
# for (5, 0, 6) aic score is 8977.617296113644
# for (5, 0, 7) aic score is 8983.262290280112
# for (5, 0, 8) aic score is 8974.859181015989
# for (5, 0, 9) aic score is 8977.323693207254
# for (5, 0, 10) aic score is 8981.021721736444
# for (5, 0, 11) aic score is 8974.174291090781
# for (5, 0, 12) aic score is 8977.568064357129
# for (6, 0, 1) aic score is 18.0
# for (6, 0, 2) aic score is 8986.360317400038
# for (6, 0, 3) aic score is 8981.051814008591
# for (6, 0, 4) aic score is 8978.904552658882
# for (6, 0, 5) aic score is 8969.929505907365
# for (6, 0, 6) aic score is 8972.107627876463
# for (6, 0, 7) aic score is 8971.971640552381
# for (6, 0, 8) aic score is 8976.860404567446
# for (6, 0, 9) aic score is 8978.270033866384
# for (6, 0, 10) aic score is 8978.945914770156
# for (6, 0, 11) aic score is 8976.535964561866
# for (6, 0, 12) aic score is 8980.4825974926
# for (7, 0, 1) aic score is 8985.004160458844
# for (7, 0, 2) aic score is 8985.899962213074
# for (7, 0, 3) aic score is 8978.693302415115
# for (7, 0, 4) aic score is 8980.428591228767
# for (7, 0, 5) aic score is 8971.650974539087
# for (7, 0, 6) aic score is 8974.682641710897
# for (7, 0, 7) aic score is 8973.68883473454
# for (7, 0, 8) aic score is 8976.933490554857
# for (7, 0, 9) aic score is 8978.350616813088
# for (7, 0, 10) aic score is 8981.275606452647
# for (7, 0, 11) aic score is 8978.230145409276
# for (7, 0, 12) aic score is 8980.344919261997

# %% [markdown]
# ### Training of model

# %%
p,d,q = 6,0,6

model1 = ARIMA(train, order=(p,d,q)).fit()
print(model1.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  price   No. Observations:                  864
# Model:                 ARIMA(6, 0, 6)   Log Likelihood               -7576.264
# Date:                Wed, 01 Feb 2023   AIC                          15180.529
# Time:                        22:02:40   BIC                          15247.191
# Sample:                    05-07-2000   HQIC                         15206.044
#                          - 11-20-2016
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3256.2941   2.49e-08   1.31e+11      0.000    3256.294    3256.294
# ar.L1          0.0166      0.046      0.364      0.716      -0.073       0.106
# ar.L2          0.6924      0.044     15.858      0.000       0.607       0.778
# ar.L3          0.0960      0.022      4.366      0.000       0.053       0.139
# ar.L4          0.8707      0.023     38.309      0.000       0.826       0.915
# ar.L5          0.1261      0.040      3.181      0.001       0.048       0.204
# ar.L6         -0.8030      0.037    -21.903      0.000      -0.875      -0.731
# ma.L1          0.7035      0.047     14.858      0.000       0.611       0.796
# ma.L2         -0.0569      0.049     -1.165      0.244      -0.153       0.039
# ma.L3         -0.0482      0.037     -1.301      0.193      -0.121       0.024
# ma.L4         -0.8241      0.027    -31.075      0.000      -0.876      -0.772
# ma.L5         -0.7204      0.039    -18.531      0.000      -0.797      -0.644
# ma.L6          0.1888      0.027      7.083      0.000       0.137       0.241
# sigma2        2.6e+06   2.84e-08   9.15e+13      0.000     2.6e+06     2.6e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):             30227.10
# Prob(Q):                              0.87   Prob(JB):                         0.00
# Heteroskedasticity (H):             393.65   Skew:                             2.90
# Prob(H) (two-sided):                  0.00   Kurtosis:                        31.39
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.23e+29. Standard errors may be unstable.

# %% [markdown]
# ### Predictions

# %%
start = len(train)
end =  len(train)+len(test)-1
pred = model1.predict(start=start,end=end)

DF_ARMA = pd.DataFrame({ 'Actual':test, 'Predicted':pred, 'Error':-test+pred})
DF_ARMA.head()
# Out:
#               Actual     Predicted        Error
# 2016-11-27  12501.41  11116.974627 -1384.435373
# 2016-12-04  15067.04  12997.799667 -2069.240333
# 2016-12-11  19488.52  12352.321324 -7136.198676
# 2016-12-18  16050.86  12236.259006 -3814.600994
# 2016-12-25  19515.66  11768.769643 -7746.890357

# %% [markdown]
# ### Actual vs predicted

# %%
plt.figure(figsize=(15,5))

plt.plot(test,'b--',linewidth=2,label='actual')
plt.plot(pred,'r-',linewidth=2,label='predicted')

plt.title(f'ARMA Actual vs predicted')
plt.legend()
plt.grid()

# %% [markdown]
# ### Evaluation

# %%
mse = mean_squared_error(pred,test)
rmse = np.sqrt(mse)
print('Root Mean squarred error for ARMA model  is : ',round(rmse,2))
# Out:
# Root Mean squarred error for ARMA model  is :  8297.47

# %% [markdown]
# ### Ljung box test

# %%
pvalue = sm.stats.acorr_ljungbox(model1.resid,lags=[1],return_df=True)['lb_pvalue'].values
if pvalue < 0.05:
    print("Reject H0. Bad model")
else:
    print("Fail-to-Reject H0. Good model")
# Out:
# Fail-to-Reject H0. Good model

# %% [markdown]
# ### ARIMA Model

# %%
for p in range(1,8):
    for q in range(1,13):
        model = ARIMA(category_resemple1,order=(p,1,q))
        result = model.fit()
        print(f'for {(p,1,q)} aic score is {result.aic}')
# Out:
# for (1, 1, 1) aic score is 8958.080439756464
# for (1, 1, 2) aic score is 8956.895329617273
# for (1, 1, 3) aic score is 8957.987578792821
# for (1, 1, 4) aic score is 8967.920732302595
# for (1, 1, 5) aic score is 8961.302713482622
# for (1, 1, 6) aic score is 8962.964759654958
# for (1, 1, 7) aic score is 8960.200090898776
# for (1, 1, 8) aic score is 8961.156743004054
# for (1, 1, 9) aic score is 8958.93983789957
# for (1, 1, 10) aic score is 8961.077917642371
# for (1, 1, 11) aic score is 8960.80123413772
# for (1, 1, 12) aic score is 8961.784085458854
# for (2, 1, 1) aic score is 8957.34279002417
# for (2, 1, 2) aic score is 8960.115098331418
# for (2, 1, 3) aic score is 8959.973980476696
# for (2, 1, 4) aic score is 8960.66672942686
# for (2, 1, 5) aic score is 8961.01445013666
# for (2, 1, 6) aic score is 8962.959159265552
# for (2, 1, 7) aic score is 8960.06577553754
# for (2, 1, 8) aic score is 8960.90434620417
# for (2, 1, 9) aic score is 8957.808957312784
# for (2, 1, 10) aic score is 8962.241213659849
# for (2, 1, 11) aic score is 8952.917757233867
# for (2, 1, 12) aic score is 8950.537933053754
# for (3, 1, 1) aic score is 8957.843226616555
# for (3, 1, 2) aic score is 8960.734125910052
# for (3, 1, 3) aic score is 8958.42543872596
# for (3, 1, 4) aic score is 8955.026385776624
# for (3, 1, 5) aic score is 8965.504915543523
# for (3, 1, 6) aic score is 8967.073293437825
# for (3, 1, 7) aic score is 8953.2470426187
# for (3, 1, 8) aic score is 8954.889215880079
# for (3, 1, 9) aic score is 8959.304317309181
# for (3, 1, 10) aic score is 8964.44299795743
# for (3, 1, 11) aic score is 8950.697934194612
# for (3, 1, 12) aic score is 8951.506297280728
# for (4, 1, 1) aic score is 8959.686133497922
# for (4, 1, 2) aic score is 8959.484236661252
# for (4, 1, 3) aic score is 8957.006866579759
# for (4, 1, 4) aic score is 8953.655053164053
# for (4, 1, 5) aic score is 8954.122324892789
# for (4, 1, 6) aic score is 8954.838378462915
# for (4, 1, 7) aic score is 8951.462631657834
# for (4, 1, 8) aic score is 8952.068138304245
# for (4, 1, 9) aic score is 8954.51037168983
# for (4, 1, 10) aic score is 8957.916295424011
# for (4, 1, 11) aic score is 8952.903349209795
# for (4, 1, 12) aic score is 8954.614056509969
# for (5, 1, 1) aic score is 8960.327345949907
# for (5, 1, 2) aic score is 8961.111435312323
# for (5, 1, 3) aic score is 8962.976554593602
# for (5, 1, 4) aic score is 8952.265820878129
# for (5, 1, 5) aic score is 8957.84280368287
# for (5, 1, 6) aic score is 8949.186609973
# for (5, 1, 7) aic score is 8950.301468215008
# for (5, 1, 8) aic score is 8954.359421345682
# for (5, 1, 9) aic score is 8957.733333054712
# for (5, 1, 10) aic score is 8955.765338810836
# for (5, 1, 11) aic score is 8954.46242375288
# for (5, 1, 12) aic score is 8956.901355633896
# for (6, 1, 1) aic score is 8962.29837064668
# for (6, 1, 2) aic score is 8963.071815861895
# for (6, 1, 3) aic score is 8964.833450314662
# for (6, 1, 4) aic score is 8954.306371196179
# for (6, 1, 5) aic score is 8956.282275338515
# for (6, 1, 6) aic score is 8953.074191064643
# for (6, 1, 7) aic score is 8954.310104705473
# for (6, 1, 8) aic score is 8953.079735457586
# for (6, 1, 9) aic score is 8955.518017555429
# for (6, 1, 10) aic score is 8957.596670186387
# for (6, 1, 11) aic score is 8955.574426046152
# for (6, 1, 12) aic score is 8957.70286901982
# for (7, 1, 1) aic score is 8962.436601643934
# for (7, 1, 2) aic score is 8964.359958206605
# for (7, 1, 3) aic score is 8958.508785277048
# for (7, 1, 4) aic score is 8955.411326170255
# for (7, 1, 5) aic score is 8948.679092604165
# for (7, 1, 6) aic score is 8950.987556917411
# for (7, 1, 7) aic score is 8956.281152154621
# for (7, 1, 8) aic score is 8952.570799525114
# for (7, 1, 9) aic score is 8953.264448564354
# for (7, 1, 10) aic score is 8957.157791008874
# for (7, 1, 11) aic score is 8957.615855408865
# for (7, 1, 12) aic score is 8959.99221285502

# %% [markdown]
# ### training of model

# %%
p,d,q =1,1,7

model2 = ARIMA(train, order=(p,d,q)).fit()
print(model2.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  price   No. Observations:                  864
# Model:                 ARIMA(1, 1, 7)   Log Likelihood               -7583.967
# Date:                Wed, 01 Feb 2023   AIC                          15185.933
# Time:                        22:04:30   BIC                          15228.777
# Sample:                    05-07-2000   HQIC                         15202.333
#                          - 11-20-2016
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6937      0.072     -9.694      0.000      -0.834      -0.553
# ma.L1          0.4232      0.073      5.813      0.000       0.281       0.566
# ma.L2         -0.2788      0.025    -10.943      0.000      -0.329      -0.229
# ma.L3         -0.1383      0.020     -7.010      0.000      -0.177      -0.100
# ma.L4         -0.0495      0.017     -2.950      0.003      -0.082      -0.017
# ma.L5         -0.1310      0.029     -4.570      0.000      -0.187      -0.075
# ma.L6         -0.1087      0.031     -3.560      0.000      -0.169      -0.049
# ma.L7         -0.1282      0.021     -6.192      0.000      -0.169      -0.088
# sigma2      2.627e+06   4.22e+04     62.231      0.000    2.54e+06    2.71e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):             31184.43
# Prob(Q):                              0.81   Prob(JB):                         0.00
# Heteroskedasticity (H):             463.36   Skew:                             2.77
# Prob(H) (two-sided):                  0.00   Kurtosis:                        31.92
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### predictions

# %%
start = len(train)
end =  len(train)+len(test)-1
pred = model2.predict(start=start,end=end)

DF_ARiMA = pd.DataFrame({ 'Actual':test, 'Predicted':pred, 'Error':-test+pred})
DF_ARiMA.head()
# Out:
#               Actual     Predicted        Error
# 2016-11-27  12501.41  12048.258935  -453.151065
# 2016-12-04  15067.04  12217.967938 -2849.072062
# 2016-12-11  19488.52  12080.563405 -7407.956595
# 2016-12-18  16050.86  12265.636977 -3785.223023
# 2016-12-25  19515.66  12030.681025 -7484.978975

# %% [markdown]
# ### Actual vs predicted

# %%
plt.figure(figsize=(15,5))

plt.plot(test,'b--',linewidth=2,label='actual')
plt.plot(pred,'r-',linewidth=2,label='predicted')

plt.title(f'ARIMA Actual vs predicted')
plt.legend()
plt.grid()

# %% [markdown]
# ### Evaluation

# %%
mse = mean_squared_error(pred,test)
rmse = np.sqrt(mse)
print('Root Mean squarred error for ARIMA model  is : ',round(rmse,2))
# Out:
# Root Mean squarred error for ARIMA model  is :  8068.61

# %% [markdown]
# ### Ljung box test

# %%
pvalue = sm.stats.acorr_ljungbox(model1.resid,lags=[1],return_df=True)['lb_pvalue'].values
if pvalue < 0.05:
    print("Reject H0. Bad model")
else:
    print("Fail-to-Reject H0. Good model")
# Out:
# Fail-to-Reject H0. Good model

# %% [markdown]
# ### SARIMA Model

# %%
p,d,q = (6, 0, 6)
model = SARIMAX(train, order=(p,d,q), seasonal_order=(p,d,q,24)).fit()
print(model.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              price   No. Observations:                  864
# Model:             SARIMAX(6, 0, 6)x(6, 0, 6, 24)   Log Likelihood               -7577.832
# Date:                            Wed, 01 Feb 2023   AIC                          15205.665
# Time:                                    22:12:36   BIC                          15324.704
# Sample:                                05-07-2000   HQIC                         15251.227
#                                      - 11-20-2016
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0621      0.051      1.226      0.220      -0.037       0.161
# ar.L2          0.6844      0.082      8.379      0.000       0.524       0.845
# ar.L3          0.1046      0.039      2.689      0.007       0.028       0.181
# ar.L4          0.8590      0.110      7.794      0.000       0.643       1.075
# ar.L5          0.0870      0.058      1.508      0.132      -0.026       0.200
# ar.L6         -0.7986      0.069    -11.507      0.000      -0.935      -0.663
# ma.L1          0.6540      0.055     11.887      0.000       0.546       0.762
# ma.L2         -0.0929      0.061     -1.531      0.126      -0.212       0.026
# ma.L3         -0.0769      0.067     -1.140      0.254      -0.209       0.055
# ma.L4         -0.8252      0.042    -19.849      0.000      -0.907      -0.744
# ma.L5         -0.6903      0.063    -10.967      0.000      -0.814      -0.567
# ma.L6          0.2192      0.030      7.348      0.000       0.161       0.278
# ar.S.L24      -0.7864      0.739     -1.064      0.287      -2.235       0.662
# ar.S.L48       0.9166      2.022      0.453      0.650      -3.046       4.879
# ar.S.L72       1.5239      3.769      0.404      0.686      -5.863       8.911
# ar.S.L96       0.5927      2.674      0.222      0.825      -4.649       5.834
# ar.S.L120     -0.8423      0.753     -1.119      0.263      -2.318       0.633
# ar.S.L144     -0.8463      0.625     -1.354      0.176      -2.071       0.379
# ma.S.L24       0.7503      0.736      1.019      0.308      -0.693       2.194
# ma.S.L48      -0.9293      2.037     -0.456      0.648      -4.921       3.063
# ma.S.L72      -1.4744      3.705     -0.398      0.691      -8.737       5.788
# ma.S.L96      -0.5584      2.614     -0.214      0.831      -5.681       4.564
# ma.S.L120      0.8311      0.826      1.006      0.314      -0.788       2.450
# ma.S.L144      0.8121      0.632      1.285      0.199      -0.426       2.051
# sigma2      2.604e+06   5.83e-06   4.47e+11      0.000     2.6e+06     2.6e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.12   Jarque-Bera (JB):             31967.89
# Prob(Q):                              0.73   Prob(JB):                         0.00
# Heteroskedasticity (H):             436.53   Skew:                             2.99
# Prob(H) (two-sided):                  0.00   Kurtosis:                        32.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.69e+28. Standard errors may be unstable.

# %% [markdown]
# ### Predictions

# %%
start = len(train)
end =  len(train)+len(test)-1

pred = model.predict(start=start,end=end)

DF_SARIMA = pd.DataFrame({ 'Actual':test, 'Predicted':pred, 'Error':test-pred})
DF_SARIMA.head()
# Out:
#               Actual     Predicted        Error
# 2016-11-27  12501.41  11469.490459  1031.919541
# 2016-12-04  15067.04  13299.807410  1767.232590
# 2016-12-11  19488.52  12567.849188  6920.670812
# 2016-12-18  16050.86  12212.618395  3838.241605
# 2016-12-25  19515.66  12049.171834  7466.488166

# %% [markdown]
# ### Actual vs predicted

# %%
plt.figure(figsize=(15,5))

plt.plot(test,'b--',linewidth=2,label='actual')
plt.plot(pred,'r-',linewidth=2,label='predicted')

plt.title(f'SARIMA Actual vs predicted')
plt.legend()
plt.grid()

# %% [markdown]
# ### Evaluation

# %%
mse = mean_squared_error(pred,test)
rmse = np.sqrt(mse)
print('Root Mean squarred error for SARIMA model  is : ',round(rmse,2))
# Out:
# Root Mean squarred error for SARIMA model  is :  7756.54

# %% [markdown]
# ### Ljung box test

# %%
pvalue = sm.stats.acorr_ljungbox(model.resid,lags=[1],return_df=True)['lb_pvalue'].values
if pvalue < 0.05:
    print("Reject H0. Bad model")
else:
    print("Fail-to-Reject H0. Good model")
# Out:
# Fail-to-Reject H0. Good model

# %% [markdown]
# ### Comparision between ARMA , ARIMA , SARIMA forecasting

# %%
plt.figure(figsize=(20,8))
plt.plot(test,label='Test Data')
#plt.plot(category_resemple1,color='black',label='Actual')

plt.plot(DF_ARMA['Predicted'],color='blue',label='ARMA')
plt.plot(DF_ARiMA['Predicted'],color='purple',label='ARIMA')
plt.plot(DF_SARIMA['Predicted'],color='red',label='SARIMA')
plt.legend()

plt.title('ARMA VS ARIMA VS SARIMA ')
plt.show()

# %% [markdown]
# ### Forecasting the next year sales for ['Toys & Games', 'Action Figures & Statues', 'Action Figures']  category

# %%
# forecast for the next 52 weeks
start = 864+97
end = start + 52
future = model.predict(start=start,end=end)
future

plt.figure(figsize=(16,5))

plt.plot(train,color='black',label='Actual')
plt.plot(test,color='black')
plt.plot(future,color='red',label='Forecast')
plt.title("Forecasting total sales  for ['Toys & Games', 'Action Figures & Statues', 'Action Figures'] category for 2019")

plt.legend()
plt.show()

# %% [markdown]
# #### Observation
# the category rating for 2019 is expected to show a downward trend which is still more than 2018
# also the variance in rating is reduced compared to the previous year

# %% [markdown]
# ---

# %%
# reusability
d = df.copy()

d.sort_values(by='reviewTime',ascending=True,inplace=True)
d = d.set_index('reviewTime')
d.head()
# Out:
#             overall  verified        asin  \
# reviewTime
# 1999-10-06      5.0     False  1572810939
# 2000-03-08      5.0     False  B00000IWFB
# 2000-03-08      5.0     False  B00000IWFB
# 2000-05-02      3.0     False  B00000IW4C
# 2000-05-02      3.0     False  B00000IW4C
#
#                                                    reviewText  \
# reviewTime
# 1999-10-06  ready heart meet spade whist ready play wizard...
# 2000-03-08  long ha toy yes awhile great play great stress...
# 2000-03-08  long ha toy yes awhile great play great stress...
# 2000-05-02  came price wa year ago said not getting commte...
# 2000-05-02  came price wa year ago said not getting commte...
#
#                                             summary  \
# reviewTime
# 1999-10-06  The game was a great time for everyone.
# 2000-03-08           Lots of fun for grown-ups too!
# 2000-03-08           Lots of fun for grown-ups too!
# 2000-05-02     Getting better with the POTF figures
# 2000-05-02     Getting better with the POTF figures
#
#                                                      category           brand  \
# reviewTime
# 1999-10-06            ['Toys & Games', 'Games', 'Card Games']        US Games
# 2000-03-08                          ['Toys & Games', 'Games']  Milton Bradley
# 2000-03-08                          ['Toys & Games', 'Games']  Milton Bradley
# 2000-05-02  ['Toys & Games', 'Action Figures & Statues', '...          Hasbro
# 2000-05-02  ['Toys & Games', 'Action Figures & Statues', '...          Hasbro
#
#             price sentiment predicted
# reviewTime
# 1999-10-06  12.72  Positive  Positive
# 2000-03-08  39.63  Positive  Positive
# 2000-03-08  39.63  Positive  Positive
# 2000-05-02  19.95   Neutral  Positive
# 2000-05-02  19.95   Neutral  Positive

# %%
d1 = d['overall'].resample('m').mean()
d1 = d1[d1.index>='2002-01-01']
d1.head()
# Out:
# reviewTime
# 2002-01-31    4.125000
# 2002-02-28    4.000000
# 2002-03-31    5.000000
# 2002-04-30    4.782609
# 2002-05-31    4.520000
# Freq: M, Name: overall, dtype: float64

# %% [markdown]
# ### Data decomposition of ratings

# %%
decomposition=seasonal_decompose(d1, period=12)
d_trend=decomposition.trend
d_seasonal=decomposition.seasonal
d_residual=decomposition.resid

# plotting all the 4 graphs
fig,ax = plt.subplots(4,1,figsize=(20,12))

plt.subplot(411)
plt.plot(d1,label='Amazone Product Review')
plt.legend(loc='best')

plt.subplot(412)
plt.plot(d_trend,label='Trend')
plt.legend(loc='best')

plt.subplot(413)
plt.plot(d_seasonal,label='Seasonal')
plt.legend(loc='best')

plt.subplot(414)
plt.plot(d_residual,label='Residual')
plt.legend(loc='best')

plt.tight_layout()

# %% [markdown]
# In the decomposition graph we can see that there is a decrease in rating from year 2002 and increase after 2011 and also the seasonality is present that means repeatation of total ratings in between specific time period over the years

# %% [markdown]
# ### Data stationarity
# ADF test to check the stationarity of data

# %%
checkStationarity(d1)
# Out:
# 'p-value = 0.182. Data is not stationary'

# %% [markdown]
# Here we can see that if our Data is not stationary i.e. data don't have constant mean and constant variance over the time so for further processing we have to make data stationary so we can accurately do the statistical analysis.

# %% [markdown]
# ### Differencing method
# subtracts the current value from the previous value

# %%
shift1 = d1 - d1.shift(1)
checkStationarity(shift1.dropna())
# Out:
# 'p-value = 0.000. Data is stationary'

# %%
Stationary_positive = shift1.dropna()

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(15,5))

ax[0].plot(d1)
ax[0].set_title('Before making Data Stationary')

ax[1].plot(Stationary_positive)
ax[1].set_title('After making Data Stationary')
plt.show()

# %% [markdown]
# ACF PACF Plot Just with a quick look over the left graph it’s easy to determine the time series is not stationary. The average value changes over time and the peaks in the seasonal periods seem to get only larger

# %%
fig = plt.figure(figsize=(15,5))

# Show ACF
ax1 = fig.add_subplot(121)
sm.graphics.tsa.plot_acf(Stationary_positive, lags=8, ax=ax1)

# Show PACF
ax2 = fig.add_subplot(122)
sm.graphics.tsa.plot_pacf(Stationary_positive, lags=8, ax=ax2)
plt.tight_layout()

# %% [markdown]
# #### OBSERVATION
# From the graph above we get the Q value to be 1 and P value to be 4

# %% [markdown]
# ### Data spliting

# %%
train_size = int(0.8 * len(d1))

train = d1.iloc[:train_size]
test = d1.iloc[train_size:]
print("train = {}, test = {}".format(len(train), len(test)))
# Out:
# train = 161, test = 41

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for p in range(1,9):
    for q in range(1,9):
        m1 = ARIMA(Stationary_positive,order=(p,0,q))
        r1 = m1.fit()
        print(f'for AR{p,0,q} AIC score is {r1.aic}')
# Out:
# for AR(1, 0, 1) AIC score is -146.87506729408216
# for AR(1, 0, 2) AIC score is -144.70551340926437
# for AR(1, 0, 3) AIC score is -148.85625229106915
# for AR(1, 0, 4) AIC score is -146.81674011182295
# for AR(1, 0, 5) AIC score is -145.6496667436808
# for AR(1, 0, 6) AIC score is -143.5527472810498
# for AR(1, 0, 7) AIC score is -143.9729652800535
# for AR(1, 0, 8) AIC score is -145.8645687694177
# for AR(2, 0, 1) AIC score is -145.73772343755815
# for AR(2, 0, 2) AIC score is -146.55131689465526
# for AR(2, 0, 3) AIC score is -146.62666545619885
# for AR(2, 0, 4) AIC score is -144.8536753487459
# for AR(2, 0, 5) AIC score is -143.5583903682963
# for AR(2, 0, 6) AIC score is -141.21517284986038
# for AR(2, 0, 7) AIC score is -144.4875277191898
# for AR(2, 0, 8) AIC score is -144.27782621994717
# for AR(3, 0, 1) AIC score is -143.7785233853826
# for AR(3, 0, 2) AIC score is -146.6232528005067
# for AR(3, 0, 3) AIC score is -145.2009302349498
# for AR(3, 0, 4) AIC score is -142.33721655928986
# for AR(3, 0, 5) AIC score is -141.04811903770758
# for AR(3, 0, 6) AIC score is -139.51135696956393
# for AR(3, 0, 7) AIC score is -142.46395919947008
# for AR(3, 0, 8) AIC score is -141.67260817400148
# for AR(4, 0, 1) AIC score is -142.4253071229137
# for AR(4, 0, 2) AIC score is -141.27329997476664
# for AR(4, 0, 3) AIC score is -144.25948271145697
# for AR(4, 0, 4) AIC score is -141.3912795028438
# for AR(4, 0, 5) AIC score is -141.421791635885
# for AR(4, 0, 6) AIC score is -142.62028864861014
# for AR(4, 0, 7) AIC score is -142.70723390385098
# for AR(4, 0, 8) AIC score is -147.39162432284985
# for AR(5, 0, 1) AIC score is -140.5035505813969
# for AR(5, 0, 2) AIC score is -140.22429520240337
# for AR(5, 0, 3) AIC score is -140.7756889712222
# for AR(5, 0, 4) AIC score is -140.59526815586503
# for AR(5, 0, 5) AIC score is -139.6658227095135
# for AR(5, 0, 6) AIC score is -140.64829304755273
# for AR(5, 0, 7) AIC score is -138.51373455926606
# for AR(5, 0, 8) AIC score is -141.9498979502096
# for AR(6, 0, 1) AIC score is -148.3018303314662
# for AR(6, 0, 2) AIC score is -147.87171915094754
# for AR(6, 0, 3) AIC score is -146.18028320437094
# for AR(6, 0, 4) AIC score is -136.21216974279443
# for AR(6, 0, 5) AIC score is -143.2165984548172
# for AR(6, 0, 6) AIC score is -141.194519697583
# for AR(6, 0, 7) AIC score is -136.94083387920327
# for AR(6, 0, 8) AIC score is -137.23923420355726
# for AR(7, 0, 1) AIC score is -147.7087659180043
# for AR(7, 0, 2) AIC score is -146.8780299763258
# for AR(7, 0, 3) AIC score is -144.98386947114275
# for AR(7, 0, 4) AIC score is -143.98337464705136
# for AR(7, 0, 5) AIC score is -142.60761099065067
# for AR(7, 0, 6) AIC score is -140.0133617876744
# for AR(7, 0, 7) AIC score is -134.74960568084686
# for AR(7, 0, 8) AIC score is -137.0185706033235
# for AR(8, 0, 1) AIC score is -145.78059522431977
# for AR(8, 0, 2) AIC score is -145.11496590490862
# for AR(8, 0, 3) AIC score is -143.8549594081693
# for AR(8, 0, 4) AIC score is -142.5005161708954
# for AR(8, 0, 5) AIC score is -141.20521639606528
# for AR(8, 0, 6) AIC score is -139.1008398901707
# for AR(8, 0, 7) AIC score is -136.7531161926434
# for AR(8, 0, 8) AIC score is -141.54100088110079

# %% [markdown]
# ARMA(6,0,8) model giving the lowest AIC score thats we choose these parameters for further model training

# %%
p=6; q=8
model = ARIMA(train,order=(p,0,q))
result = model.fit()
print(result.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                overall   No. Observations:                  161
# Model:                 ARIMA(6, 0, 8)   Log Likelihood                  56.971
# Date:                Wed, 01 Feb 2023   AIC                            -81.942
# Time:                        22:13:27   BIC                            -32.639
# Sample:                    01-31-2002   HQIC                           -61.923
#                          - 05-31-2015
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.3934      0.040    110.888      0.000       4.316       4.471
# ar.L1          0.9238      0.361      2.561      0.010       0.217       1.631
# ar.L2          0.2944      0.230      1.279      0.201      -0.157       0.745
# ar.L3         -0.3424      0.187     -1.834      0.067      -0.708       0.023
# ar.L4         -0.3784      0.227     -1.667      0.096      -0.823       0.067
# ar.L5          0.6872      0.210      3.274      0.001       0.276       1.099
# ar.L6         -0.2249      0.266     -0.845      0.398      -0.747       0.297
# ma.L1         -0.8621      0.370     -2.330      0.020      -1.587      -0.137
# ma.L2         -0.3193      0.234     -1.363      0.173      -0.778       0.140
# ma.L3          0.4142      0.188      2.198      0.028       0.045       0.784
# ma.L4          0.3471      0.212      1.636      0.102      -0.069       0.763
# ma.L5         -0.7390      0.217     -3.399      0.001      -1.165      -0.313
# ma.L6          0.2234      0.259      0.861      0.389      -0.285       0.732
# ma.L7          0.4682      0.114      4.108      0.000       0.245       0.692
# ma.L8         -0.4030      0.166     -2.428      0.015      -0.728      -0.078
# sigma2         0.0283      0.003      9.297      0.000       0.022       0.034
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):                80.60
# Prob(Q):                              0.82   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.07   Skew:                            -0.52
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.31
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### Predictions

# %%
start = len(train)
end = len(train)+len(test)-1
pred = result.predict(start=start,end=end)

pred.index=d1.index[start:end+1]

# %% [markdown]
# ### Plotting Actual and Predicted

# %%
pred.plot(legend=True)
test.plot(legend=True)
# Out:
# <AxesSubplot:xlabel='reviewTime'>

# %% [markdown]
# Model is predicting near to the actual values but not the exact values and predictin values following the pattern of actual values overall ratings seems to rise after 2018 july

# %% [markdown]
# ### Evaluation

# %%
mse = mean_squared_error(pred,test)
print('Mean squarred error for ARMA model is : ',round(mse,2))
print('\nRoot Mean squarred error for ARMA model is : ',np.sqrt(round(mse,2)))
# Out:
# Mean squarred error for ARMA model is :  0.01
#
# Root Mean squarred error for ARMA model is :  0.1

# %% [markdown]
# ### ARIMA model

# %%
for p in range(1,7):
    for q in range(1,7):
        m1 = ARIMA(Stationary_positive,order=(p,1,q))
        r1 = m1.fit()
        print(f'for AR{p,1,q} AIC score is {r1.aic}')
# Out:
# for AR(1, 1, 1) AIC score is -73.17358575601331
# for AR(1, 1, 2) AIC score is -135.45747937346056
# for AR(1, 1, 3) AIC score is -130.73195844957925
# for AR(1, 1, 4) AIC score is -132.22514905606792
# for AR(1, 1, 5) AIC score is -130.77572856034175
# for AR(1, 1, 6) AIC score is -128.85509111405594
# for AR(2, 1, 1) AIC score is -101.499724348054
# for AR(2, 1, 2) AIC score is -86.53075941864064
# for AR(2, 1, 3) AIC score is -132.7783231509057
# for AR(2, 1, 4) AIC score is -136.92664049707537
# for AR(2, 1, 5) AIC score is -135.9174837683031
# for AR(2, 1, 6) AIC score is -134.55424520989786
# for AR(3, 1, 1) AIC score is -108.72911206803188
# for AR(3, 1, 2) AIC score is -99.83370400386357
# for AR(3, 1, 3) AIC score is -130.67432247010572
# for AR(3, 1, 4) AIC score is -135.71449858777703
# for AR(3, 1, 5) AIC score is -136.2279904581841
# for AR(3, 1, 6) AIC score is -134.93934004645672
# for AR(4, 1, 1) AIC score is -115.60203970715702
# for AR(4, 1, 2) AIC score is -117.18625375198138
# for AR(4, 1, 3) AIC score is -128.8340065978777
# for AR(4, 1, 4) AIC score is -131.94819752844765
# for AR(4, 1, 5) AIC score is -142.20325743587506
# for AR(4, 1, 6) AIC score is -130.6783080782542
# for AR(5, 1, 1) AIC score is -115.12469318219473
# for AR(5, 1, 2) AIC score is -116.47352479161401
# for AR(5, 1, 3) AIC score is -113.18559344102701
# for AR(5, 1, 4) AIC score is -131.33581071783019
# for AR(5, 1, 5) AIC score is -133.00997039158395
# for AR(5, 1, 6) AIC score is -129.23507164222943
# for AR(6, 1, 1) AIC score is -138.91047993902865
# for AR(6, 1, 2) AIC score is -137.61993110658756
# for AR(6, 1, 3) AIC score is -137.2467458338844
# for AR(6, 1, 4) AIC score is -130.85021290599678
# for AR(6, 1, 5) AIC score is -134.1655081082109
# for AR(6, 1, 6) AIC score is -131.0188785927466

# %% [markdown]
# ARIMA(6,1,1) Model giving the lowest AIC score

# %%
p=6; q=1
model = ARIMA(train,order=(p,1,q))
result = model.fit()

print(result.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                overall   No. Observations:                  161
# Model:                 ARIMA(6, 1, 1)   Log Likelihood                  49.960
# Date:                Wed, 01 Feb 2023   AIC                            -83.919
# Time:                        22:13:48   BIC                            -59.318
# Sample:                    01-31-2002   HQIC                           -73.929
#                          - 05-31-2015
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7184      0.164     -4.369      0.000      -1.041      -0.396
# ar.L2         -0.6333      0.155     -4.090      0.000      -0.937      -0.330
# ar.L3         -0.4861      0.127     -3.814      0.000      -0.736      -0.236
# ar.L4         -0.4752      0.105     -4.522      0.000      -0.681      -0.269
# ar.L5         -0.3837      0.094     -4.100      0.000      -0.567      -0.200
# ar.L6         -0.3514      0.069     -5.110      0.000      -0.486      -0.217
# ma.L1         -0.2585      0.174     -1.482      0.138      -0.600       0.083
# sigma2         0.0310      0.002     14.406      0.000       0.027       0.035
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):               157.82
# Prob(Q):                              0.75   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.06   Skew:                            -0.46
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
pred = result.predict(start=start,end=end)

# %%
mse = mean_squared_error(pred,test)
print('Mean squarred error for ARMA model is : ',mse)
print('\nRoot Mean squarred error for ARMA model is : ',np.sqrt(mse))
# Out:
# Mean squarred error for ARMA model is :  0.004422530128176268
#
# Root Mean squarred error for ARMA model is :  0.06650210619353547

# %%
m = SARIMAX(train, order=(6,1,1), seasonal_order=(6,1,1,12)).fit()

# %% [markdown]
# ### Predictions

# %%
pred=m.predict(len(train),((len(train)+len(test)-1)))

SARIMA = pd.DataFrame({'Actual':test,
                     'Predicted':pred,
                     'Error':test-pred})
SARIMA
# Out:
#               Actual  Predicted     Error
# 2015-06-30  4.509802   4.529686 -0.019884
# 2015-07-31  4.520956   4.572848 -0.051892
# 2015-08-31  4.524589   4.546599 -0.022010
# 2015-09-30  4.518361   4.590239 -0.071878
# 2015-10-31  4.515284   4.527452 -0.012168
# 2015-11-30  4.530265   4.538291 -0.008026
# 2015-12-31  4.489604   4.472557  0.017047
# 2016-01-31  4.532989   4.587426 -0.054438
# 2016-02-29  4.535126   4.558507 -0.023380
# 2016-03-31  4.529139   4.540618 -0.011478
# 2016-04-30  4.528057   4.580500 -0.052444
# 2016-05-31  4.544346   4.601273 -0.056928
# 2016-06-30  4.530359   4.534132 -0.003773
# 2016-07-31  4.503010   4.553542 -0.050531
# 2016-08-31  4.519286   4.564852 -0.045566
# 2016-09-30  4.515263   4.600112 -0.084849
# 2016-10-31  4.502491   4.528074 -0.025583
# 2016-11-30  4.516865   4.571685 -0.054820
# 2016-12-31  4.535221   4.536619 -0.001398
# 2017-01-31  4.549232   4.609112 -0.059880
# 2017-02-28  4.532454   4.595000 -0.062547
# 2017-03-31  4.526181   4.582477 -0.056296
# 2017-04-30  4.493652   4.612788 -0.119137
# 2017-05-31  4.496224   4.625444 -0.129220
# 2017-06-30  4.485806   4.577681 -0.091875
# 2017-07-31  4.492541   4.593848 -0.101308
# 2017-08-31  4.511066   4.592918 -0.081852
# 2017-09-30  4.484550   4.622613 -0.138063
# 2017-10-31  4.471693   4.571514 -0.099821
# 2017-11-30  4.453382   4.602968 -0.149586
# 2017-12-31  4.411427   4.573064 -0.161638
# 2018-01-31  4.495603   4.639478 -0.143875
# 2018-02-28  4.493361   4.629670 -0.136309
# 2018-03-31  4.510866   4.617305 -0.106439
# 2018-04-30  4.485357   4.641328 -0.155971
# 2018-05-31  4.445894   4.651665 -0.205771
# 2018-06-30  4.474706   4.610346 -0.135640
# 2018-07-31  4.480731   4.642127 -0.161396
# 2018-08-31  4.472765   4.638191 -0.165425
# 2018-09-30  4.358400   4.664981 -0.306581
# 2018-10-31  4.800000   4.621198  0.178802

# %% [markdown]
# ### Evaluation

# %%
err=np.sqrt(mean_squared_error(test,pred))
print('RMSE:',err)
# Out:
# RMSE: 0.10975844182751528

# %% [markdown]
# ### Actual and Predicted Plot

# %%
SARIMA[['Actual','Predicted']].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### LJung Box Test

# %%
pvalue = sm.stats.acorr_ljungbox(m.resid,lags=[1],return_df=True)['lb_pvalue'].values
if pvalue < 0.05:
    print("Reject H0. Bad model")
else:
    print("Fail-to-Reject H0. Good model")
# Out:
# Fail-to-Reject H0. Good model

# %% [markdown]
# Fail To Reject the H0 , Therefore it is a Good model

# %% [markdown]
# ### Forecasting future values

# %%
start = 202
end = 214
future =m.predict(start=start,end=end)
future
# Out:
# 2018-11-30    4.647560
# 2018-12-31    4.609213
# 2019-01-31    4.678988
# 2019-02-28    4.665596
# 2019-03-31    4.656880
# 2019-04-30    4.675112
# 2019-05-31    4.686785
# 2019-06-30    4.647182
# 2019-07-31    4.678755
# 2019-08-31    4.673668
# 2019-09-30    4.705235
# 2019-10-31    4.652544
# 2019-11-30    4.679639
# Freq: M, Name: predicted_mean, dtype: float64

# %%
d1.plot()
future.plot()
# Out:
# <AxesSubplot:xlabel='reviewTime'>

# %%
future.describe()
# Out:
# count    13.000000
# mean      4.665935
# std       0.023829
# min       4.609213
# 25%       4.652544
# 50%       4.673668
# 75%       4.678988
# max       4.705235
# Name: predicted_mean, dtype: float64

# %% [markdown]
# ## Data insights

# %% [markdown]
# - Since we have data for upto year 2018 , we are predicting the future        outcomes for year 2019.
# - The Average Rating For Year 2019 is 4.657113 and the Minimum is 4.599376 whereas 4.694732
# - We are predicting the reviewTime , we can see a steep rise and stability after year 2013 , before 2013 we can see that there was no stability but the graph provides us the information about the year 2002
# - We can also see that overall rating decreased after year 2002 , after 2002 we can hardly see 5 point review for toys and games over the years .
# - In 2007 where there is a steep high and low in overall reviews mainly because in 2007 Amazon released its new logo and the release of its first kindle in america .
# - India being the huge market in asia and asia pacific region amazon established itself in indian marketplace in year 2013 and the boom of digitalization in india boosted the overall ratings and also the stability.
# - Since we only have data for upto 2018 we can predict from various models and graphs that the overall rating is going to fall a bit but then gradually rise for year 2019.
# - Considering the data from 2002 to 2018 we get to a point that the customers are mostly happy with the toys and games section of amazon.
